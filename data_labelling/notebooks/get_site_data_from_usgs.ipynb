# %%
from urllib import request

import json
import os
import random

# %%
MAPBOX_ACCESS_TOKEN = os.environ['MAPBOX_ACCESS_TOKEN']

STATE_CODES = ['AL', 'AK', 'AZ', 'AR', 'CA', 'CO', 'CT', 'DC', 'DE', 'FL', 'GA', 
               'HI', 'ID', 'IL', 'IN', 'IA', 'KS', 'KY', 'LA', 'ME', 'MD', 
               'MA', 'MI', 'MN', 'MS', 'MO', 'MT', 'NE', 'NV', 'NH', 'NJ', 
               'NM', 'NY', 'NC', 'ND', 'OH', 'OK', 'OR', 'PA', 'RI', 'SC', 
               'SD', 'TN', 'TX', 'UT', 'VT', 'VA', 'WA', 'WV', 'WI', 'WY']

filepath = 'sites.json'

# %%
sites_dict = {
    'unchecked': [],
    'water': [],
    'no_water': []   
}

# %%
def get_sites_for_state(state_code):
    url = 'http://waterservices.usgs.gov/nwis/iv/?format=json&stateCd={}'.format(state_code)
    response = request.urlopen(url)
    sites = json.loads(response.read())['value']['timeSeries']

    return sites


def parse_site_data(site):
    site_info = site['sourceInfo']
    site_code = site_info['siteCode'][0]['value']
    site_geo_info = site_info['geoLocation']['geogLocation']

    name = site_info['siteName']
    lon = site_geo_info['longitude']
    lat = site_geo_info['latitude']

    return site_code, name, lon, lat

# %%
total_sites = 0
unique_sites = set()

for state_code in STATE_CODES:
    sites = get_sites_for_state(state_code)
    num_sites_for_state = 0

    for site in sites:
        site_code, name, lon, lat = parse_site_data(site)
        
        if site_code in unique_sites:
            continue

        unique_sites.add(site_code)
        num_sites_for_state += 1

        sites_dict['unchecked'].append({
            'site_code': site_code,
            'name': name,
            'lon': lon,
            'lat': lat
        })

    total_sites += num_sites_for_state
    print('Data recorded for {} {} sites.'.format(num_sites_for_state, state_code))

print('{} total sites.'.format(total_sites))
# Out:
# Data recorded for 224 AL sites.
# Data recorded for 269 AK sites.
# Data recorded for 425 AZ sites.
# Data recorded for 330 AR sites.
# Data recorded for 1154 CA sites.
# Data recorded for 754 CO sites.
# Data recorded for 105 CT sites.
# Data recorded for 7 DC sites.
# Data recorded for 64 DE sites.
# Data recorded for 1300 FL sites.
# Data recorded for 579 GA sites.
# Data recorded for 283 HI sites.
# Data recorded for 453 ID sites.
# Data recorded for 513 IL sites.
# Data recorded for 483 IN sites.
# Data recorded for 307 IA sites.
# Data recorded for 303 KS sites.
# Data recorded for 269 KY sites.
# Data recorded for 321 LA sites.
# Data recorded for 153 ME sites.
# Data recorded for 263 MD sites.
# Data recorded for 224 MA sites.
# Data recorded for 351 MI sites.
# Data recorded for 312 MN sites.
# Data recorded for 244 MS sites.
# Data recorded for 533 MO sites.
# Data recorded for 362 MT sites.
# Data recorded for 307 NE sites.
# Data recorded for 472 NV sites.
# Data recorded for 79 NH sites.
# Data recorded for 476 NJ sites.
# Data recorded for 734 NM sites.
# Data recorded for 669 NY sites.
# Data recorded for 623 NC sites.
# Data recorded for 186 ND sites.
# Data recorded for 550 OH sites.
# Data recorded for 312 OK sites.
# Data recorded for 578 OR sites.
# Data recorded for 539 PA sites.
# Data recorded for 58 RI sites.
# Data recorded for 374 SC sites.
# Data recorded for 255 SD sites.
# Data recorded for 283 TN sites.
# Data recorded for 954 TX sites.
# Data recorded for 319 UT sites.
# Data recorded for 77 VT sites.
# Data recorded for 559 VA sites.
# Data recorded for 539 WA sites.
# Data recorded for 193 WV sites.
# Data recorded for 527 WI sites.
# Data recorded for 265 WY sites.
# 20513 total sites.

# %%
sites_dict['unchecked'] = random.sample(sites_dict['unchecked'], len(sites_dict['unchecked']))

# %%
sites_dict
# Out:
# {'unchecked': [{'site_code': '445511074103902',
#    'name': 'Local number, F-854, at Burke NY',
#    'lon': -74.1771201,
#    'lat': 44.91971239},
#   {'site_code': '391056122420801',
#    'name': 'BARTLETT SPRINGS PRECIP GAGE A BARTLETT SPRINGS CA',
#    'lon': -122.7033224,
#    'lat': 39.1821118},
#   {'site_code': '412429087504201',
#    'name': 'RAIN GAGE NEAR MONEE, IL',
#    'lon': -87.845,
#    'lat': 41.40805556},
#   {'site_code': '03383000',
#    'name': 'TRADEWATER RIVER AT OLNEY, KY',
#    'lon': -87.7805659,
#    'lat': 37.22393575},
#   {'site_code': '04160900',
#    'name': 'CLINTON RIVER NEAR DRAYTON PLAINS, MI',
#    'lon': -83.3902164,
#    'lat': 42.6603092},
#   {'site_code': '05534050',
#    'name': 'DES PLAINES RIVER AT LOCKPORT, IL',
#    'lon': -88.0686111,
#    'lat': 41.59638889},
#   {'site_code': '14375400',
#    'name': 'ELK CREEK NEAR OBRIEN,OREG.',
#    'lon': -123.7378483,
#    'lat': 42.0315013},
#   {'site_code': '433242092260901',
#    'name': 'SPR-1A    South Drained Site Perimeter',
#    'lon': -92.4360556,
#    'lat': 43.54501667},
#   {'site_code': '06889200',
#    'name': 'SOLDIER C NR DELIA, KS',
#    'lon': -95.8885992,
#    'lat': 39.23833024},
#   {'site_code': '212340157552301',
#    'name': '3-2355-15 Kaamilo Deep, Oahu, HI',
#    'lon': -157.9200556,
#    'lat': 21.39105556},
#   {'site_code': '395316083593100',
#    'name': 'CL-11 OH',
#    'lon': -83.99186389,
#    'lat': 39.88766944},
#   {'site_code': '05387405',
#    'name': 'Upper Iowa River at Kendallville, IA',
#    'lon': -92.0359444,
#    'lat': 43.44130556},
#   {'site_code': '03536440',
#    'name': 'NORTHWEST TRIBUTARY NEAR OAK RIDGE, TN',
#    'lon': -84.320224,
#    'lat': 35.92179964},
#   {'site_code': '02149000',
#    'name': 'COVE CREEK NEAR LAKE LURE, NC',
#    'lon': -82.1116667,
#    'lat': 35.4233333},
#   {'site_code': '07030600',
#    'name': 'WOLF RIVER NEAR COLLIERVILLE',
#    'lon': -89.6505556,
#    'lat': 35.08138889},
#   {'site_code': '03612000',
#    'name': 'CACHE RIVER AT FORMAN, IL',
#    'lon': -88.923955,
#    'lat': 37.33644107},
#   {'site_code': '07380249',
#    'name': 'Caminada Pass NW of Grand Isle, LA',
#    'lon': -90.0485278,
#    'lat': 29.2313611},
#   {'site_code': '03381495',
#    'name': 'LITTLE WABASH RIVER AT MAIN ST AT CARMI, IL',
#    'lon': -88.1561487,
#    'lat': 38.09226857},
#   {'site_code': '415552070031701',
#    'name': 'MA-WNW 159-0035 WELLFLEET, MA',
#    'lon': -70.0547306,
#    'lat': 41.9311083},
#   {'site_code': '02011460',
#    'name': 'BACK CREEK NEAR SUNRISE, VA',
#    'lon': -79.76866328,
#    'lat': 38.24540129},
#   {'site_code': '08059590',
#    'name': 'Wilson Ck Dws of Hwy 75 at McKinney, TX',
#    'lon': -96.63805,
#    'lat': 33.18485},
#   {'site_code': '10348570',
#    'name': 'WINTERS CK BLW US ALT 395 NR WASHOE CITY, NV',
#    'lon': -119.8232083,
#    'lat': 39.31238889},
#   {'site_code': '09523600',
#    'name': 'YAQUI CANAL NEAR YUMA, AZ',
#    'lon': -114.5882852,
#    'lat': 32.80865585},
#   {'site_code': '02156409',
#    'name': 'BROAD RIVER NEAR LOCKHART, SC',
#    'lon': -81.4889869,
#    'lat': 34.73235784},
#   {'site_code': '354303080354645',
#    'name': 'RAINGAGE AT SECOND CREEK NEAR BARBER, NC',
#    'lon': -80.5959778,
#    'lat': 35.71756667},
#   {'site_code': '210544157014801',
#    'name': '4-0501-09 Forestry 1, Molokai, HI',
#    'lon': -157.0300833,
#    'lat': 21.09566667},
#   {'site_code': '301912088583300',
#    'name': 'MISSISSIPPI SOUND AT USGS GULFPORT LIGHT, MS',
#    'lon': -88.9722222,
#    'lat': 30.3186111},
#   {'site_code': '13171500',
#    'name': 'CJ STRIKE RES NR GRAND VIEW ID',
#    'lon': -115.975,
#    'lat': 42.9436111},
#   {'site_code': '09066200',
#    'name': 'BOOTH CREEK NEAR MINTURN, CO.',
#    'lon': -106.3230833,
#    'lat': 39.64831927},
#   {'site_code': '05289800',
#    'name': 'MINNEHAHA CREEK AT HIAWATHA AVE. IN MINNEAPOLIS,MN',
#    'lon': -93.2127224,
#    'lat': 44.91552097},
#   {'site_code': '09070500',
#    'name': 'COLORADO RIVER NEAR DOTSERO, CO',
#    'lon': -107.0780139,
#    'lat': 39.6446111},
#   {'site_code': '03326950',
#    'name': 'MISSISSINEWA LAKE AT PEORIA, IN',
#    'lon': -85.9572222,
#    'lat': 40.71444444},
#   {'site_code': '11162753',
#    'name': 'SAN MATEO C BL LO CRYSTAL SP RES NR SAN MATEO CA',
#    'lon': -122.3583333,
#    'lat': 37.52944444},
#   {'site_code': '360901114321056',
#    'name': 'LAKE MEAD VIRGIN BASIN QW PLATFORM 56 METER DEPTH',
#    'lon': -114.5361389,
#    'lat': 36.15016667},
#   {'site_code': '04191378',
#    'name': 'Flatrock Creek at State Route 613 near Payne OH',
#    'lon': -84.6930556,
#    'lat': 41.09166667},
#   {'site_code': '07196000',
#    'name': 'Flint Creek near Kansas, OK',
#    'lon': -94.7068913,
#    'lat': 36.18647245},
#   {'site_code': '14155500',
#    'name': 'ROW RIVER NEAR COTTAGE GROVE, OR',
#    'lon': -122.9914655,
#    'lat': 43.7929012},
#   {'site_code': '14377100',
#    'name': 'ILLINOIS RIVER NEAR KERBY, OR',
#    'lon': -123.66368,
#    'lat': 42.23177936},
#   {'site_code': '261735080534001',
#    'name': 'HE - 861',
#    'lon': -80.8928424,
#    'lat': 26.30285898},
#   {'site_code': '07032200',
#    'name': 'NONCONNAH CREEK NEAR GERMANTOWN, TN',
#    'lon': -89.81897519,
#    'lat': 35.04981397},
#   {'site_code': '08171000',
#    'name': 'Blanco Rv at Wimberley, TX',
#    'lon': -98.088898,
#    'lat': 29.9943808},
#   {'site_code': '07141175',
#    'name': 'BUCKNER C NR BURDETT, KS',
#    'lon': -99.6428988,
#    'lat': 38.1625166},
#   {'site_code': '05548030',
#    'name': 'NIPPERSINK CREEK NEAR GREENWOOD, IL',
#    'lon': -88.4416667,
#    'lat': 42.41444444},
#   {'site_code': '01304562',
#    'name': 'PECONIC RIVER AT COUNTY HWY 105 AT RIVERHEAD NY',
#    'lon': -72.6386667,
#    'lat': 40.91777778},
#   {'site_code': '02280500',
#    'name': 'HILLSBORO CANAL BELOW S351 NR SOUTH BAY FLA',
#    'lon': -80.712281,
#    'lat': 26.70034336},
#   {'site_code': '10310402',
#    'name': 'E BRANCH BROCKLISS SLOUGH AT MULLER LANE NR MINDEN',
#    'lon': -119.8318456,
#    'lat': 38.97074097},
#   {'site_code': '0136235580',
#    'name': 'WARNER CREEK IN SILVER HOLLOW NEAR CHICHESTER NY',
#    'lon': -74.2761944,
#    'lat': 42.09688889},
#   {'site_code': '16212480',
#    'name': 'Honouliuli Stream Tributary near Waipahu, Oahu, HI',
#    'lon': -158.0669167,
#    'lat': 21.40183333},
#   {'site_code': '021720869',
#    'name': 'ASHLEY RIVER NEAR NORTH CHARLESTON, SC',
#    'lon': -80.0237014,
#    'lat': 32.8346201},
#   {'site_code': '14199704',
#    'name': 'NATE CREEK TRIBUTARY NEAR COLTON, OR',
#    'lon': -122.4120018,
#    'lat': 45.2052333},
#   {'site_code': '411833075133601',
#    'name': 'PI   522  Pike County Observation Well',
#    'lon': -75.2268611,
#    'lat': 41.30919444},
#   {'site_code': '404812073004101',
#    'name': 'S  3521. 1',
#    'lon': -73.0108056,
#    'lat': 40.8033611},
#   {'site_code': '02202190',
#    'name': 'OGEECHEE RIVER AT GA 24, NEAR OLIVER, GA',
#    'lon': -81.5556634,
#    'lat': 32.4946232},
#   {'site_code': '02293345',
#    'name': 'SHADROE CANAL AT CAPE CORAL, FL',
#    'lon': -82.039257,
#    'lat': 26.6522948},
#   {'site_code': '01473169',
#    'name': 'Valley Creek at PA Turnpike Br near Valley Forge',
#    'lon': -75.46074808,
#    'lat': 40.07927367},
#   {'site_code': '272524080221800',
#    'name': 'FIVE MILE CANAL ABOVE S-29-1-4 NR FT. PIERCE, FL',
#    'lon': -80.37144,
#    'lat': 27.42365086},
#   {'site_code': '01608070',
#    'name': 'SOUTH BRANCH POTOMAC RIVER NEAR MOOREFIELD, WV',
#    'lon': -78.96002719,
#    'lat': 39.10399579},
#   {'site_code': '02303180',
#    'name': 'PEMBERTON CK AT WALLACE BRANCH RD NR PLANT CITY FL',
#    'lon': -82.1542538,
#    'lat': 28.04057533},
#   {'site_code': '11499100',
#    'name': 'SYCAN RIVER BELOW SNAKE CREEK NR BEATTY,OREG.',
#    'lon': -121.2788876,
#    'lat': 42.4859811},
#   {'site_code': '01125100',
#    'name': 'FRENCH RIVER AT NORTH GROSVENORDALE, CT',
#    'lon': -71.90051389,
#    'lat': 41.97846389},
#   {'site_code': '12148500',
#    'name': 'TOLT RIVER NEAR CARNATION, WA',
#    'lon': -121.8240056,
#    'lat': 47.69565678},
#   {'site_code': '02142654',
#    'name': 'MCDOWELL CREEK NR HUNTERSVILLE, NC',
#    'lon': -80.8905556,
#    'lat': 35.40694444},
#   {'site_code': '01379000',
#    'name': 'Passaic River near Millington NJ',
#    'lon': -74.52888889,
#    'lat': 40.68},
#   {'site_code': '12121830',
#    'name': 'INGLEWOOD CREEK AT E LK SAMM PKWY NR REDMOND, WA',
#    'lon': -122.0676213,
#    'lat': 47.61537788},
#   {'site_code': '350138106401102',
#    'name': '09N.03E.07.114A RIO BRAVO 5 SHALLOW',
#    'lon': -106.6710361,
#    'lat': 35.0277861},
#   {'site_code': '10301115',
#    'name': 'WALKER RVR BLW YERINGTON WEIR NR YERINGTON, NV',
#    'lon': -119.1560556,
#    'lat': 39.02041667},
#   {'site_code': '07144300',
#    'name': 'ARKANSAS R AT WICHITA, KS',
#    'lon': -97.3353227,
#    'lat': 37.64334849},
#   {'site_code': '343736079562200',
#    'name': 'CTF-  56',
#    'lon': -79.9406667,
#    'lat': 34.62677778},
#   {'site_code': '08164525',
#    'name': 'Lk Texana nr Edna, TX',
#    'lon': -96.5777528,
#    'lat': 28.89193124},
#   {'site_code': '01442500',
#    'name': 'Brodhead Creek at Minisink Hills, PA',
#    'lon': -75.1426788,
#    'lat': 40.998706},
#   {'site_code': '02223190',
#    'name': 'COMMISSIONER CREEK AT US 441, AT MCINTYRE, GA',
#    'lon': -83.1929324,
#    'lat': 32.8498693},
#   {'site_code': '11473900',
#    'name': 'MF EEL R NR DOS RIOS CA',
#    'lon': -123.3252913,
#    'lat': 39.70626687},
#   {'site_code': '02336644',
#    'name': 'SANDY CREEK AT BOLTON ROAD, NEAR ATLANTA, GA',
#    'lon': -84.4993756,
#    'lat': 33.77955088},
#   {'site_code': '07379960',
#    'name': 'Dawson Cr. at Bluebonnet Blvd near Baton Rouge, LA',
#    'lon': -91.0942712,
#    'lat': 30.38241445},
#   {'site_code': '12190718',
#    'name': 'PARK CREEK AT UPPER BRIDGE NEAR CONCRETE, WA',
#    'lon': -121.690975,
#    'lat': 48.7431767},
#   {'site_code': '03049500',
#    'name': 'Allegheny River at Natrona, PA',
#    'lon': -79.71838129,
#    'lat': 40.615344},
#   {'site_code': '452439122394600',
#    'name': 'OSWEGO CREEK NR DAM OUTLET, AT LAKE OSWEGO, OR',
#    'lon': -122.6628333,
#    'lat': 45.4108611},
#   {'site_code': '06653500',
#    'name': 'HORSESHOE CREEK NEAR GLENDO, WYO.',
#    'lon': -104.9702484,
#    'lat': 42.452469},
#   {'site_code': '05480500',
#    'name': 'Des Moines River at Fort Dodge, IA',
#    'lon': -94.2035732,
#    'lat': 42.50830276},
#   {'site_code': '13275300',
#    'name': 'POWDER RIVER NEAR SUMPTER, OREG.',
#    'lon': -117.995495,
#    'lat': 44.67210015},
#   {'site_code': '05432927',
#    'name': 'PLEASANT VALLEY CREEK @ CTH H NR BLANCHARDVILLE,WI',
#    'lon': -89.7991667,
#    'lat': 42.8747222},
#   {'site_code': '07344210',
#    'name': 'Sulphur Rv nr Texarkana, TX',
#    'lon': -94.1513889,
#    'lat': 33.30416667},
#   {'site_code': '03022540',
#    'name': 'Woodcock Creek at Blooming Valley, PA',
#    'lon': -80.04811219,
#    'lat': 41.6906115},
#   {'site_code': '09306242',
#    'name': 'CORRAL GULCH NEAR RANGELY, CO',
#    'lon': -108.4728719,
#    'lat': 39.9202502},
#   {'site_code': '04269000',
#    'name': 'ST. REGIS RIVER AT BRASHER CENTER NY',
#    'lon': -74.77888889,
#    'lat': 44.8636111},
#   {'site_code': '06877600',
#    'name': 'SMOKY HILL R AT ENTERPRISE, KS',
#    'lon': -97.1177952,
#    'lat': 38.90638906},
#   {'site_code': '251241080385302',
#    'name': 'G  -3763',
#    'lon': -80.6477778,
#    'lat': 25.21},
#   {'site_code': '08110100',
#    'name': 'Davidson Ck nr Lyons, TX',
#    'lon': -96.5402466,
#    'lat': 30.41965196},
#   {'site_code': '402615075530501',
#    'name': 'BE   623 Berks County Observation Well',
#    'lon': -75.88425,
#    'lat': 40.4374722},
#   {'site_code': '06930000',
#    'name': 'Big Piney River near Big Piney, MO',
#    'lon': -92.0499167,
#    'lat': 37.66563889},
#   {'site_code': '12304500',
#    'name': 'Yaak River near Troy MT',
#    'lon': -115.9701583,
#    'lat': 48.5617222},
#   {'site_code': '404949099445701',
#    'name': ' 10N 21W18DDD 1 LEXINGTON',
#    'lon': -99.7498944,
#    'lat': 40.83013889},
#   {'site_code': '0208250885',
#    'name': 'TAR RIVER AT US 301 BYPASS AT ROCKY MOUNT, NC',
#    'lon': -77.8305556,
#    'lat': 35.9261111},
#   {'site_code': '01581920',
#    'name': 'GUNPOWDER FALLS NEAR PARKTON, MD',
#    'lon': -76.6903056,
#    'lat': 39.61888889},
#   {'site_code': '08385000',
#    'name': 'FORT SUMNER MAIN CANAL NEAR FORT SUMNER, NM',
#    'lon': -104.2783611,
#    'lat': 34.50827778},
#   {'site_code': '09243700',
#    'name': 'MIDDLE CREEK NEAR OAK CREEK, CO',
#    'lon': -106.993107,
#    'lat': 40.38553335},
#   {'site_code': '02246804',
#    'name': 'DUNN CREEK AT DUNN CREEK RD NR EASTPORT, FL',
#    'lon': -81.59688889,
#    'lat': 30.45494167},
#   {'site_code': '390735084333301',
#    'name': 'Lower inflow weir at St. Francis, Cincinnati OH',
#    'lon': -84.5590917,
#    'lat': 39.12626389},
#   {'site_code': '07260678',
#    'name': 'East Fork Point Remove Creek nr Morrilton, AR',
#    'lon': -92.6811111,
#    'lat': 35.28416667},
#   {'site_code': '365654091001301',
#    'name': 'Big Spring',
#    'lon': -91.0037222,
#    'lat': 36.94841667},
#   {'site_code': '391827074371001',
#    'name': '010578-- Jobs Point Obs',
#    'lon': -74.6187687,
#    'lat': 39.30733785},
#   {'site_code': '0204288905',
#    'name': 'BAILEY CREEK AT DOCK LANDING RD AT CHESAPEAKE, VA',
#    'lon': -76.4087222,
#    'lat': 36.80575},
#   {'site_code': '08211520',
#    'name': 'Oso Ck at Corpus Christi, TX',
#    'lon': -97.5019377,
#    'lat': 27.71141879},
#   {'site_code': '03058500',
#    'name': 'WEST FORK RIVER AT BUTCHERVILLE, WV',
#    'lon': -80.4675915,
#    'lat': 39.09064846},
#   {'site_code': '02307673',
#    'name': 'ALLIGATOR CREEK AT CLEARWATER FL',
#    'lon': -82.7156559,
#    'lat': 27.9730757},
#   {'site_code': '010965852',
#    'name': 'BEAVER BROOK AT NORTH PELHAM, NH',
#    'lon': -71.35367448,
#    'lat': 42.78286636},
#   {'site_code': '441923120534300',
#    'name': 'CROOKED RIVER BLW OCHOCO CREEK, NR PRINEVILLE, OR',
#    'lon': -120.8952778,
#    'lat': 44.32305556},
#   {'site_code': '360246114443012',
#    'name': 'BOULDER BASIN MONITORING STATION (56 METER DEPTH)',
#    'lon': -114.7416667,
#    'lat': 36.0461111},
#   {'site_code': '03293548',
#    'name': 'OHIO RIVER AT 2ND STREET BRIDGE AT LOUISVILLE, KY',
#    'lon': -85.751907,
#    'lat': 38.26257074},
#   {'site_code': '06890898',
#    'name': 'PERRY LK NR PERRY, KS',
#    'lon': -95.4263636,
#    'lat': 39.11416639},
#   {'site_code': '02310742',
#    'name': 'CRYSTAL RIVER AT MOUTH OF KINGS BAY FL',
#    'lon': -82.6055556,
#    'lat': 28.8933611},
#   {'site_code': '350146106401801',
#    'name': '09N.03E.07.113A RBERS-T2',
#    'lon': -106.6717111,
#    'lat': 35.02916667},
#   {'site_code': '023365218',
#    'name': 'PROCTOR CREEK TRIB AT SPRING ST, AT ATLANTA, GA',
#    'lon': -84.46888889,
#    'lat': 33.79277778},
#   {'site_code': '09024000',
#    'name': 'FRASER RIVER AT WINTER PARK, CO.',
#    'lon': -105.7766741,
#    'lat': 39.89998695},
#   {'site_code': '441558123103500',
#    'name': 'WILLAMETTE R SIDE CHANNEL ON LB NEAR RM 161.3',
#    'lon': -123.1764333,
#    'lat': 44.26624444},
#   {'site_code': '14140000',
#    'name': 'BULL RUN RIVER NEAR BULL RUN (RIVER ONLY), OR',
#    'lon': -122.1796556,
#    'lat': 45.4373},
#   {'site_code': '04254500',
#    'name': 'MOOSE RIVER AT MCKEEVER NY',
#    'lon': -75.1105556,
#    'lat': 43.61027778},
#   {'site_code': '11476600',
#    'name': 'BULL C NR WEOTT CA',
#    'lon': -124.0050423,
#    'lat': 40.351528},
#   {'site_code': '371554076010200',
#    'name': 'CAPE CHARLES HARBOR AT CAPE CHARLES, VA',
#    'lon': -76.017325,
#    'lat': 37.26495556},
#   {'site_code': '04233286',
#    'name': 'SIXMILE CREEK AT BROOKTONDALE NY',
#    'lon': -76.3944444,
#    'lat': 42.38138889},
#   {'site_code': '344520079281001',
#    'name': 'SC-040 AT LAURINBURG, NC (BLACK CREEK)',
#    'lon': -79.4672222,
#    'lat': 34.755},
#   {'site_code': '01161280',
#    'name': 'CONNECTICUT RIVER NEAR NORTHFIELD, MA',
#    'lon': -72.4719444,
#    'lat': 42.6833333},
#   {'site_code': '08091730',
#    'name': 'Squaw Ck Res nr Glen Rose, TX',
#    'lon': -97.786974,
#    'lat': 32.30014116},
#   {'site_code': '04166750',
#    'name': 'MIDDLE RIVER ROUGE AT PLYMOUTH, MI',
#    'lon': -83.4454903,
#    'lat': 42.37170308},
#   {'site_code': '330735090300200',
#    'name': 'HARD CASH LAKE AT HARD CASH, MS',
#    'lon': -90.5005833,
#    'lat': 33.12633333},
#   {'site_code': '02079640',
#    'name': 'ALLEN CREEK NEAR BOYDTON, VA',
#    'lon': -78.326664,
#    'lat': 36.67958589},
#   {'site_code': '03238745',
#    'name': 'TWELVEMILE CREEK AT HIGHWAY 1997 NR ALEXANDRIA, KY',
#    'lon': -84.3382712,
#    'lat': 38.9514529},
#   {'site_code': '01054000',
#    'name': 'Androscoggin River near Gorham, NH',
#    'lon': -71.19027778,
#    'lat': 44.4358333},
#   {'site_code': '01117471',
#    'name': 'BEAVER RIVER SHANNOCK HILL RD, NEAR SHANNOCK, RI',
#    'lon': -71.62784109,
#    'lat': 41.4642672},
#   {'site_code': '06773150',
#    'name': 'SILVER CREEK AT OVINA, NE',
#    'lon': -98.4541667,
#    'lat': 40.9597222},
#   {'site_code': '275411081372001',
#    'name': 'ROMP 57 FLORIDAN WELL NEAR LAKE WALES FL',
#    'lon': -81.6225,
#    'lat': 27.90363889},
#   {'site_code': '05587480',
#    'name': 'PIASA CREEK NEAR MELVILLE, IL',
#    'lon': -90.2716667,
#    'lat': 38.95777778},
#   {'site_code': '04086149',
#    'name': 'MILWAUKEE RIVER ABOVE DAM AT KEWASKUM, WI',
#    'lon': -88.2223184,
#    'lat': 43.527219},
#   {'site_code': '02130840',
#    'name': 'BLACK CREEK BELOW CHESTERFIELD, SC',
#    'lon': -80.2116667,
#    'lat': 34.6633333},
#   {'site_code': '13352950',
#    'name': 'LAKE SACAJAWEA FOREBAY AT ICE HARBOR DAM, WA',
#    'lon': -118.8774998,
#    'lat': 46.25152478},
#   {'site_code': '02147310',
#    'name': 'CATAWBA RIVER AT GREAT FALLS,SC',
#    'lon': -80.8905556,
#    'lat': 34.59805556},
#   {'site_code': '02390140',
#    'name': 'SETTINGDOWN CREEK NEAR BALL GROUND, GA',
#    'lon': -84.2635319,
#    'lat': 34.2931497},
#   {'site_code': '254848080432001',
#    'name': 'SITE 65 IN CONSERVATION AREA 3A NR COOPERTOWN, FL',
#    'lon': -80.7201222,
#    'lat': 25.8142722},
#   {'site_code': '16272200',
#    'name': 'Kamooalii Str blw Luluku Str nr Kaneohe, Oahu, HI',
#    'lon': -157.80375,
#    'lat': 21.39338889},
#   {'site_code': '14321000',
#    'name': 'UMPQUA RIVER NEAR ELKTON, OR',
#    'lon': -123.5553727,
#    'lat': 43.5859502},
#   {'site_code': '03230310',
#    'name': 'Little Darby Creek at West Jefferson OH',
#    'lon': -83.26936009,
#    'lat': 39.9511729},
#   {'site_code': '01464500',
#    'name': 'Crosswicks Creek at Extonville NJ',
#    'lon': -74.6,
#    'lat': 40.1372222},
#   {'site_code': '370828094274101',
#    'name': 'Webb City 6',
#    'lon': -94.4611944,
#    'lat': 37.1411111},
#   {'site_code': '324325114461001',
#    'name': '016S021E33E001S',
#    'lon': -114.7703241,
#    'lat': 32.72350874},
#   {'site_code': '01186000',
#    'name': 'WEST BRANCH FARMINGTON RIVER AT RIVERTON, CT',
#    'lon': -73.017606,
#    'lat': 41.9628729},
#   {'site_code': '341741116132501',
#    'name': '002N007E02C001S',
#    'lon': -116.224454,
#    'lat': 34.2941669},
#   {'site_code': '04235000',
#    'name': 'CANANDAIGUA OUTLET AT CHAPIN NY',
#    'lon': -77.23277778,
#    'lat': 42.91805556},
#   {'site_code': '380653080155301',
#    'name': ' Poc-0256',
#    'lon': -80.26451729,
#    'lat': 38.11484119},
#   {'site_code': '06794650',
#    'name': 'Clear Creek 1.75 mile W of Polk County line, Nebr.',
#    'lon': -97.4033333,
#    'lat': 41.35194444},
#   {'site_code': '08136600',
#    'name': 'O. H. Ivie Res nr Voss, TX',
#    'lon': -99.6684022,
#    'lat': 31.50015746},
#   {'site_code': '16283600',
#    'name': 'SF WAIHEE STR NR HEEIA, OAHU, HI',
#    'lon': -157.8672533,
#    'lat': 21.44321779},
#   {'site_code': '09415639',
#    'name': 'ASH SPGS DIV AT ASH SPGS, NV',
#    'lon': -115.1941025,
#    'lat': 37.45982179},
#   {'site_code': '01310740',
#    'name': 'REYNOLDS CHANNEL AT POINT LOOKOUT NY',
#    'lon': -73.5837396,
#    'lat': 40.5934366},
#   {'site_code': '0212880025',
#    'name': 'PEE DEE RIVER BELOW POWERHOUSE DAM NR PEE DEE, NC',
#    'lon': -79.8775806,
#    'lat': 34.9834833},
#   {'site_code': '12188380',
#    'name': 'SUIATTLE RIVER ABOVE ALL CREEK NR DARRINGTON, WA',
#    'lon': -121.418174,
#    'lat': 48.3017792},
#   {'site_code': '13210986',
#    'name': 'W HARTLEY GULCH NR CALDWELL ID',
#    'lon': -116.6856944,
#    'lat': 43.69960556},
#   {'site_code': '14312000',
#    'name': 'SOUTH UMPQUA RIVER NEAR BROCKWAY, OR',
#    'lon': -123.3984053,
#    'lat': 43.13317169},
#   {'site_code': '01362398',
#    'name': 'STONY CLOVE CR ABOVE ST HWY 214 AT PHOENICIA NY',
#    'lon': -74.3158333,
#    'lat': 42.08305556},
#   {'site_code': '05594100',
#    'name': 'KASKASKIA RIVER NEAR VENEDY STATION, IL',
#    'lon': -89.6275926,
#    'lat': 38.45060486},
#   {'site_code': '12464606',
#    'name': 'SAND HOLLOW CREEK AT S RD SW NEAR VANTAGE, WA',
#    'lon': -119.8997709,
#    'lat': 46.9304106},
#   {'site_code': '03039035',
#    'name': 'Allegheny River at Lock & Dam 6 at Clinton, PA',
#    'lon': -79.5811111,
#    'lat': 40.71666667},
#   {'site_code': '02047370',
#    'name': 'NOTTOWAY RIVER NEAR RIVERDALE, VA',
#    'lon': -76.9444058,
#    'lat': 36.56681864},
#   {'site_code': '254754080344300',
#    'name': 'SHARK RIVER SLOUGH NO.1 IN CONS.3B NR COOPERTOWN',
#    'lon': -80.5788611,
#    'lat': 25.79755556},
#   {'site_code': '09035800',
#    'name': 'DARLING CREEK NEAR LEAL, CO.',
#    'lon': -106.0264066,
#    'lat': 39.8005418},
#   {'site_code': '07068510',
#    'name': 'Little Black River below Fairdealing, MO',
#    'lon': -90.5753925,
#    'lat': 36.63172367},
#   {'site_code': '0134277123',
#    'name': 'HONNEDAGA LAKE TRIBUTARY NO. 6 AT FOREST LODGE NY',
#    'lon': -74.8148611,
#    'lat': 43.5115},
#   {'site_code': '07377243',
#    'name': 'Sandy Ck at Alph. Forbes nr Greenwell Springs, LA',
#    'lon': -90.9821167,
#    'lat': 30.62110833},
#   {'site_code': '02315005',
#    'name': 'HUNTER CREEK NEAR BELMONT FLA',
#    'lon': -82.7120734,
#    'lat': 30.4857755},
#   {'site_code': '02160390',
#    'name': 'ENOREE RIVER NEAR WOODRUFF, SC',
#    'lon': -82.0398229,
#    'lat': 34.68345815},
#   {'site_code': '01170500',
#    'name': 'CONNECTICUT RIVER AT MONTAGUE CITY, MA',
#    'lon': -72.5745,
#    'lat': 42.5802222},
#   {'site_code': '06718550',
#    'name': 'NORTH CLEAR CREEK ABOVE MOUTH NR BLACK HAWK, CO',
#    'lon': -105.3997159,
#    'lat': 39.74887674},
#   {'site_code': '415549070031401',
#    'name': 'MA-WNW 158 WELLFLEET, MA',
#    'lon': -70.0537556,
#    'lat': 41.93035},
#   {'site_code': '353825105594702',
#    'name': '16N.09E.04.334B NMOSE Fairgrounds Mid Piezometer',
#    'lon': -105.9963889,
#    'lat': 35.64027778},
#   {'site_code': '01184100',
#    'name': 'STONY BROOK NEAR WEST SUFFIELD, CT',
#    'lon': -72.7104861,
#    'lat': 41.96083889},
#   {'site_code': '05527905',
#    'name': 'HASTINGS CREEK NEAR LINDENHURST, IL',
#    'lon': -88.0247222,
#    'lat': 42.44805556},
#   {'site_code': '434657112282201',
#    'name': '05N 34E 09BDA1               USGS 4',
#    'lon': -112.4734887,
#    'lat': 43.7821113},
#   {'site_code': '381711088521700',
#    'name': 'RAIN GAGE AT CASEY FORK AT MOUNT VERNON, IL',
#    'lon': -88.87138889,
#    'lat': 38.28638889},
#   {'site_code': '03362500',
#    'name': 'SUGAR CREEK NEAR EDINBURGH, IN',
#    'lon': -85.9980833,
#    'lat': 39.36091667},
#   {'site_code': '03263000',
#    'name': 'Great Miami River at Taylorsville OH',
#    'lon': -84.16188479,
#    'lat': 39.87450176},
#   {'site_code': '405105087173301',
#    'name': 'NEWTON 6 (NE 6)',
#    'lon': -87.2927611,
#    'lat': 40.85138056},
#   {'site_code': '411535096020301',
#    'name': 'Little Papillion Cr at Dodge St at Omaha, Nebr.',
#    'lon': -96.0341667,
#    'lat': 41.2597222},
#   {'site_code': '01359133',
#    'name': 'PATROON CR AT NORTHERN BLVD AT ALBANY NY',
#    'lon': -73.7555556,
#    'lat': 42.67138889},
#   {'site_code': '321740106481001',
#    'name': 'MBOWN-33 - 23S.01E.23.244A (LC-3A)',
#    'lon': -106.8033379,
#    'lat': 32.29453824},
#   {'site_code': '03196800',
#    'name': 'ELK RIVER AT CLAY, WV',
#    'lon': -81.0876087,
#    'lat': 38.46065656},
#   {'site_code': '13140800',
#    'name': 'BIG WOOD RIVER AT STANTON CROSSING NR BELLEVUE ID',
#    'lon': -114.3191667,
#    'lat': 43.32916667},
#   {'site_code': '07339000',
#    'name': 'Mountain Fork near Eagletown, OK',
#    'lon': -94.6199358,
#    'lat': 34.04177757},
#   {'site_code': '05421000',
#    'name': 'Wapsipinicon River at Independence, IA',
#    'lon': -91.8951722,
#    'lat': 42.46359796},
#   {'site_code': '07229200',
#    'name': 'Canadian River at Purcell, OK',
#    'lon': -97.3475281,
#    'lat': 35.01396104},
#   {'site_code': '390937090365500',
#    'name': 'RAIN GAGE AT ILLINOIS RIVER AT HARDIN, IL',
#    'lon': -90.6153994,
#    'lat': 39.1603259},
#   {'site_code': '414431085313001',
#    'name': 'LAGRANGE 11 (LG 11)',
#    'lon': -85.5249556,
#    'lat': 41.7419361},
#   {'site_code': '10172300',
#    'name': 'RED BUTTE CR @ 1600 EAST @ SALT LAKE CITY, UT',
#    'lon': -111.8446568,
#    'lat': 40.74661305},
#   {'site_code': '02301300',
#    'name': 'SOUTH PRONG ALAFIA RIVER NEAR LITHIA FL',
#    'lon': -82.1175877,
#    'lat': 27.79669525},
#   {'site_code': '402618095222701',
#    'name': 'Tarkio Glacial Drift Aquifer',
#    'lon': -95.3741667,
#    'lat': 40.4383333},
#   {'site_code': '09419679',
#    'name': 'LAS VEGAS WASTEWAY NR E LAS VEGAS, NV',
#    'lon': -115.0194403,
#    'lat': 36.10608548},
#   {'site_code': '14163900',
#    'name': 'MCKENZIE RIVER NEAR WALTERVILLE, OR',
#    'lon': -122.7711874,
#    'lat': 44.0698492},
#   {'site_code': '09033010',
#    'name': 'MEADOW CREEK DIVERSION NEAR TABERNASH, CO',
#    'lon': -105.7797056,
#    'lat': 40.0502861},
#   {'site_code': '05570360',
#    'name': 'EVELYN BRANCH NEAR BRYANT, IL',
#    'lon': -90.102341,
#    'lat': 40.48753988},
#   {'site_code': '03459500',
#    'name': 'PIGEON RIVER NEAR HEPCO, NC',
#    'lon': -82.99,
#    'lat': 35.635},
#   {'site_code': '13172410',
#    'name': 'MURPHY FLAT CANAL NR MURPHY ID',
#    'lon': -116.396111,
#    'lat': 43.1972222},
#   {'site_code': '09498500',
#    'name': 'SALT RIVER NEAR ROOSEVELT, AZ',
#    'lon': -110.9215037,
#    'lat': 33.6194949},
#   {'site_code': '422202083023305',
#    'name': 'R. PARK SOUTH 07 SHALLOW REPLACED (RP-S-07 SR)',
#    'lon': -83.0425917,
#    'lat': 42.36730556},
#   {'site_code': '293332098550701',
#    'name': 'Medina Lk Meteorological Sta 2 nr Rio Medina, TX',
#    'lon': -98.9185,
#    'lat': 29.55883333},
#   {'site_code': '08329882',
#    'name': 'PINO ARROYO AT JEFFERSON ST. AT ALBUQUERQUE, NM',
#    'lon': -106.5975,
#    'lat': 35.15944444},
#   {'site_code': '07359610',
#    'name': 'Caddo River near Caddo Gap, AR',
#    'lon': -93.6061111,
#    'lat': 34.38277778},
#   {'site_code': '09255000',
#    'name': 'SLATER FORK NEAR SLATER, CO',
#    'lon': -107.3828391,
#    'lat': 40.9824657},
#   {'site_code': '13210824',
#    'name': 'N MIDDLETON DRAIN (MILL SLOUGH) AT MIDDLETON ID',
#    'lon': -116.6181917,
#    'lat': 43.70655},
#   {'site_code': '395301105120800',
#    'name': 'ANTELOPE SPGS. CR. ABV. WOMAN CR. AT RFP',
#    'lon': -105.2030434,
#    'lat': 39.8833196},
#   {'site_code': '364358120314906',
#    'name': '014S013E11D006M',
#    'lon': -120.5315278,
#    'lat': 36.73263889},
#   {'site_code': '06409000',
#    'name': 'CASTLE CR ABOVE DEERFIELD RES NEAR HILL CITY,SD',
#    'lon': -103.8304784,
#    'lat': 44.01359238},
#   {'site_code': '07331000',
#    'name': 'Washita River near Dickson, OK',
#    'lon': -96.9758447,
#    'lat': 34.23342725},
#   {'site_code': '403846105164801',
#    'name': 'HIGH PARK PRECIP ON RIST CANYON RD NEAR BELLVUE CO',
#    'lon': -105.2802611,
#    'lat': 40.6461611},
#   {'site_code': '09404104',
#    'name': 'CATARACT CREEK AT REDLANDS CROSSING NEAR VALLE, AZ',
#    'lon': -112.4263889,
#    'lat': 35.80444444},
#   {'site_code': '374736080181600',
#    'name': 'HOWARDS CREEK AT WHITE SULPHUR SPRINGS, WV',
#    'lon': -80.3045583,
#    'lat': 37.7934361},
#   {'site_code': '01343403',
#    'name': 'BLACK CREEK NEAR GRAY NY',
#    'lon': -74.9591944,
#    'lat': 43.28277778},
#   {'site_code': '335714116565001',
#    'name': '002S001W35J001S',
#    'lon': -116.9471528,
#    'lat': 33.9541333},
#   {'site_code': '02239501',
#    'name': 'SILVER RIVER NEAR OCALA, FL',
#    'lon': -82.0412,
#    'lat': 29.2149764},
#   {'site_code': '03301500',
#    'name': 'ROLLING FORK NEAR BOSTON, KY',
#    'lon': -85.7038488,
#    'lat': 37.7672853},
#   {'site_code': '02145268',
#    'name': 'DUHARTS CREEK AT SR 2439 NEAR CRAMERTON, NC',
#    'lon': -81.0978167,
#    'lat': 35.24765},
#   {'site_code': '09265500',
#    'name': 'ASHLEY CR ABV SP NR VERNAL UT',
#    'lon': -109.6229194,
#    'lat': 40.58884697},
#   {'site_code': '02135060',
#    'name': 'CHINNERS SWAMP NEAR AYNOR, SC',
#    'lon': -79.2406007,
#    'lat': 33.9734987},
#   {'site_code': '420451121510000',
#    'name': 'KLAMATH STRAITS DRAIN NEAR HIGHWAY 97, OR',
#    'lon': -121.85,
#    'lat': 42.0808333},
#   {'site_code': '13170800',
#    'name': 'GRAND VIEW REALTY PUMPING PLANT NR GRAND VIEW ID',
#    'lon': -115.9575,
#    'lat': 42.93138889},
#   {'site_code': '06893793',
#    'name': 'Little Blue River below Longview Dam at KC, MO',
#    'lon': -94.4685833,
#    'lat': 38.92591667},
#   {'site_code': '09504000',
#    'name': 'VERDE RIVER NEAR CLARKDALE, AZ',
#    'lon': -112.065994,
#    'lat': 34.8522416},
#   {'site_code': '09415460',
#    'name': 'WHITE RV NR RED MTN NR PRESTON, NV',
#    'lon': -115.2983582,
#    'lat': 38.93521559},
#   {'site_code': '0209722970',
#    'name': 'SANDY CREEK AT CORNWALLIS RD NEAR DURHAM, NC',
#    'lon': -78.9568056,
#    'lat': 35.9832222},
#   {'site_code': '05426070',
#    'name': 'BARK RIVER AT DELAFIELD, WI',
#    'lon': -88.4025968,
#    'lat': 43.0627864},
#   {'site_code': '01655794',
#    'name': 'TURKEY RUN AT ROUTE 643 NEAR CATLETT, VA',
#    'lon': -77.7475556,
#    'lat': 38.67577778},
#   {'site_code': '06166000',
#    'name': 'Beaver Cr bl Guston Coulee nr Saco MT',
#    'lon': -107.5821861,
#    'lat': 48.3567833},
#   {'site_code': '07249413',
#    'name': 'Poteau River near Panama, OK',
#    'lon': -94.6530016,
#    'lat': 35.16565268},
#   {'site_code': '01570500',
#    'name': 'Susquehanna River at Harrisburg, PA',
#    'lon': -76.8860846,
#    'lat': 40.25481164},
#   {'site_code': '05599500',
#    'name': 'BIG MUDDY RIVER AT MURPHYSBORO, IL',
#    'lon': -89.3466667,
#    'lat': 37.74805556},
#   {'site_code': '11109700',
#    'name': 'LK PIRU NR PIRU CA',
#    'lon': -118.7514805,
#    'lat': 34.46138337},
#   {'site_code': '350359106335208',
#    'name': '10N.04E.30.134H CESAR CHAVEZ DEEP OBS-1H',
#    'lon': -106.5645694,
#    'lat': 35.06649444},
#   {'site_code': '01407600',
#    'name': 'Shrewsbury River at Sea Bright, NJ',
#    'lon': -73.9747222,
#    'lat': 40.36555556},
#   {'site_code': '12208000',
#    'name': 'MF NOOKSACK RIVER NEAR DEMING, WA',
#    'lon': -122.1065434,
#    'lat': 48.7792828},
#   {'site_code': '07141780',
#    'name': 'WALNUT C AT NEKOMA, KS',
#    'lon': -99.4381656,
#    'lat': 38.47723614},
#   {'site_code': '340503117104101',
#    'name': '001S003W15K001S',
#    'lon': -117.1772083,
#    'lat': 34.0843222},
#   {'site_code': '333241095432300',
#    'name': 'Rain Gage at Roxton, TX',
#    'lon': -95.7230556,
#    'lat': 33.5447222},
#   {'site_code': '302341086305600',
#    'name': 'EAST PASS TO CHOCTAWHATCHEE BAY AT DESTIN FL',
#    'lon': -86.5155722,
#    'lat': 30.3948472},
#   {'site_code': '04212100',
#    'name': 'Grand River near Painesville OH',
#    'lon': -81.2278789,
#    'lat': 41.7189339},
#   {'site_code': '07274252',
#    'name': 'OTOUCALOFA CREEK CANAL NR WATER VALLEY, MS',
#    'lon': -89.6525,
#    'lat': 34.14416667},
#   {'site_code': '194037156012901',
#    'name': 'Aimakapa Fishpond 2-inch PVC monitoring pipe, HI',
#    'lon': -156.0247222,
#    'lat': 19.67694444},
#   {'site_code': '01654000',
#    'name': 'ACCOTINK CREEK NEAR ANNANDALE, VA',
#    'lon': -77.2283158,
#    'lat': 38.81289066},
#   {'site_code': '394211088231100',
#    'name': 'RAIN GAGE AT KASKASKIA RIVER AT CHESTERVILLE, IL',
#    'lon': -88.3864406,
#    'lat': 39.7030884},
#   {'site_code': '06933500',
#    'name': 'Gasconade River at Jerome, MO',
#    'lon': -91.9773333,
#    'lat': 37.92991667},
#   {'site_code': '04133501',
#    'name': 'THUNDER BAY RIVER AT HERRON ROAD NEAR BOLTON, MI',
#    'lon': -83.63554,
#    'lat': 45.1241787},
#   {'site_code': '12100498',
#    'name': 'WHITE RIVER AT PACIFIC, WA',
#    'lon': -122.238453,
#    'lat': 47.26010078},
#   {'site_code': '02300210',
#    'name': 'SOUTH FORK LITTLE MANATEE RIVER NEAR PARRISH FL',
#    'lon': -82.2112009,
#    'lat': 27.60197978},
#   {'site_code': '06893400',
#    'name': 'Indian Creek at 103rd St in Kansas City, MO',
#    'lon': -94.6045,
#    'lat': 38.9419722},
#   {'site_code': '02039500',
#    'name': 'APPOMATTOX RIVER AT FARMVILLE, VA',
#    'lon': -78.388607,
#    'lat': 37.3070965},
#   {'site_code': '324605091475701',
#    'name': 'Mo-1286 WU',
#    'lon': -91.7991667,
#    'lat': 32.76805556},
#   {'site_code': '451031069185301',
#    'name': 'Dover-Foxcroft Precip near Dover-Foxcroft, Maine',
#    'lon': -69.3147222,
#    'lat': 45.17527778},
#   {'site_code': '15085900',
#    'name': 'WOLF LK OUTLET NR HOLLIS AK',
#    'lon': -132.5972134,
#    'lat': 55.5304722},
#   {'site_code': '02322685',
#    'name': 'ICHETUCKNEE HEAD SPRING NR HILDRETH, FL',
#    'lon': -82.7619444,
#    'lat': 29.98388889},
#   {'site_code': '340559117194504',
#    'name': '001S004W08E004S',
#    'lon': -117.3301889,
#    'lat': 34.09991944},
#   {'site_code': '15295700',
#    'name': 'TERROR R AT MOUTH NR KODIAK AK',
#    'lon': -153.1639087,
#    'lat': 57.69397807},
#   {'site_code': '10322535',
#    'name': 'HENDERSON CK BLW VINNINI CK NR EUREKA, NV',
#    'lon': -116.1669444,
#    'lat': 39.869},
#   {'site_code': '443320089212303',
#    'name': 'PT-24/09E/13-1447',
#    'lon': -89.3563306,
#    'lat': 44.555675},
#   {'site_code': '340046117020804',
#    'name': '002S002W12H004S',
#    'lon': -117.0363917,
#    'lat': 34.01291667},
#   {'site_code': '03144816',
#    'name': 'South Fork Licking River at Kirkersville OH',
#    'lon': -82.5986111,
#    'lat': 39.9636111},
#   {'site_code': '01118010',
#    'name': 'PAWCATUCK RIVER AT BURDICKVILLE, RI',
#    'lon': -71.7289551,
#    'lat': 41.4162111},
#   {'site_code': '02335810',
#    'name': 'CHATTAHOOCHEE RIVER AT MORGAN FALLS DAM, GA',
#    'lon': -84.3827778,
#    'lat': 33.9683333},
#   {'site_code': '01582000',
#    'name': 'LITTLE FALLS AT BLUE MOUNT, MD',
#    'lon': -76.6204722,
#    'lat': 39.6040833},
#   {'site_code': '03331040',
#    'name': 'PIKE LAKE AT WARSAW, IN',
#    'lon': -85.8499914,
#    'lat': 41.26226699},
#   {'site_code': '08031000',
#    'name': 'Cow Bayou nr Mauriceville, TX',
#    'lon': -93.9085058,
#    'lat': 30.18632045},
#   {'site_code': '03146405',
#    'name': 'North Fork Licking River at Ohio Street, Newark OH',
#    'lon': -82.3922222,
#    'lat': 40.05388889},
#   {'site_code': '09527590',
#    'name': 'COACHELLA CANAL ABOVE ALL-AMERICAN CANAL DIVERSION',
#    'lon': -114.9438889,
#    'lat': 32.71416667},
#   {'site_code': '294643095035200',
#    'name': 'Lynchburg Res nr CWA Canal Inflow nr Baytown, TX',
#    'lon': -95.0644278,
#    'lat': 29.7785861},
#   {'site_code': '15087618',
#    'name': 'STARRIGAVAN C AT UPPER BRIDGE NR SITKA AK',
#    'lon': -135.3334277,
#    'lat': 57.12491678},
#   {'site_code': '07301420',
#    'name': 'Sweetwater Creek near Sweetwater, OK',
#    'lon': -99.9692772,
#    'lat': 35.42227237},
#   {'site_code': '0248018020',
#    'name': 'ESCATAWPA RIVER AT I-10 NR ORANGE GROVE, MS',
#    'lon': -88.45138889,
#    'lat': 30.4586111},
#   {'site_code': '382427107491401',
#    'name': 'LGRB-Poly 25',
#    'lon': -107.8205556,
#    'lat': 38.4075},
#   {'site_code': '07374510',
#    'name': '(COE) Mississippi River at New Orleans, LA',
#    'lon': -90.13618489,
#    'lat': 29.9349269},
#   {'site_code': '302609081453300',
#    'name': 'TROUT RIVER BL US 1 AT DINSMORE, FL',
#    'lon': -81.7592,
#    'lat': 30.43585},
#   {'site_code': '301124081395901',
#    'name': 'ST.JOHNS RIVER BUCKMAN BRIDGE AT JACKSONVILLE,FL',
#    'lon': -81.6662048,
#    'lat': 30.1902405},
#   {'site_code': '16247150',
#    'name': 'Makiki Stream at Aarohie Baker Park, Oahu, HI',
#    'lon': -157.8304167,
#    'lat': 21.30872222},
#   {'site_code': '07256500',
#    'name': 'Spadra Creek at Clarksville, AR',
#    'lon': -93.4630556,
#    'lat': 35.4683333},
#   {'site_code': '260536080302501',
#    'name': 'EDEN 4 IN WATER CONSERVATION AREA 3-A',
#    'lon': -80.5069444,
#    'lat': 26.09333333},
#   {'site_code': '442450071052301',
#    'name': 'NH-SJW    2',
#    'lon': -71.0892421,
#    'lat': 44.41394958},
#   {'site_code': '02450000',
#    'name': 'MULBERRY FORK NEAR GARDEN CITY, AL.',
#    'lon': -86.73666329,
#    'lat': 34.01204356},
#   {'site_code': '07030500',
#    'name': 'WOLF RIVER AT ROSSVILLE, TN',
#    'lon': -89.5411896,
#    'lat': 35.05425748},
#   {'site_code': '16726000',
#    'name': 'Up Hamakua Ditch abv Waimea Res Div nr Kamuela, HI',
#    'lon': -155.626109,
#    'lat': 20.0566606},
#   {'site_code': '13157296',
#    'name': 'ROCKING R RANCH CANAL NR HAMMETT ID',
#    'lon': -115.6333333,
#    'lat': 42.9675},
#   {'site_code': '440024088361601',
#    'name': 'RUSCHFIELD DR STORM SEWER AT OSHKOSH, WI',
#    'lon': -88.6044444,
#    'lat': 44.00666667},
#   {'site_code': '381929076043002',
#    'name': 'DO Fe  42',
#    'lon': -76.0749694,
#    'lat': 38.3246361},
#   {'site_code': '380229093464701',
#    'name': 'Osceola',
#    'lon': -93.7799339,
#    'lat': 38.0416967},
#   {'site_code': '03188900',
#    'name': 'LAUREL CREEK NEAR FENWICK, WV',
#    'lon': -80.5880556,
#    'lat': 38.1636111},
#   {'site_code': '06837500',
#    'name': 'RED WILLOW CREEK NEAR MCCOOK, NEBR.',
#    'lon': -100.6441667,
#    'lat': 40.345},
#   {'site_code': '02136358',
#    'name': 'SAMPIT RIVER NEAR GEORGETOWN, SC',
#    'lon': -79.3833333,
#    'lat': 33.36194444},
#   {'site_code': '332948094464101',
#    'name': 'Rain Gage at Avery, TX',
#    'lon': -94.7779167,
#    'lat': 33.49652778},
#   {'site_code': '09479350',
#    'name': 'GILA RIVER NEAR MARICOPA, AZ.',
#    'lon': -112.0073648,
#    'lat': 33.168661},
#   {'site_code': '02429900',
#    'name': 'BIG BROWN CREEK NR BOONEVILLE, MS',
#    'lon': -88.445,
#    'lat': 34.6247222},
#   {'site_code': '01121330',
#    'name': 'FENTON RIVER AT MANSFIELD, CT',
#    'lon': -72.2427806,
#    'lat': 41.83319444},
#   {'site_code': '15310002',
#    'name': 'MOSQUITO FORK 2 MI BL KECHUMSTUK C NR CHICKEN AK',
#    'lon': -142.5283333,
#    'lat': 64.0344444},
#   {'site_code': '261938080101001',
#    'name': 'G  -2852',
#    'lon': -80.16925,
#    'lat': 26.32766667},
#   {'site_code': '410428087231501',
#    'name': 'NEWTON 8 (NE 8)',
#    'lon': -87.4289201,
#    'lat': 41.0744789},
#   {'site_code': '07277730',
#    'name': 'SENATOBIA CREEK NR SENATOBIA, MS',
#    'lon': -89.9413889,
#    'lat': 34.61666667},
#   {'site_code': '12472380',
#    'name': 'CRAB CREEK LATERAL ABOVE ROYAL LAKE NR OTHELLO, WA',
#    'lon': -119.3486328,
#    'lat': 46.87680678},
#   {'site_code': '02403310',
#    'name': 'CHOCCOLOCCO CREEK NEAR BOILING SPRING, ALABAMA',
#    'lon': -85.7852411,
#    'lat': 33.60204998},
#   {'site_code': '01411485',
#    'name': 'Maurice River at Brotmanville NJ',
#    'lon': -75.0733333,
#    'lat': 39.52194444},
#   {'site_code': '09365000',
#    'name': 'SAN JUAN RIVER AT FARMINGTON, NM',
#    'lon': -108.2255889,
#    'lat': 36.72301667},
#   {'site_code': '02299735',
#    'name': "VENICE INLET AT CROW'S NEST MARINA AT VENICE FL",
#    'lon': -82.4655556,
#    'lat': 27.1122222},
#   {'site_code': '07329700',
#    'name': 'Wildhorse Creek near Hoover, OK',
#    'lon': -97.2472436,
#    'lat': 34.54147378},
#   {'site_code': '08403500',
#    'name': 'CARLSBAD MAIN CANAL AT HEAD NEAR CARLSBAD, NM',
#    'lon': -104.2527278,
#    'lat': 32.49039444},
#   {'site_code': '10315600',
#    'name': 'MARYS RV BLW TWIN BUTTES NR DEETH, NV',
#    'lon': -115.2711684,
#    'lat': 41.15436386},
#   {'site_code': '02301900',
#    'name': 'FOX BRANCH NEAR SOCRUM, FL',
#    'lon': -82.0125,
#    'lat': 28.18194444},
#   {'site_code': '333959090243601',
#    'name': 'MS-GW-41167  LEFLORE WU',
#    'lon': -90.41,
#    'lat': 33.66638889},
#   {'site_code': '05480986',
#    'name': 'Lyons Creek near Webster City, IA (L3)',
#    'lon': -93.7668056,
#    'lat': 42.49325},
#   {'site_code': '03283370',
#    'name': 'CAT CREEK NEAR STANTON, KY',
#    'lon': -83.8113065,
#    'lat': 37.83202665},
#   {'site_code': '10219000',
#    'name': 'SEVIER RIVER NEAR JUAB, UT',
#    'lon': -112.0396557,
#    'lat': 39.37468029},
#   {'site_code': '262158081283402',
#    'name': 'C  - 983',
#    'lon': -81.4764676,
#    'lat': 26.3670253},
#   {'site_code': '03009680',
#    'name': 'Potato Creek at Smethport, PA',
#    'lon': -78.4302963,
#    'lat': 41.809786},
#   {'site_code': '02175445',
#    'name': 'SAVANNAH CREEK AT EHRHARDT, SC',
#    'lon': -81.0319444,
#    'lat': 33.08666667},
#   {'site_code': '362505078562901',
#    'name': 'PS-102 NEAR ROXBORO, NC (GRANITE)',
#    'lon': -78.94125,
#    'lat': 36.41794444},
#   {'site_code': '01475530',
#    'name': 'Cobbs Cr at U.S. Hghwy No. 1 at Philadelphia, PA',
#    'lon': -75.2799067,
#    'lat': 39.97483455},
#   {'site_code': '12331900',
#    'name': 'Clark Fork near Clinton MT',
#    'lon': -113.5893306,
#    'lat': 46.71737778},
#   {'site_code': '0208734210',
#    'name': 'WALNUT CREEK AT TRAILWOOD DRIVE AT RALEIGH, NC',
#    'lon': -78.691,
#    'lat': 35.76838889},
#   {'site_code': '01399190',
#    'name': 'Lamington (Black) River at Succasunna NJ',
#    'lon': -74.6341667,
#    'lat': 40.85055556},
#   {'site_code': '12467000',
#    'name': 'CRAB CREEK NEAR MOSES LAKE, WA',
#    'lon': -119.265855,
#    'lat': 47.1893085},
#   {'site_code': '14167000',
#    'name': 'COYOTE CREEK NEAR CROW, OREG.',
#    'lon': -123.255926,
#    'lat': 44.0217904},
#   {'site_code': '09235100',
#    'name': 'CROUSE CREEK NEAR VERNAL, UT',
#    'lon': -109.0912348,
#    'lat': 40.7952383},
#   {'site_code': '01472104',
#    'name': 'Schuylkill River at Vincent Dam at Linfield, PA',
#    'lon': -75.5654631,
#    'lat': 40.20621166},
#   {'site_code': '05536121',
#    'name': 'CHICAGO RIVER AT CHICAGO LOCK AT CHICAGO, IL',
#    'lon': -87.6075518,
#    'lat': 41.88836638},
#   {'site_code': '07333010',
#    'name': 'Atoka Reservoir near Stringtown, OK',
#    'lon': -96.0836033,
#    'lat': 34.44537087},
#   {'site_code': '01439800',
#    'name': 'Big Flat Brook near Hainesville NJ',
#    'lon': -74.8036111,
#    'lat': 41.20694444},
#   {'site_code': '09419753',
#    'name': 'LV WASH ABV THREE KIDS WASH BLW HENDERSON, NV',
#    'lon': -114.9433194,
#    'lat': 36.100375},
#   {'site_code': '342835099230401',
#    'name': '01S-21W-15 ABC 1 SFR02',
#    'lon': -99.3845944,
#    'lat': 34.4764083},
#   {'site_code': '350147106402601',
#    'name': '09N.03E.07.113K RBWRS-T2',
#    'lon': -106.6734806,
#    'lat': 35.02933889},
#   {'site_code': '13334700',
#    'name': 'ASOTIN CREEK BELOW KEARNEY GULCH NEAR ASOTIN, WA',
#    'lon': -117.1526605,
#    'lat': 46.3262691},
#   {'site_code': '02391860',
#    'name': 'ETOWAH RIVER DOWNSTREAM OF I-575, AT CANTON, GA',
#    'lon': -84.4691667,
#    'lat': 34.2508333},
#   {'site_code': '11176900',
#    'name': 'ARROYO DE LA LAGUNA A VERONA CA',
#    'lon': -121.8830126,
#    'lat': 37.62659915},
#   {'site_code': '272603080324901',
#    'name': 'STL- 286',
#    'lon': -80.5467219,
#    'lat': 27.43448404},
#   {'site_code': '251032080432200',
#    'name': 'SEVEN PALM LAKE NEAR FLAMINGO, FL',
#    'lon': -80.7231111,
#    'lat': 25.17464167},
#   {'site_code': '16400000',
#    'name': 'Halawa Stream near Halawa, Molokai, HI',
#    'lon': -156.7619722,
#    'lat': 21.1555},
#   {'site_code': '05592800',
#    'name': 'HURRICANE CREEK NEAR MULBERRY GROVE, IL',
#    'lon': -89.2367389,
#    'lat': 38.9225459},
#   {'site_code': '354048119445003',
#    'name': '026S021E07J003M',
#    'lon': -119.7474306,
#    'lat': 35.6801611},
#   {'site_code': '322245083290101',
#    'name': '18T001',
#    'lon': -83.4835102,
#    'lat': 32.3793221},
#   {'site_code': '07157940',
#    'name': 'BLUFF C NR BUTTERMILK, KS',
#    'lon': -99.4795615,
#    'lat': 37.03197269},
#   {'site_code': '07019130',
#    'name': 'Meramec River at Valley Park, MO',
#    'lon': -90.4850278,
#    'lat': 38.5466111},
#   {'site_code': '05536123',
#    'name': 'CHICAGO RIVER AT COLUMBUS DRIVE AT CHICAGO, IL',
#    'lon': -87.6211634,
#    'lat': 41.88836628},
#   {'site_code': '363308114553001',
#    'name': '217  S16 E63 09DDAB1    USBLM SHV-1',
#    'lon': -114.9245444,
#    'lat': 36.5526722},
#   {'site_code': '09468500',
#    'name': 'SAN CARLOS RIVER NEAR PERIDOT, AZ.',
#    'lon': -110.4514876,
#    'lat': 33.29644678},
#   {'site_code': '12399500',
#    'name': 'COLUMBIA RIVER AT INTERNATIONAL BOUNDARY',
#    'lon': -117.6294206,
#    'lat': 49.00074966},
#   {'site_code': '02344736',
#    'name': 'WHITEWATER CR AT SHERWOOD RD, NR FAYETTEVILLE, GA',
#    'lon': -84.4927778,
#    'lat': 33.42138889},
#   {'site_code': '02146800',
#    'name': 'SUGAR CREEK NEAR FORT MILL, SC',
#    'lon': -80.9022968,
#    'lat': 35.0059812},
#   {'site_code': '383239076354201',
#    'name': 'CA Db  47',
#    'lon': -76.5946667,
#    'lat': 38.54355556},
#   {'site_code': '393647105425317',
#    'name': 'SOUTH CLEAR CREEK ABV NAYLOR CREEK NR GEORGETOWN C',
#    'lon': -105.7152832,
#    'lat': 39.61304278},
#   {'site_code': '09309600',
#    'name': 'FAIRVIEW TUNNEL NEAR FAIRVIEW, UT',
#    'lon': -111.3121238,
#    'lat': 39.6674624},
#   {'site_code': '394348118040254',
#    'name': 'DVSV ET STA DEPTH 4.1 FT BLW LAND SURFACE (A)',
#    'lon': -118.0672639,
#    'lat': 39.73010556},
#   {'site_code': '06299500',
#    'name': 'WOLF CREEK AT WOLF, WY',
#    'lon': -107.234243,
#    'lat': 44.77246889},
#   {'site_code': '351514116401403',
#    'name': '013N003E04C003S',
#    'lon': -116.6710194,
#    'lat': 35.253575},
#   {'site_code': '05330920',
#    'name': 'MINNESOTA RIVER AT FORT SNELLING STATE PARK, MN',
#    'lon': -93.1924432,
#    'lat': 44.8702432},
#   {'site_code': '021473415',
#    'name': 'FISHING CREEK @ HWY 5 BELOW YORK, SC',
#    'lon': -81.18,
#    'lat': 34.975},
#   {'site_code': '09383590',
#    'name': 'IRRIGATION DIV. 1 AT WENIMA, NR SPRINGERVILLE, AZ',
#    'lon': -109.3395332,
#    'lat': 34.18893399},
#   {'site_code': '01113695',
#    'name': 'CATAMINT BROOK AT CUMBERLAND, RI',
#    'lon': -71.41366908,
#    'lat': 41.98509878},
#   {'site_code': '02322016',
#    'name': 'BLUES CREEK NEAR GAINSVILLE, FL',
#    'lon': -82.4314979,
#    'lat': 29.72829934},
#   {'site_code': '05537500',
#    'name': 'LONG RUN NEAR LEMONT, IL',
#    'lon': -87.9992252,
#    'lat': 41.642531},
#   {'site_code': '04085492',
#    'name': 'ELKHART LAKE OUTLET NEAR ELKHART LAKE, WI',
#    'lon': -88.03704,
#    'lat': 43.83027126},
#   {'site_code': '08188570',
#    'name': 'San Antonio Rv nr McFaddin, TX',
#    'lon': -97.0426944,
#    'lat': 28.53125},
#   {'site_code': '02197600',
#    'name': 'BRUSHY CREEK NEAR WRENS, GA',
#    'lon': -82.3056793,
#    'lat': 33.17709065},
#   {'site_code': '402411077374801',
#    'name': 'JU   351  Juniata County Observation Well',
#    'lon': -77.62988889,
#    'lat': 40.40302778},
#   {'site_code': '350916116453501',
#    'name': '012N002E10C002S',
#    'lon': -116.7598056,
#    'lat': 35.1544722},
#   {'site_code': '392229090542501',
#    'name': 'MISSISSIPPI R AT LOCK & DAM 24 (LOWER) (CORPS)',
#    'lon': -90.907076,
#    'lat': 39.37476918},
#   {'site_code': '01067950',
#    'name': 'Kennebunk River near Kennebunk, Maine',
#    'lon': -70.5533333,
#    'lat': 43.4322222},
#   {'site_code': '06807410',
#    'name': 'West Nishnabotna River at Hancock, IA',
#    'lon': -95.3716666,
#    'lat': 41.38999164},
#   {'site_code': '06483950',
#    'name': 'BIG SIOUX RIVER NR HAWARDEN, IA',
#    'lon': -96.4897545,
#    'lat': 43.05137597},
#   {'site_code': '07194906',
#    'name': 'Spring Creek at Sanders Ave at Springdale, AR',
#    'lon': -94.1358889,
#    'lat': 36.19566667},
#   {'site_code': '03084698',
#    'name': 'Turtle Creek at Wilmerding, PA',
#    'lon': -79.8058805,
#    'lat': 40.39423566},
#   {'site_code': '08451800',
#    'name': 'USIBW Rio Grande at Del Rio, TX & Acuna, MX',
#    'lon': -100.9284283,
#    'lat': 29.33550774},
#   {'site_code': '08420500',
#    'name': 'Pecos Rv at Pecos, TX',
#    'lon': -103.467395,
#    'lat': 31.43652327},
#   {'site_code': '02357000',
#    'name': 'SPRING CREEK NEAR IRON CITY, GA',
#    'lon': -84.74,
#    'lat': 31.04027778},
#   {'site_code': '06406760',
#    'name': 'RENO GULCH NEAR HILL CITY,SD',
#    'lon': -103.6124162,
#    'lat': 43.9097067},
#   {'site_code': '02132320',
#    'name': 'BIG SHOE HEEL CREEK NR LAURINBURG, NC',
#    'lon': -79.3866667,
#    'lat': 34.75055556},
#   {'site_code': '08074150',
#    'name': 'Cole Ck at Deihl Rd, Houston, TX',
#    'lon': -95.4879965,
#    'lat': 29.8513369},
#   {'site_code': '02336152',
#    'name': 'SOUTH FORK PEACHTREE AT CASA DR, NR CLARKSTON, GA',
#    'lon': -84.2479722,
#    'lat': 33.81044444},
#   {'site_code': '14302480',
#    'name': 'TRASK RIVER ABOVE CEDAR CREEK, NEAR TILLAMOOK, OR',
#    'lon': -123.7103974,
#    'lat': 45.4462181},
#   {'site_code': '443855106051201',
#    'name': 'WILD HORSE CR TRIB, 0.2 MI AB MOUTH, NR ARVADA, WY',
#    'lon': -106.0881944,
#    'lat': 44.6489722},
#   {'site_code': '01362380',
#    'name': 'STONY CLOVE CREEK NEAR PHOENICIA NY',
#    'lon': -74.31709199,
#    'lat': 42.09814568},
#   {'site_code': '411005096281502',
#    'name': ' 14N  8E24ACD 2  MEAD',
#    'lon': -96.4697424,
#    'lat': 41.16972247},
#   {'site_code': '430243076180401',
#    'name': 'Local number, Od-1825, Camillus NY',
#    'lon': -76.300763,
#    'lat': 43.0453441},
#   {'site_code': '06290000',
# ...
#    'lat': 38.98331575},
#   {'site_code': '0423406130',
#    'name': 'SENECA RIVER AT FREE BRIDGE CORNERS NY',
#    'lon': -76.7368961,
#    'lat': 42.96292674},
#   {'site_code': '360246114443020',
#    'name': 'BOULDER BASIN MONITORING STATION (96 METER DEPTH)',
#    'lon': -114.7416667,
#    'lat': 36.0461111},
#   {'site_code': '05482315',
#    'name': 'Black Hawk Lake at Lake View, IA',
#    'lon': -95.0419348,
#    'lat': 42.30414995},
#   {'site_code': '10251290',
#    'name': 'BOREHOLE SPG CHANNEL NR TECOPA HOT SPGS, CA',
#    'lon': -116.23425,
#    'lat': 35.88569444},
#   {'site_code': '02153551',
#    'name': 'BROAD RIVER BELOW NINETYNINE ISLAND RESERVOIR,SC',
#    'lon': -81.492591,
#    'lat': 35.0312419},
#   {'site_code': '05590000',
#    'name': 'KASKASKIA DITCH AT BONDVILLE, IL',
#    'lon': -88.3486654,
#    'lat': 40.1130876},
#   {'site_code': '12314000',
#    'name': 'KOOTENAI R AT KLOCKMANN RANCH NR BONNERS FERRY ID',
#    'lon': -116.381871,
#    'lat': 48.79382868},
#   {'site_code': '03209410',
#    'name': 'RUSSELL FORK AT CEDARVILLE, KY',
#    'lon': -82.3595549,
#    'lat': 37.31295507},
#   {'site_code': '03375800',
#    'name': 'HALL CREEK NEAR ST. ANTHONY, IND.',
#    'lon': -86.8286055,
#    'lat': 38.3625546},
#   {'site_code': '07377000',
#    'name': 'Amite River near Darlington, LA',
#    'lon': -90.8445454,
#    'lat': 30.8890694},
#   {'site_code': '03350800',
#    'name': 'WHITE RIVER AT 146TH ST NEAR NOBLESVILLE, IN',
#    'lon': -86.0224847,
#    'lat': 40.00031388},
#   {'site_code': '412020079133901',
#    'name': 'CR     3  Clarion County Observation Well',
#    'lon': -79.2255278,
#    'lat': 41.33677778},
#   {'site_code': '02208485',
#    'name': 'CORNISH CREEK AT LOWER JERSEY RD, NR COVINGTON, GA',
#    'lon': -83.8111111,
#    'lat': 33.7108333},
#   {'site_code': '11458500',
#    'name': 'SONOMA C A AGUA CALIENTE CA',
#    'lon': -122.4944258,
#    'lat': 38.32324705},
#   {'site_code': '05529500',
#    'name': 'MC DONALD CREEK NEAR MOUNT PROSPECT, IL',
#    'lon': -87.9128462,
#    'lat': 42.09530499},
#   {'site_code': '01413088',
#    'name': 'EAST BRANCH DELAWARE RIVER AT ROXBURY NY',
#    'lon': -74.5591944,
#    'lat': 42.29380556},
#   {'site_code': '15238984',
#    'name': 'SF BATTLE C NR HOMER AK',
#    'lon': -150.9560085,
#    'lat': 59.7521805},
#   {'site_code': '09089500',
#    'name': 'WEST DIVIDE CREEK NEAR RAVEN, CO',
#    'lon': -107.5800562,
#    'lat': 39.33109185},
#   {'site_code': '08025350',
#    'name': 'Toledo Bd Res nr Burkeville, TX',
#    'lon': -93.5721192,
#    'lat': 31.1962984},
#   {'site_code': '03292494',
#    'name': 'OHIO RIVER AT WATER TOWER AT LOUISVILLE, KY',
#    'lon': -85.7021843,
#    'lat': 38.2811812},
#   {'site_code': '02306950',
#    'name': 'BRUSHY CREEK NEAR CITRUS PARK FL',
#    'lon': -82.5553744,
#    'lat': 28.06501684},
#   {'site_code': '06647500',
#    'name': 'BOX ELDER CREEK AT BOXELDER, WY',
#    'lon': -105.8596711,
#    'lat': 42.61193835},
#   {'site_code': '10351650',
#    'name': 'TRUCKEE RV AT WADSWORTH, NV',
#    'lon': -119.2832254,
#    'lat': 39.63213447},
#   {'site_code': '06472000',
#    'name': 'JAMES R NEAR STRATFORD,SD',
#    'lon': -98.3914819,
#    'lat': 45.24163936},
#   {'site_code': '16405100',
#    'name': 'Molokai Tunnel at East Portal, Molokai, HI',
#    'lon': -156.9182979,
#    'lat': 21.14070369},
#   {'site_code': '351228106261130',
#    'name': 'SANDIA MTNS UPPER PRECIP SITE (SITE 1)',
#    'lon': -106.4363889,
#    'lat': 35.20777778},
#   {'site_code': '380117102023801',
#    'name': '23S 43W 28CBB 01  CO-KS STATELINE, 0.5 MI S, ARK R',
#    'lon': -102.0439444,
#    'lat': 38.02141667},
#   {'site_code': '271832082064801',
#    'name': 'EDGEVILLE DEEP WELL 3 AT EDGEVILLE FL',
#    'lon': -82.1133056,
#    'lat': 27.30933333},
#   {'site_code': '02080500',
#    'name': 'ROANOKE RIVER AT ROANOKE RAPIDS, NC',
#    'lon': -77.6336111,
#    'lat': 36.46},
#   {'site_code': '12150400',
#    'name': 'SNOQUALMIE RIVER AT DUVALL, WA',
#    'lon': -121.9879004,
#    'lat': 47.74315509},
#   {'site_code': '07194500',
#    'name': 'Arkansas River near Muskogee, OK',
#    'lon': -95.2971867,
#    'lat': 35.7695432},
#   {'site_code': '10170250',
#    'name': 'MILL CREEK @ JORDAN RIVER NR SALT LAKE CITY, UT',
#    'lon': -111.9199366,
#    'lat': 40.70855767},
#   {'site_code': '02322700',
#    'name': 'ICHETUCKNEE R @ HWY27 NR HILDRETH, FL',
#    'lon': -82.7859573,
#    'lat': 29.95273288},
#   {'site_code': '08029500',
#    'name': 'Big Cow Ck nr Newton, TX',
#    'lon': -93.7855556,
#    'lat': 30.81888889},
#   {'site_code': '04201506',
#    'name': 'Abram Creek at Middleburg Heights OH',
#    'lon': -81.81888889,
#    'lat': 41.36277778},
#   {'site_code': '06930015',
#    'name': 'McCourtney Hollow Trib at FLW(Outfall 13)',
#    'lon': -92.1033333,
#    'lat': 37.68916667},
#   {'site_code': '11261500',
#    'name': 'SAN JOAQUIN R A FREMONT FORD BRIDGE CA',
#    'lon': -120.9310369,
#    'lat': 37.3099386},
#   {'site_code': '350358106391303',
#    'name': '08N.02E.01.243C I-25 ED',
#    'lon': -106.6754306,
#    'lat': 34.9513611},
#   {'site_code': '405137099085201',
#    'name': '10N 16W 5DC  1  RIVERDALE DEEP',
#    'lon': -99.1530389,
#    'lat': 40.85825},
#   {'site_code': '360901114321046',
#    'name': 'LAKE MEAD VIRGIN BASIN QW PLATFORM 46 METER DEPTH',
#    'lon': -114.5361389,
#    'lat': 36.15016667},
#   {'site_code': '11517500',
#    'name': 'SHASTA R NR YREKA CA',
#    'lon': -122.5955813,
#    'lat': 41.8229179},
#   {'site_code': '474921093144001',
#    'name': 'WLN01     062N23W26CDCDAB01 Togo        0000612778',
#    'lon': -93.2440694,
#    'lat': 47.82246667},
#   {'site_code': '02107544',
#    'name': 'BLACK RIVER NEAR CURRIE, NC',
#    'lon': -78.1436111,
#    'lat': 34.43166667},
#   {'site_code': '414010091210201',
#    'name': 'Raingage at Hoover Nat Hist Site, West Branch, IA',
#    'lon': -91.3506389,
#    'lat': 41.6695833},
#   {'site_code': '422745073112001',
#    'name': 'MA-PTW   51 PITTSFIELD, MA',
#    'lon': -73.1884366,
#    'lat': 42.46258478},
#   {'site_code': '08143500',
#    'name': 'Pecan Bayou at Brownwood, TX',
#    'lon': -98.9754889,
#    'lat': 31.7364},
#   {'site_code': '05399550',
#    'name': 'FENWOOD CREEK AT BRADLEY, WI',
#    'lon': -89.9733333,
#    'lat': 44.80055556},
#   {'site_code': '06466500',
#    'name': 'Bazile Creek near Niobrara, Nebr.',
#    'lon': -97.9225,
#    'lat': 42.7322222},
#   {'site_code': '14070615',
#    'name': 'M F TUMALO CREEK ABV PROWELL SPRINGS, NR BEND, OR',
#    'lon': -121.6327694,
#    'lat': 44.03711389},
#   {'site_code': '03433637',
#    'name': 'SOUTH HARPETH CREEK NEAR PEWITT CHAPEL',
#    'lon': -87.13084,
#    'lat': 35.91173135},
#   {'site_code': '09086470',
#    'name': 'MAIN ELK CREEK NEAR NEW CASTLE, CO.',
#    'lon': -107.5731137,
#    'lat': 39.6780363},
#   {'site_code': '06935997',
#    'name': 'Mill Creek near Florissant, MO',
#    'lon': -90.2860833,
#    'lat': 38.8484722},
#   {'site_code': '350527082420000',
#    'name': 'USGS RAINGAGE AT SLICKING MTN NR ROCKY BOTTOM,SC',
#    'lon': -82.7,
#    'lat': 35.0908333},
#   {'site_code': '14165500',
#    'name': 'MCKENZIE RIVER NEAR COBURG, OR',
#    'lon': -123.0469722,
#    'lat': 44.11305556},
#   {'site_code': '01115183',
#    'name': 'QUONAPAUG BK AT RT 116 NR NORTH SCITUATE, RI',
#    'lon': -71.5847857,
#    'lat': 41.79759966},
#   {'site_code': '374004122092001',
#    'name': '003S003W14K015M',
#    'lon': -122.1556667,
#    'lat': 37.66788889},
#   {'site_code': '402120081134200',
#    'name': 'Weather Station at Tappan Lake OH',
#    'lon': -81.2282222,
#    'lat': 40.35566667},
#   {'site_code': '365204105365501',
#    'name': '30N.12E.01.1414',
#    'lon': -105.6152972,
#    'lat': 36.86780278},
#   {'site_code': '10350000',
#    'name': 'TRUCKEE RV AT VISTA, NV',
#    'lon': -119.7010198,
#    'lat': 39.5204672},
#   {'site_code': '09481000',
#    'name': 'NOGALES WASH AT NOGALES, AZ',
#    'lon': -110.9316722,
#    'lat': 31.3432722},
#   {'site_code': '09359010',
#    'name': 'MINERAL CREEK AT SILVERTON, CO',
#    'lon': -107.6728392,
#    'lat': 37.8027744},
#   {'site_code': '450628097060800',
#    'name': 'PRECIP NEAR SOUTH SHORE, SD',
#    'lon': -97.102576,
#    'lat': 45.1077412},
#   {'site_code': '04202000',
#    'name': 'Cuyahoga River at Hiram Rapids OH',
#    'lon': -81.1667664,
#    'lat': 41.3406103},
#   {'site_code': '11062399',
#    'name': 'FONTANA WATER CO SURFACE DIV WEIR 2 NR FONTANA CA',
#    'lon': -117.4494936,
#    'lat': 34.20278567},
#   {'site_code': '03230700',
#    'name': 'Scioto River at Circleville OH',
#    'lon': -82.9551804,
#    'lat': 39.60145128},
#   {'site_code': '02172080',
#    'name': 'ASHLEY R NR SUMMERVILLE S C',
#    'lon': -80.2528745,
#    'lat': 32.9685046},
#   {'site_code': '413612087200901',
#    'name': 'CITY HALL NORTHEAST FLUME AT GARY, IN',
#    'lon': -87.3358333,
#    'lat': 41.6033333},
#   {'site_code': '02171700',
#    'name': 'SANTEE RIVER NR JAMESTOWN, SC',
#    'lon': -79.6781263,
#    'lat': 33.3048893},
#   {'site_code': '03360600',
#    'name': 'SMOTHERS CREEK NR PLAINVILLE, IN',
#    'lon': -87.1300833,
#    'lat': 38.812},
#   {'site_code': '11451300',
#    'name': 'NF CACHE C NR CLEARLAKE OAKS CA',
#    'lon': -122.5341477,
#    'lat': 39.07544877},
#   {'site_code': '02231600',
#    'name': 'JANE GREEN CREEK NEAR DEER PARK, FL',
#    'lon': -80.8881155,
#    'lat': 28.074462},
#   {'site_code': '05461390',
#    'name': 'Flood Creek near Powersville, IA',
#    'lon': -92.7207472,
#    'lat': 42.90719618},
#   {'site_code': '01613095',
#    'name': 'TONOLOWAY CREEK NEAR HANCOCK, MD',
#    'lon': -78.15275,
#    'lat': 39.7063611},
#   {'site_code': '09415558',
#    'name': 'HOT CK NR SUNNYSIDE, NV',
#    'lon': -115.1516667,
#    'lat': 38.37944444},
#   {'site_code': '09383500',
#    'name': 'NUTRIOSO CREEK ABV NELSON RES NR SPRINGERVILLE, AZ',
#    'lon': -109.1864707,
#    'lat': 34.03032717},
#   {'site_code': '06438000',
#    'name': ' BELLE FOURCHE RIVER NEAR ELM SPRINGS,SD',
#    'lon': -102.5665256,
#    'lat': 44.369989},
#   {'site_code': '01387450',
#    'name': 'Mahwah River near Suffern NY',
#    'lon': -74.1161111,
#    'lat': 41.1411111},
#   {'site_code': '03114000',
#    'name': 'Captina Creek at Armstrongs Mills OH',
#    'lon': -80.92398369,
#    'lat': 39.90868407},
#   {'site_code': '420710077052101',
#    'name': 'Local number, Sb-446, near Corning NY',
#    'lon': -77.0890556,
#    'lat': 42.11955556},
#   {'site_code': '04290335',
#    'name': 'ALLEN BROOK AT VT 2A, NEAR ESSEX JUNCTION, VT',
#    'lon': -73.1126264,
#    'lat': 44.46171705},
#   {'site_code': '414659087411901',
#    'name': 'SEWER AT MORRILL SCHOOL AT CHICAGO, IL',
#    'lon': -87.6886111,
#    'lat': 41.78305556},
#   {'site_code': '370907093144101',
#    'name': 'Springfield-Valley Park',
#    'lon': -93.2446111,
#    'lat': 37.15188889},
#   {'site_code': '02196000',
#    'name': 'STEVENS CREEK NEAR MODOC, SC',
#    'lon': -82.1817873,
#    'lat': 33.72929717},
#   {'site_code': '323659117033302',
#    'name': '018S002W11P002S',
#    'lon': -117.059411,
#    'lat': 32.6165972},
#   {'site_code': '06662000',
#    'name': ' LARAMIE RIVER NEAR LOOKOUT, WYO.',
#    'lon': -105.6883288,
#    'lat': 41.762193},
#   {'site_code': '02043120',
#    'name': 'ALBEMARLE&CHESAPEAKE CNL NR PRINCESS ANNE, VA AC1',
#    'lon': -76.100211,
#    'lat': 36.71792779},
#   {'site_code': '03322190',
#    'name': 'OHIO RIVER AT HENDERSON, KY',
#    'lon': -87.5922359,
#    'lat': 37.84559817},
#   {'site_code': '370624092244701',
#    'name': 'Norwood Well',
#    'lon': -92.4131667,
#    'lat': 37.1066111},
#   {'site_code': '403734073153401',
#    'name': 'FIRE ISLAND INLET AT BABYLON NY',
#    'lon': -73.2594444,
#    'lat': 40.6261111},
#   {'site_code': '352921080473245',
#    'name': 'CRN-36 RAINGAGE AT WEST FORK SUBSTATION',
#    'lon': -80.7922833,
#    'lat': 35.48941944},
#   {'site_code': '12090452',
#    'name': 'SPANAWAY CR AT SPANAWAY LK OUTLET NR SPANAWAY, WA',
#    'lon': -122.4462333,
#    'lat': 47.12232116},
#   {'site_code': '09352800',
#    'name': 'LOS PINOS R ABV VALLECITO RES NR BAYFIELD, CO',
#    'lon': -107.5133893,
#    'lat': 37.4147242},
#   {'site_code': '03574768',
#    'name': 'FLINT RIVER AT OSCAR PATTERSON RD, AL',
#    'lon': -86.48054629,
#    'lat': 34.88064458},
#   {'site_code': '11164500',
#    'name': 'SAN FRANCISQUITO C A STANFORD UNIVERSITY CA',
#    'lon': -122.1894095,
#    'lat': 37.42327257},
#   {'site_code': '01464750',
#    'name': 'Neshaminy Creek near Rushland, PA',
#    'lon': -75.0348915,
#    'lat': 40.26038549},
#   {'site_code': '12175500',
#    'name': 'THUNDER CREEK NEAR NEWHALEM, WA',
#    'lon': -121.0728964,
#    'lat': 48.6726287},
#   {'site_code': '02197310',
#    'name': 'UPPER THREE RUNS ABOVE ROAD C (SRS), SC',
#    'lon': -81.6942783,
#    'lat': 33.28570125},
#   {'site_code': '10322500',
#    'name': 'HUMBOLDT RV AT PALISADE, NV',
#    'lon': -116.2017444,
#    'lat': 40.60741747},
#   {'site_code': '02344673',
#    'name': 'FLAT CREEK (DS OF LAKE) AT PEACHTREE CITY, GA',
#    'lon': -84.5727066,
#    'lat': 33.38317219},
#   {'site_code': '03073751',
#    'name': 'Monongahela R @ Maxwell L&D (lower pool) @ Maxwell',
#    'lon': -79.9589417,
#    'lat': 39.9974111},
#   {'site_code': '02259100',
#    'name': 'INDIAN PRAIRIE CANAL ABOVE S-72 NR OKEECHOBEE, FL',
#    'lon': -81.0091722,
#    'lat': 27.0964472},
#   {'site_code': '02301988',
#    'name': 'HILLSBOROUGH RIVER AT HWY 39 NR CRYSTAL SPRINGS FL',
#    'lon': -82.16508419,
#    'lat': 28.19334443},
#   {'site_code': '02393419',
#    'name': 'ALLATOONA CREEK AT STILESBORO RD, NEAR ACWORTH, GA',
#    'lon': -84.6930556,
#    'lat': 33.99527778},
#   {'site_code': '422704088385301',
#    'name': '46N5E-21.1d1 (1-CHE-S)',
#    'lon': -88.6480556,
#    'lat': 42.4511111},
#   {'site_code': '03500000',
#    'name': 'LITTLE TENNESSEE RIVER NEAR PRENTISS, NC',
#    'lon': -83.3797222,
#    'lat': 35.15},
#   {'site_code': '02043269',
#    'name': 'NORTH LANDING RIVER AT MARINA NEAR CREEDS, VA',
#    'lon': -76.0463333,
#    'lat': 36.61816667},
#   {'site_code': '05595200',
#    'name': 'RICHLAND CREEK NEAR HECKER, IL',
#    'lon': -89.9705556,
#    'lat': 38.32388889},
#   {'site_code': '11121010',
#    'name': 'JAMESON LK RELEASE WEIR A JAMESON LAKE CA',
#    'lon': -119.507902,
#    'lat': 34.4922149},
#   {'site_code': '351205106381201',
#    'name': 'T11N.R03E.09.113a (projected) aedes-t1',
#    'lon': -106.6366278,
#    'lat': 35.20125278},
#   {'site_code': '09419648',
#    'name': 'LAS VEGAS WASH ABV DETENTION BASIN NR N LAS VEGAS',
#    'lon': -115.1391714,
#    'lat': 36.30246806},
#   {'site_code': '02301793',
#    'name': 'EAST LAKE OUTFALL AT E. CHELSEA ST. NEAR TAMPA FL',
#    'lon': -82.37175969,
#    'lat': 27.985021},
#   {'site_code': '344640120274401',
#    'name': '008N034W16C001S',
#    'lon': -120.4631,
#    'lat': 34.77788889},
#   {'site_code': '05394500',
#    'name': 'PRAIRIE RIVER NEAR MERRILL, WI',
#    'lon': -89.6497222,
#    'lat': 45.2358333},
#   {'site_code': '275815082440401',
#    'name': 'PINELLAS WELL 665 NEAR CLEARWATER FL',
#    'lon': -82.7344444,
#    'lat': 27.97138889},
#   {'site_code': '02335778',
#    'name': 'CHATTAHOOCHEE R 0.25 MI US WILLEO CR, ROSWELL, GA',
#    'lon': -84.3844444,
#    'lat': 33.99638889},
#   {'site_code': '15478040',
#    'name': 'PHELAN C NR PAXSON AK',
#    'lon': -145.4680556,
#    'lat': 63.24027778},
#   {'site_code': '363337075595002',
#    'name': '63A  2',
#    'lon': -75.9972,
#    'lat': 36.5603472},
#   {'site_code': '02475050',
#    'name': 'WATERFALL BRANCH NR MCLAIN, MS',
#    'lon': -88.7572222,
#    'lat': 31.11916667},
#   {'site_code': '13352595',
#    'name': 'LAKE H G WEST FOREBAY AT LOWER MONUMENTAL DAM, WA',
#    'lon': -118.5344299,
#    'lat': 46.5626405},
#   {'site_code': '07299890',
#    'name': 'Lelia Lk Ck bl Bell Ck nr Hedley, TX',
#    'lon': -100.6965246,
#    'lat': 34.93560669},
#   {'site_code': '01568750',
#    'name': 'Stony Creek at Water Tank Trail nr Dauphin, PA',
#    'lon': -76.7802479,
#    'lat': 40.41425388},
#   {'site_code': '484548101463200',
#    'name': 'SOURIS RIVER ON HIGHWAY 5 NEAR TOLLEY, ND',
#    'lon': -101.775775,
#    'lat': 48.76351389},
#   {'site_code': '02100500',
#    'name': 'DEEP RIVER AT RAMSEUR, NC',
#    'lon': -79.6555556,
#    'lat': 35.72638889},
#   {'site_code': '06102500',
#    'name': 'Teton River bl South Fork nr Choteau MT',
#    'lon': -112.6119833,
#    'lat': 47.8830833},
#   {'site_code': '340509117172401',
#    'name': '001S004W15F006S',
#    'lon': -117.2901389,
#    'lat': 34.08573056},
#   {'site_code': '01362350',
#    'name': 'STONY CLOVE CREEK AT CHICHESTER NY',
#    'lon': -74.29,
#    'lat': 42.10555556},
#   ...],
#  'water': [],
#  'no_water': []}

# %%
len(sites_dict['unchecked'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-97743a393511> in <module>
# ----> 1 len(sites_dict['unchecked'])
#
# NameError: name 'sites_dict' is not defined

# %%
with open(filepath, 'w+') as fp:
    json.dump(sites_dict, fp)
