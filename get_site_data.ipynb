# %%
from urllib import request

import json
import os
import random

# %%
MAPBOX_ACCESS_TOKEN = os.environ['MAPBOX_ACCESS_TOKEN']

STATE_CODES = ['AL', 'AK', 'AZ', 'AR', 'CA', 'CO', 'CT', 'DC', 'DE', 'FL', 'GA', 
               'HI', 'ID', 'IL', 'IN', 'IA', 'KS', 'KY', 'LA', 'ME', 'MD', 
               'MA', 'MI', 'MN', 'MS', 'MO', 'MT', 'NE', 'NV', 'NH', 'NJ', 
               'NM', 'NY', 'NC', 'ND', 'OH', 'OK', 'OR', 'PA', 'RI', 'SC', 
               'SD', 'TN', 'TX', 'UT', 'VT', 'VA', 'WA', 'WV', 'WI', 'WY']

filepath = 'sites.json'

# %%
sites_dict = {
    'unchecked': [],
    'water': [],
    'no_water': []   
}

# %%
def get_sites_for_state(state_code):
    url = 'http://waterservices.usgs.gov/nwis/iv/?format=json&stateCd={}'.format(state_code)
    response = request.urlopen(url)
    sites = json.loads(response.read())['value']['timeSeries']

    return sites


def parse_site_data(site):
    site_info = site['sourceInfo']
    site_code = site_info['siteCode'][0]['value']
    site_geo_info = site_info['geoLocation']['geogLocation']

    name = site_info['siteName']
    lon = site_geo_info['longitude']
    lat = site_geo_info['latitude']

    return site_code, name, lon, lat

# %%
total_sites = 0
unique_sites = set()

for state_code in STATE_CODES:
    sites = get_sites_for_state(state_code)
    num_sites_for_state = 0

    for site in sites:
        site_code, name, lon, lat = parse_site_data(site)
        
        if site_code in unique_sites:
            continue

        unique_sites.add(site_code)
        num_sites_for_state += 1

        sites_dict['unchecked'].append({
            'site_code': site_code,
            'name': name,
            'lon': lon,
            'lat': lat
        })

    total_sites += num_sites_for_state
    print('Data recorded for {} {} sites.'.format(num_sites_for_state, state_code))

print('{} total sites.'.format(total_sites))
# Out:
# Data recorded for 224 AL sites.
# Data recorded for 269 AK sites.
# Data recorded for 425 AZ sites.
# Data recorded for 329 AR sites.
# Data recorded for 1154 CA sites.
# Data recorded for 754 CO sites.
# Data recorded for 105 CT sites.
# Data recorded for 7 DC sites.
# Data recorded for 64 DE sites.
# Data recorded for 1300 FL sites.
# Data recorded for 579 GA sites.
# Data recorded for 281 HI sites.
# Data recorded for 453 ID sites.
# Data recorded for 513 IL sites.
# Data recorded for 483 IN sites.
# Data recorded for 307 IA sites.
# Data recorded for 303 KS sites.
# Data recorded for 269 KY sites.
# Data recorded for 320 LA sites.
# Data recorded for 153 ME sites.
# Data recorded for 263 MD sites.
# Data recorded for 224 MA sites.
# Data recorded for 351 MI sites.
# Data recorded for 312 MN sites.
# Data recorded for 244 MS sites.
# Data recorded for 533 MO sites.
# Data recorded for 362 MT sites.
# Data recorded for 307 NE sites.
# Data recorded for 472 NV sites.
# Data recorded for 79 NH sites.
# Data recorded for 474 NJ sites.
# Data recorded for 734 NM sites.
# Data recorded for 659 NY sites.
# Data recorded for 623 NC sites.
# Data recorded for 186 ND sites.
# Data recorded for 549 OH sites.
# Data recorded for 312 OK sites.
# Data recorded for 579 OR sites.
# Data recorded for 539 PA sites.
# Data recorded for 58 RI sites.
# Data recorded for 374 SC sites.
# Data recorded for 255 SD sites.
# Data recorded for 283 TN sites.
# Data recorded for 953 TX sites.
# Data recorded for 319 UT sites.
# Data recorded for 77 VT sites.
# Data recorded for 559 VA sites.
# Data recorded for 539 WA sites.
# Data recorded for 194 WV sites.
# Data recorded for 525 WI sites.
# Data recorded for 265 WY sites.
# 20495 total sites.

# %%
sites_dict['unchecked'] = random.sample(sites_dict['unchecked'], len(sites_dict['unchecked']))

# %%
sites_dict
# Out:
# {'unchecked': [{'site_code': '14306900',
#    'name': 'BIG CREEK NEAR ROOSEVELT BEACH, OREG.',
#    'lon': -124.0665067,
#    'lat': 44.167899},
#   {'site_code': '15300300',
#    'name': 'ILIAMNA R NR PEDRO BAY AK',
#    'lon': -153.8468866,
#    'lat': 59.7579499},
#   {'site_code': '01407760',
#    'name': 'Jumping Brook near Neptune City NJ',
#    'lon': -74.0658333,
#    'lat': 40.2033333},
#   {'site_code': '01361000',
#    'name': 'KINDERHOOK CREEK AT ROSSMAN NY',
#    'lon': -73.7444444,
#    'lat': 42.33105556},
#   {'site_code': '02312600',
#    'name': 'WITHLACOOCHEE RIVER NEAR FLORAL CITY, FL',
#    'lon': -82.2200892,
#    'lat': 28.74359973},
#   {'site_code': '05438137',
#    'name': 'UNNAMED TR TO SB KISHWAUKEE C NR HUNTLEY, IL',
#    'lon': -88.4222222,
#    'lat': 42.195},
#   {'site_code': '02444161',
#    'name': 'TOMBIGBEE RIVER BEL BEVIL L&D NR PICKENSVILLE, AL.',
#    'lon': -88.2886454,
#    'lat': 33.21040097},
#   {'site_code': '08330830',
#    'name': 'RIO GRANDE AT VALLE DE ORO, NM',
#    'lon': -106.6865556,
#    'lat': 34.9833333},
#   {'site_code': '09395630',
#    'name': 'PUERCO RIVER NR MANUELITO, NM',
#    'lon': -108.9428665,
#    'lat': 35.46196735},
#   {'site_code': '08063590',
#    'name': 'Waxahachie Ck at Waxahachie, TX',
#    'lon': -96.8505556,
#    'lat': 32.3822222},
#   {'site_code': '02414500',
#    'name': 'TALLAPOOSA RIVER AT WADLEY AL',
#    'lon': -85.5607875,
#    'lat': 33.11678684},
#   {'site_code': '08088500',
#    'name': 'Possum Kingdom Lk nr Graford, TX',
#    'lon': -98.425886,
#    'lat': 32.87234474},
#   {'site_code': '373316077125202',
#    'name': '53J 24 SOW 234A',
#    'lon': -77.2144138,
#    'lat': 37.55463685},
#   {'site_code': '06307500',
#    'name': 'Tongue River at Tongue R Dam nr Decker MT',
#    'lon': -106.7713556,
#    'lat': 45.141275},
#   {'site_code': '411305083453111',
#    'name': 'OARDC NWARS test plot 6 subsurface drainage',
#    'lon': -83.7586111,
#    'lat': 41.21805556},
#   {'site_code': '02237700',
#    'name': 'APOPKA-BEAUCLAIR CANAL NEAR ASTATULA, FL',
#    'lon': -81.6847976,
#    'lat': 28.72249444},
#   {'site_code': '350836106395401',
#    'name': "11N.03E.31.21311A  Montano-6 973-978' screen",
#    'lon': -106.6654444,
#    'lat': 35.1429861},
#   {'site_code': '08043950',
#    'name': 'Big Sandy Ck nr Chico, TX',
#    'lon': -97.6786424,
#    'lat': 33.27428117},
#   {'site_code': '391627085534401',
#    'name': 'BARTHOLOMEW 4 (BA 4)',
#    'lon': -85.8955466,
#    'lat': 39.27421786},
#   {'site_code': '06461300',
#    'name': 'Big Beaver Cr at Nebr Hwy 12 nr Valentine, Nebr.',
#    'lon': -100.4575,
#    'lat': 42.94027778},
#   {'site_code': '400343090092101',
#    'name': 'SANGAMON RIVER NEAR CHANDLERVILLE, IL (CORPS)',
#    'lon': -90.1559523,
#    'lat': 40.0619919},
#   {'site_code': '07359000',
#    'name': 'Lake Catherine at Jones Mill, AR',
#    'lon': -92.8929778,
#    'lat': 34.42950278},
#   {'site_code': '10251259',
#    'name': 'AMARGOSA RV AT HWY 127 NR CA-NV STATE LINE',
#    'lon': -116.4236549,
#    'lat': 36.3866218},
#   {'site_code': '344520120174001',
#    'name': '008N032W19M001S',
#    'lon': -120.2946806,
#    'lat': 34.75568889},
#   {'site_code': '404014074585401',
#    'name': '190495-- NJWSA TW-B',
#    'lon': -74.98177778,
#    'lat': 40.67044444},
#   {'site_code': '05284305',
#    'name': 'SEGUCHIE CREEK AT HOLT LAKE OUTLET, NEAR GARRISON',
#    'lon': -93.8274771,
#    'lat': 46.2519038},
#   {'site_code': '10153800',
#    'name': 'NORTH FORK PROVO RIVER NEAR KAMAS, UT',
#    'lon': -111.0973947,
#    'lat': 40.59661455},
#   {'site_code': '04064500',
#    'name': 'PINE RIVER BELOW PINE R POWERPLANT NR FLORENCE, WI',
#    'lon': -88.2252778,
#    'lat': 45.8372222},
#   {'site_code': '08100500',
#    'name': 'Leon Rv at Gatesville, TX',
#    'lon': -97.7583333,
#    'lat': 31.4347222},
#   {'site_code': '07010034',
#    'name': 'Engelholm Creek at 70th Street near Pagedale',
#    'lon': -90.3033361,
#    'lat': 38.68360278},
#   {'site_code': '462023120075200',
#    'name': 'DR 2 AT YAKIMA VALLEY HIGHWAY NEAR GRANGER, WA',
#    'lon': -120.1321426,
#    'lat': 46.33947179},
#   {'site_code': '09019500',
#    'name': 'COLORADO RIVER NEAR GRANBY, CO',
#    'lon': -105.9005694,
#    'lat': 40.12081915},
#   {'site_code': '13066000',
#    'name': 'BLACKFOOT RIVER NR SHELLEY ID',
#    'lon': -112.0477778,
#    'lat': 43.26277778},
#   {'site_code': '14211901',
#    'name': 'COLD CREEK AT MOUTH AT VANCOUVER, WA',
#    'lon': -122.6675977,
#    'lat': 45.66150557},
#   {'site_code': '02341500',
#    'name': 'CHATTAHOOCHEE RIVER AT COLUMBUS, GA',
#    'lon': -84.9977096,
#    'lat': 32.4626431},
#   {'site_code': '05451900',
#    'name': 'Richland Creek near Haven, IA',
#    'lon': -92.474355,
#    'lat': 41.89943868},
#   {'site_code': '03284525',
#    'name': 'E HICKMAN CR TRIB AT CHILESBURG RD NR LEXINGTON,KY',
#    'lon': -84.4110465,
#    'lat': 37.98841157},
#   {'site_code': '320836110172301',
#    'name': 'D-15-20 10CAB2',
#    'lon': -110.2911844,
#    'lat': 32.1447997},
#   {'site_code': '04146000',
#    'name': 'FARMERS CREEK NEAR LAPEER, MI',
#    'lon': -83.33716779,
#    'lat': 43.0447494},
#   {'site_code': '04026390',
#    'name': 'BEARTRAP CREEK AT U.S. HIGHWAY 2 NEAR ASHLAND, WI',
#    'lon': -90.7602778,
#    'lat': 46.60916667},
#   {'site_code': '421209121463001',
#    'name': 'KLAMATH RIVER AT RAILROAD BRIDGE - BOTTOM',
#    'lon': -121.775,
#    'lat': 42.2025},
#   {'site_code': '03288100',
#    'name': 'NORTH ELKHORN CREEK AT GEORGETOWN, KY',
#    'lon': -84.562998,
#    'lat': 38.2195187},
#   {'site_code': '414139070311501',
#    'name': 'MA-SDW  526-0040 (MW-145S)',
#    'lon': -70.5204421,
#    'lat': 41.6943657},
#   {'site_code': '02411600',
#    'name': 'COOSA RIVER AT WETUMPKA AL',
#    'lon': -86.208857,
#    'lat': 32.53707835},
#   {'site_code': '04208684',
#    'name': 'East Branch Euclid Creek at Richmond Heights OH',
#    'lon': -81.4947222,
#    'lat': 41.57416667},
#   {'site_code': '02203900',
#    'name': 'SOUTH RIVER AT FLAKES MILL ROAD NR ATLANTA, GA',
#    'lon': -84.2246426,
#    'lat': 33.66621924},
#   {'site_code': '352907090032801',
#    'name': '10N10E18DAC1 MI-18 WU',
#    'lon': -90.0577778,
#    'lat': 35.48527778},
#   {'site_code': '260958081135700',
#    'name': 'I-75 CULVERT AT MILE 72.9 NEAR NAPLES, FL',
#    'lon': -81.2324194,
#    'lat': 26.16603889},
#   {'site_code': '02277600',
#    'name': 'LOXAHATCHEE RIVER NEAR JUPITER,FL',
#    'lon': -80.1750444,
#    'lat': 26.93922405},
#   {'site_code': '07377150',
#    'name': 'Amite River at Grangeville, LA',
#    'lon': -90.84176699,
#    'lat': 30.73629484},
#   {'site_code': '07345900',
#    'name': "Lk O' the Pines nr Jefferson, TX",
#    'lon': -94.4993658,
#    'lat': 32.7551388},
#   {'site_code': '10251335',
#    'name': 'WILLOW CK AT CHINA RANCH, CA',
#    'lon': -116.1944167,
#    'lat': 35.80094444},
#   {'site_code': '06468250',
#    'name': 'JAMES RIVER ABOVE ARROWWOOD LAKE NR KENSAL, ND',
#    'lon': -98.7976057,
#    'lat': 47.3997189},
#   {'site_code': '04176000',
#    'name': 'RIVER RAISIN NEAR ADRIAN, MI',
#    'lon': -83.98077629,
#    'lat': 41.9047691},
#   {'site_code': '01376269',
#    'name': 'HUDSON RIVER AT PIERMONT NY',
#    'lon': -73.8960556,
#    'lat': 41.04319444},
#   {'site_code': '05544385',
#    'name': 'MUSKEGO (BIG MUSKEGO) LAKE OUTLET NR WIND LAKE, WI',
#    'lon': -88.1306438,
#    'lat': 42.8525157},
#   {'site_code': '464222092403801',
#    'name': 'FDLGWSW02 049N18W30BBDA  01 RicePortage 0000685831',
#    'lon': -92.6770833,
#    'lat': 46.7061111},
#   {'site_code': '02089192',
#    'name': 'NEUSE R AT WHITEHALL, NC',
#    'lon': -77.84638889,
#    'lat': 35.2297222},
#   {'site_code': '06894650',
#    'name': 'Missouri River at Napoleon, MO',
#    'lon': -94.0632786,
#    'lat': 39.13750825},
#   {'site_code': '03255420',
#    'name': 'Mill Creek at Evendale OH',
#    'lon': -84.4257749,
#    'lat': 39.2545024},
#   {'site_code': '09330230',
#    'name': 'FREMONT RIVER NEAR CAINEVILLE, UT',
#    'lon': -111.0657201,
#    'lat': 38.2791469},
#   {'site_code': '274240082212702',
#    'name': 'ROMP 50 NRSD WELL NEAR WIMAUMA FL',
#    'lon': -82.3571111,
#    'lat': 27.71163889},
#   {'site_code': '06877600',
#    'name': 'SMOKY HILL R AT ENTERPRISE, KS',
#    'lon': -97.1177952,
#    'lat': 38.90638906},
#   {'site_code': '06934500',
#    'name': 'Missouri River at Hermann, MO',
#    'lon': -91.4385,
#    'lat': 38.70980556},
#   {'site_code': '06479010',
#    'name': 'VERMILLION RIVER NR VERMILLION,SD',
#    'lon': -96.9242106,
#    'lat': 42.8172187},
#   {'site_code': '441748088133704',
#    'name': 'TRT WETLAND ONE OUTLET NR KAUKAUNA, WI',
#    'lon': -88.2269444,
#    'lat': 44.29666667},
#   {'site_code': '354048119445002',
#    'name': '026S021E07J002M',
#    'lon': -119.7474306,
#    'lat': 35.6801611},
#   {'site_code': '01484683',
#    'name': 'INDIAN RIVER BAY INLET NEAR BETHANY BEACH, DE',
#    'lon': -75.068,
#    'lat': 38.6098333},
#   {'site_code': '09081000',
#    'name': 'ROARING FORK RIVER NEAR EMMA, CO',
#    'lon': -107.0839367,
#    'lat': 39.37331729},
#   {'site_code': '370000089094501',
#    'name': 'OHIO RIVER AT CAIRO, IL (CORPS)',
#    'lon': -89.1625713,
#    'lat': 37.0000517},
#   {'site_code': '03197950',
#    'name': 'ELK RIVER AT CHARLESTON, WV',
#    'lon': -81.627068,
#    'lat': 38.3581527},
#   {'site_code': '01605500',
#    'name': 'SOUTH BRANCH POTOMAC RIVER AT FRANKLIN, WV',
#    'lon': -79.3378199,
#    'lat': 38.63567247},
#   {'site_code': '0359816545',
#    'name': 'PARCH CORN CREEK AT MARTIN ROAD NR ELBETHEL, TN',
#    'lon': -86.4855491,
#    'lat': 35.56173718},
#   {'site_code': '07194500',
#    'name': 'Arkansas River near Muskogee, OK',
#    'lon': -95.2971867,
#    'lat': 35.7695432},
#   {'site_code': '07061600',
#    'name': 'Black River below Annapolis, MO',
#    'lon': -90.7640093,
#    'lat': 37.32504888},
#   {'site_code': '0208700780',
#    'name': 'LITTLE LICK CR AB SR1814 NR OAK GROVE, NC',
#    'lon': -78.7991726,
#    'lat': 35.9865346},
#   {'site_code': '412743081375800',
#    'name': 'CU-39',
#    'lon': -81.6328278,
#    'lat': 41.46196389},
#   {'site_code': '445322088281801',
#    'name': 'BERRY LAKE NEAR SHAWANO, WI',
#    'lon': -88.4722222,
#    'lat': 44.8875},
#   {'site_code': '0212430293',
#    'name': 'REEDY CREEK BELOW I-485 NR PINE RIDGE, NC',
#    'lon': -80.6627778,
#    'lat': 35.2586111},
#   {'site_code': '10092700',
#    'name': 'BEAR RIVER AT IDAHO-UTAH STATE LINE',
#    'lon': -111.92134,
#    'lat': 42.0129808},
#   {'site_code': '07331455',
#    'name': 'Lake Texoma at Cumberland Cut nr Cumberland, Ok',
#    'lon': -96.5532694,
#    'lat': 34.09691389},
#   {'site_code': '03363900',
#    'name': 'FLATROCK RIVER AT COLUMBUS, IN',
#    'lon': -85.9266597,
#    'lat': 39.2350514},
#   {'site_code': '352936076125245',
#    'name': 'RAINGAGE AT LK MATTAMUSKEET HWY 94 NR FAIRFIELD NC',
#    'lon': -76.21455278,
#    'lat': 35.4932361},
#   {'site_code': '02484000',
#    'name': 'YOCKANOOKANY RIVER NR KOSCIUSKO, MS',
#    'lon': -89.5777778,
#    'lat': 33.0322222},
#   {'site_code': '12413355',
#    'name': 'SF COEUR D ALENE RIVER ABV PINE CR NR PINEHURST ID',
#    'lon': -116.2197222,
#    'lat': 47.5483333},
#   {'site_code': '08072600',
#    'name': 'Buffalo Bayou at State Hwy 6 nr Addicks, TX',
#    'lon': -95.6431667,
#    'lat': 29.76938056},
#   {'site_code': '384704080131501',
#    'name': 'ALEXANDER RAIN',
#    'lon': -80.2206346,
#    'lat': 38.78454825},
#   {'site_code': '09427520',
#    'name': 'COLORADO RIVER BELOW PARKER DAM, AZ-CA',
#    'lon': -114.140225,
#    'lat': 34.29557035},
#   {'site_code': '02326000',
#    'name': 'ECONFINA RIVER NEAR PERRY, FLA.',
#    'lon': -83.8237679,
#    'lat': 30.17076448},
#   {'site_code': '372156076431702',
#    'name': '57G129 SOW 240A',
#    'lon': -76.720908,
#    'lat': 37.36562074},
#   {'site_code': '313312110082302',
#    'name': 'D-22-22 06AAA6 [LSP-1]',
#    'lon': -110.1403562,
#    'lat': 31.5534288},
#   {'site_code': '05401063',
#    'name': 'LAKE HURON NEAR PLAINFIELD, WI',
#    'lon': -89.4174722,
#    'lat': 44.19563889},
#   {'site_code': '401753074483501',
#    'name': '210289-- Bristol-Myers 100 Obs',
#    'lon': -74.80932958,
#    'lat': 40.29816305},
#   {'site_code': '03325311',
#    'name': 'LITTLE MISSISSINEWA RIVER AT UNION CITY, IN',
#    'lon': -84.8291291,
#    'lat': 40.1961575},
#   {'site_code': '411922085221801',
#    'name': 'NOBLE 8 (NO 8)',
#    'lon': -85.3720833,
#    'lat': 41.32266667},
#   {'site_code': '350554106283230',
#    'name': 'EMBUDO CANYON RAIN GAGE AT ALBUQUERQUE, NM',
#    'lon': -106.476134,
#    'lat': 35.09838},
#   {'site_code': '385548104503201',
#    'name': 'FOOTHILLS MET STA AT FOOTHILLS ELEM AT CO SPGS, CO',
#    'lon': -104.8422222,
#    'lat': 38.93},
#   {'site_code': '02160990',
#    'name': 'PARR SHOALS RESERVOIR AT PARR, SC',
#    'lon': -81.3317636,
#    'lat': 34.26125835},
#   {'site_code': '12158040',
#    'name': 'TULALIP CREEK NEAR TULALIP, WA',
#    'lon': -122.2879204,
#    'lat': 48.0684294},
#   {'site_code': '03572110',
#    'name': 'CROW CREEK AT BASS',
#    'lon': -85.9174783,
#    'lat': 34.93424968},
#   {'site_code': '03373610',
#    'name': 'LICK CREEK AT PAOLI, IN',
#    'lon': -86.4758333,
#    'lat': 38.5558333},
#   {'site_code': '02083800',
#    'name': 'CONETOE CREEK NEAR BETHEL, NC',
#    'lon': -77.4621915,
#    'lat': 35.77599167},
#   {'site_code': '05284000',
#    'name': 'MILLE LACS LAKE AT COVE BAY NEAR ONAMIA, MN',
#    'lon': -93.6191325,
#    'lat': 46.1099581},
#   {'site_code': '411925089063901',
#    'name': 'ILLINOIS RIVER NEAR LA SALLE, IL (CORPS)',
#    'lon': -89.1109168,
#    'lat': 41.3236459},
#   {'site_code': '02319800',
#    'name': 'SUWANNEE RIVER AT DOWLING PARK, FLORIDA',
#    'lon': -83.24958439,
#    'lat': 30.2449425},
#   {'site_code': '340615117170904',
#    'name': '001S004W10B004S',
#    'lon': -117.28645,
#    'lat': 34.10414167},
#   {'site_code': '06482000',
#    'name': 'BIG SIOUX R AT SIOUX FALLS SD',
#    'lon': -96.748384,
#    'lat': 43.5010864},
#   {'site_code': '14335040',
#    'name': 'LOST CREEK LAKE NEAR MCLEOD, OR',
#    'lon': -122.674762,
#    'lat': 42.6709595},
#   {'site_code': '07381454',
#    'name': 'Belle River at Hwy 70 near Pierre Part, LA',
#    'lon': -91.2158333,
#    'lat': 29.9091111},
#   {'site_code': '08083430',
#    'name': 'Elm Ck at Abilene, TX',
#    'lon': -99.7410278,
#    'lat': 32.50730556},
#   {'site_code': '310902081284301',
#    'name': '34H445',
#    'lon': -81.4784056,
#    'lat': 31.15089738},
#   {'site_code': '11045700',
#    'name': 'ONEILL LK SPILL CH NR FALLBROOK CA',
#    'lon': -117.3272599,
#    'lat': 33.32892087},
#   {'site_code': '411738097264301',
#    'name': ' 15N  1W 9BBBB1 SHELBY',
#    'lon': -97.4451667,
#    'lat': 41.29377778},
#   {'site_code': '415439093094801',
#    'name': '082N20W15DBC        2008IACRN-5',
#    'lon': -93.1633333,
#    'lat': 41.9108333},
#   {'site_code': '01483670',
#    'name': 'MUDSTONE BRANCH AT CHESTNUT GROVE, DE',
#    'lon': -75.5815927,
#    'lat': 39.1770566},
#   {'site_code': '07295000',
#    'name': 'BUFFALO RIVER NR WOODVILLE, MS',
#    'lon': -91.2955556,
#    'lat': 31.22694444},
#   {'site_code': '02323592',
#    'name': 'SUWANNEE RIVER AB GOPHER RIVER NR SUWANNEE FL',
#    'lon': -83.086515,
#    'lat': 29.33940554},
#   {'site_code': '15302000',
#    'name': 'NUYAKUK R NR DILLINGHAM AK',
#    'lon': -158.1900062,
#    'lat': 59.93483},
#   {'site_code': '03252000',
#    'name': 'STONER CREEK AT PARIS, KY',
#    'lon': -84.2560426,
#    'lat': 38.22924295},
#   {'site_code': '03322900',
#    'name': 'WABASH RIVER AT LINN GROVE, IN',
#    'lon': -85.0327466,
#    'lat': 40.65615729},
#   {'site_code': '01671100',
#    'name': 'LITTLE RIVER NEAR DOSWELL, VA',
#    'lon': -77.5130392,
#    'lat': 37.8726401},
#   {'site_code': '09516500',
#    'name': 'HASSAYAMPA RIVER NEAR MORRISTOWN, AZ.',
#    'lon': -112.6621198,
#    'lat': 33.88503188},
#   {'site_code': '03596100',
#    'name': 'CRUMPTON CREEK AT RUTLEDGE FALLS, TN',
#    'lon': -86.1364997,
#    'lat': 35.422661},
#   {'site_code': '404019111295001',
#    'name': 'DORITY SPRING WEIR NEAR PARK CITY, UTAH',
#    'lon': -111.497974,
#    'lat': 40.67189479},
#   {'site_code': '14113000',
#    'name': 'KLICKITAT RIVER NEAR PITT, WA',
#    'lon': -121.2100714,
#    'lat': 45.75651098},
#   {'site_code': '05355235',
#    'name': 'MISSISSIPPI RIVER ABV RED WING BLW DIAMOND ISL, MN',
#    'lon': -92.5793333,
#    'lat': 44.60416667},
#   {'site_code': '381952108515101',
#    'name': 'UPPER WILDLIFE POND NR BEDROCK, CO',
#    'lon': -108.8640528,
#    'lat': 38.33121944},
#   {'site_code': '07235000',
#    'name': 'Wolf Ck at Lipscomb, TX',
#    'lon': -100.2756889,
#    'lat': 36.23864885},
#   {'site_code': '435950087572701',
#    'name': 'DISCOVERY FARMS TILE NEAR SAINT NAZIANZ, WI',
#    'lon': -87.95738889,
#    'lat': 43.99725},
#   {'site_code': '07250000',
#    'name': 'LEE CR NR VAN BUREN ARK',
#    'lon': -94.4496592,
#    'lat': 35.49453306},
#   {'site_code': '01158000',
#    'name': 'ASHUELOT RIVER BELOW SURRY MT DAM, NEAR KEENE, NH',
#    'lon': -72.31119719,
#    'lat': 42.9948023},
#   {'site_code': '282051081183401',
#    'name': 'BOGGY CREEK ROAD WELL AT COUNTY LINE NEAR TAFT, FL',
#    'lon': -81.3092358,
#    'lat': 28.34778678},
#   {'site_code': '02306904',
#    'name': 'BRUSHY CREEK NEAR SULPHUR SPRINGS',
#    'lon': -82.525,
#    'lat': 28.0838611},
#   {'site_code': '02266495',
#    'name': 'REEDY CREEK AT S-40, NEAR LOUGHMAN, FL',
#    'lon': -81.5439622,
#    'lat': 28.27584517},
#   {'site_code': '02304500',
#    'name': 'HILLSBOROUGH RIVER NEAR TAMPA FL',
#    'lon': -82.4275939,
#    'lat': 28.02390784},
#   {'site_code': '01460880',
#    'name': 'Lockatong Creek at Raven Rock NJ',
#    'lon': -75.01777778,
#    'lat': 40.4161111},
#   {'site_code': '13047500',
#    'name': 'FALL RIVER NR SQUIRREL ID',
#    'lon': -111.2413889,
#    'lat': 44.0686111},
#   {'site_code': '410155074060201',
#    'name': '030289-- Saddle River 17 Obs',
#    'lon': -74.10014209,
#    'lat': 41.03204145},
#   {'site_code': '365258095013401',
#    'name': '28N-21E-26 ACB 1 Boone3',
#    'lon': -95.0261889,
#    'lat': 36.88283056},
#   {'site_code': '303212097373100',
#    'name': 'UBCWCID Dam 17 nr Round Rock, TX',
#    'lon': -97.6252472,
#    'lat': 30.53666389},
#   {'site_code': '07325800',
#    'name': 'Cobb Creek near Eakly, OK',
#    'lon': -98.5942308,
#    'lat': 35.2906111},
#   {'site_code': '14113200',
#    'name': 'MOSIER CREEK NEAR MOSIER, OR',
#    'lon': -121.3772951,
#    'lat': 45.649008},
#   {'site_code': '01443900',
#    'name': 'Yards Creek near Blairstown NJ',
#    'lon': -75.0391667,
#    'lat': 40.98055556},
#   {'site_code': '05551582',
#    'name': 'FOX RIVER BYPASS AT YORKVILLE, IL',
#    'lon': -88.4433333,
#    'lat': 41.64277778},
#   {'site_code': '0208734795',
#    'name': 'WALNUT CREEK AT SOUTH WILMINGTON ST AT RALEIGH, NC',
#    'lon': -78.6406111,
#    'lat': 35.75688889},
#   {'site_code': '331104092380201',
#    'name': '18S15W03DAB1 Welcome Cen',
#    'lon': -92.6339222,
#    'lat': 33.18438333},
#   {'site_code': '03325519',
#    'name': 'MISSISSINEWA RIVER AT RIDGEVILLE, IN',
#    'lon': -85.0284722,
#    'lat': 40.28305556},
#   {'site_code': '350402106392601',
#    'name': '10N.03E.30.244C BEBS',
#    'lon': -106.6575083,
#    'lat': 35.06730278},
#   {'site_code': '410943097575001',
#    'name': '14N 6W26AAAA1 CENTRAL CITY',
#    'lon': -97.9639028,
#    'lat': 41.16177778},
#   {'site_code': '02336986',
#    'name': 'OLLEY CREEK AT CLAY ROAD, NEAR AUSTELL, GA',
#    'lon': -84.6316006,
#    'lat': 33.83621638},
#   {'site_code': '14046778',
#    'name': 'BRIDGE CR ABV COYOTE CANYON NR MITCHELL, OR',
#    'lon': -120.301965,
#    'lat': 44.7267988},
#   {'site_code': '08456310',
#    'name': 'Las Moras Spgs Dws of pool at Brackettville,TX',
#    'lon': -100.4192222,
#    'lat': 29.30791667},
#   {'site_code': '13157370',
#    'name': 'ROGER YOUNG PUMPING PLANT NR BRUNEAU ID',
#    'lon': -115.7977778,
#    'lat': 42.94388889},
#   {'site_code': '254540080361500',
#    'name': 'TAMIAMI CANAL AT S-355A NEAR MIAMI, FL',
#    'lon': -80.5908644,
#    'lat': 25.76207297},
#   {'site_code': '01576754',
#    'name': 'Conestoga River at Conestoga, PA',
#    'lon': -76.3677388,
#    'lat': 39.9464886},
#   {'site_code': '02300050',
#    'name': 'WILLIAMS CREEK NEAR BRADENTON FL',
#    'lon': -82.4675954,
#    'lat': 27.4530969},
#   {'site_code': '03407908',
#    'name': 'NEW RIVER AT CORDELL, TN',
#    'lon': -84.4513288,
#    'lat': 36.3361456},
#   {'site_code': '06442996',
#    'name': 'LAKE FRANCIS CASE AT CHAMBERLAIN, SD',
#    'lon': -99.3273223,
#    'lat': 43.8161058},
#   {'site_code': '12039509',
#    'name': "QUINAULT R BLW TEN O'CLOCK CR (7A) NR NEILTON, WA",
#    'lon': -124.0346694,
#    'lat': 47.40143056},
#   {'site_code': '403541075112301',
#    'name': 'Riegelsville USGS heated rain gage NJ',
#    'lon': -75.1897222,
#    'lat': 40.5947222},
#   {'site_code': '07309500',
#    'name': 'Lake Lawtonka near Lawton, OK',
#    'lon': -98.5033913,
#    'lat': 34.7361799},
#   {'site_code': '02087580',
#    'name': 'SWIFT CREEK NEAR APEX, NC',
#    'lon': -78.7522222,
#    'lat': 35.71888889},
#   {'site_code': '09303500',
#    'name': 'SOUTH FORK WHITE RIVER NEAR BUFORD, CO.',
#    'lon': -107.5517269,
#    'lat': 39.9216455},
#   {'site_code': '343055093031301',
#    'name': 'Spring 9 @ HOSP N.P.',
#    'lon': -93.0537906,
#    'lat': 34.5153672},
#   {'site_code': '01022295',
#    'name': 'West Br Bear Brook near Beddington, Maine',
#    'lon': -68.1031694,
#    'lat': 44.858575},
#   {'site_code': '380649081083301',
#    'name': 'NEW RIVER BELOW HAWKS NEST DAM, WV',
#    'lon': -81.14232689,
#    'lat': 38.11372008},
#   {'site_code': '375723075344404',
#    'name': '66M 19 SOW 110S',
#    'lon': -75.5785377,
#    'lat': 37.9565126},
#   {'site_code': '01422389',
#    'name': 'COULTER BROOK NEAR BOVINA CENTER NY',
#    'lon': -74.7361111,
#    'lat': 42.2386111},
#   {'site_code': '205635156313901',
#    'name': 'Waihee River near alt 260 ft, Maui, HI',
#    'lon': -156.5275,
#    'lat': 20.94305556},
#   {'site_code': '01363556',
#    'name': 'ESOPUS CREEK NEAR LOMONTVILLE NY',
#    'lon': -74.1453611,
#    'lat': 41.8793333},
#   {'site_code': '212214157535401',
#    'name': 'Red Hill RHMW01, Oahu, HI',
#    'lon': -157.8983333,
#    'lat': 21.37055556},
#   {'site_code': '0208706575',
#    'name': 'BEAVERDAM CREEK AT DAM NEAR CREEDMOOR, NC',
#    'lon': -78.6891667,
#    'lat': 36.0236111},
#   {'site_code': '09530000',
#    'name': 'RESERVATION MAIN DRAIN NO. 4 NEAR YUMA, AZ',
#    'lon': -114.621897,
#    'lat': 32.73726888},
#   {'site_code': '07364122',
#    'name': 'Bayou Bartholomew nr Meroney, AR',
#    'lon': -91.7334167,
#    'lat': 33.95321944},
#   {'site_code': '11070465',
#    'name': 'SALT C A MURRIETA RD NR SUN CITY CA',
#    'lon': -117.2055903,
#    'lat': 33.6941882},
#   {'site_code': '452559122472401',
#    'name': 'SUMMER CREEK AT FOWLER MIDDLE SCHOOL, TIGARD, OR',
#    'lon': -122.7911617,
#    'lat': 45.43284038},
#   {'site_code': '01663500',
#    'name': 'HAZEL RIVER AT RIXEYVILLE, VA',
#    'lon': -77.9649962,
#    'lat': 38.59178867},
#   {'site_code': '13206000',
#    'name': 'BOISE RIVER AT GLENWOOD BRIDGE NR BOISE ID',
#    'lon': -116.2791667,
#    'lat': 43.66055556},
#   {'site_code': '313532084203501',
#    'name': '11L002',
#    'lon': -84.34213369,
#    'lat': 31.59239473},
#   {'site_code': '0205494935',
#    'name': 'ROANOKE RIV AT JEFFERSON ST BRIDGE AT ROANOKE, VA',
#    'lon': -79.9433333,
#    'lat': 37.25277778},
#   {'site_code': '12370000',
#    'name': 'Swan River near Bigfork, MT',
#    'lon': -113.9788194,
#    'lat': 48.02423056},
#   {'site_code': '11162620',
#    'name': 'PILARCITOS C BL STONE DAM NR HILLSBOROUGH CA',
#    'lon': -122.3994177,
#    'lat': 37.52466087},
#   {'site_code': '262337080074800',
#    'name': 'E-3 CA AT NW 51ST IN BOCA RATON FL',
#    'lon': -80.1296333,
#    'lat': 26.39198333},
#   {'site_code': '02238499',
#    'name': 'OCKLAWAHA R AB MOSS BLUFF DAM AT MOSS BLUFF,FL',
#    'lon': -81.8808333,
#    'lat': 29.0811111},
#   {'site_code': '450705069384801',
#    'name': 'Kingsbury Precipitation at Kingsbury, Maine',
#    'lon': -69.6466667,
#    'lat': 45.11805556},
#   {'site_code': '02431000',
#    'name': 'TOMBIGBEE RIVER NR FULTON, MS',
#    'lon': -88.4452778,
#    'lat': 34.265},
#   {'site_code': '02344500',
#    'name': 'FLINT RIVER NEAR GRIFFIN, GA',
#    'lon': -84.4291667,
#    'lat': 33.24416667},
#   {'site_code': '09032300',
#    'name': 'HURD CREEK NEAR TABERNASH, CO',
#    'lon': -105.7616944,
#    'lat': 40.01325},
#   {'site_code': '05431014',
#    'name': 'JACKSON CREEK AT PETRIE ROAD NEAR ELKHORN, WI',
#    'lon': -88.5217663,
#    'lat': 42.64140449},
#   {'site_code': '13092747',
#    'name': 'ROCK CREEK AB HWY 30/93 XING AT TWIN FALLS ID',
#    'lon': -114.4947222,
#    'lat': 42.5625},
#   {'site_code': '07047855',
#    'name': "Whiteman's Crk at Ind Dr at Jonesboro, AR",
#    'lon': -90.6422222,
#    'lat': 35.8086111},
#   {'site_code': '01049320',
#    'name': 'Kennebec River at Calumet Bridge at Augusta, Maine',
#    'lon': -69.7716667,
#    'lat': 44.3186111},
#   {'site_code': '412522100121201',
#    'name': 'T17N R25W S21CDDD1 Arnold',
#    'lon': -100.2033778,
#    'lat': 41.42277778},
#   {'site_code': '04086500',
#    'name': 'CEDAR CREEK NEAR CEDARBURG, WI',
#    'lon': -87.9786111,
#    'lat': 43.32305556},
#   {'site_code': '16509000',
#    'name': 'HANAWI STREAM BL GOVT RD NR NAHIKU, MAUI, HI',
#    'lon': -156.103585,
#    'lat': 20.81762706},
#   {'site_code': '412741090302201',
#    'name': 'ROCK RIVER AT MOLINE, IL (CORPS)',
#    'lon': -90.5062447,
#    'lat': 41.4614229},
#   {'site_code': '03323587',
#    'name': 'GRAHAM MCCULLOCH DITCH NEAR FORT WAYNE, IN',
#    'lon': -85.2555556,
#    'lat': 41.02138889},
#   {'site_code': '07055646',
#    'name': 'Buffalo River near Boxley, AR',
#    'lon': -93.405,
#    'lat': 35.93888889},
#   {'site_code': '351943080323145',
#    'name': 'RAINGAGE AT ROCKY RIVER WWTP, CONCORD, NC',
#    'lon': -80.54195,
#    'lat': 35.32872778},
#   {'site_code': '421056088380801',
#    'name': '43N5E-27.4h1 (14-RIL-S)',
#    'lon': -88.6355556,
#    'lat': 42.1822222},
#   {'site_code': '06714400',
#    'name': 'S CLEAR CR ABV LOWER CABIN CR RES NR GEORGETOWN,CO',
#    'lon': -105.7074833,
#    'lat': 39.64900556},
#   {'site_code': '350403106392302',
#    'name': '10N.03E.30.244G BEDWM',
#    'lon': -106.6566056,
#    'lat': 35.06739167},
#   {'site_code': '343523118095507',
#    'name': '006N012W20R HDP @ 135FEET',
#    'lon': -118.1653806,
#    'lat': 34.59000278},
#   {'site_code': '03145173',
#    'name': 'South Fork Licking River at Heath OH',
#    'lon': -82.4133333,
#    'lat': 40.0375},
#   {'site_code': '07243500',
#    'name': 'Deep Fork near Beggs, OK',
#    'lon': -96.0686077,
#    'lat': 35.6739876},
#   {'site_code': '09306224',
#    'name': 'WHITE RIV AB CROOKED WASH NR WHITE RIVER CITY, CO',
#    'lon': -108.345,
#    'lat': 40.1625},
#   {'site_code': '414637099224701',
#    'name': '21N 18W22DABB1Taylor',
#    'lon': -99.3797028,
#    'lat': 41.7769333},
#   {'site_code': '13338500',
#    'name': 'SF CLEARWATER RIVER AT STITES ID',
#    'lon': -115.9766667,
#    'lat': 46.08638889},
#   {'site_code': '01194815',
#    'name': 'CONNECTICUT RIVER NR BRIDGE ST NR OLD SAYBROOK, CT',
#    'lon': -72.34927778,
#    'lat': 41.2813333},
#   {'site_code': '264235081310601',
#    'name': 'HE - 557',
#    'lon': -81.5181333,
#    'lat': 26.71006784},
#   {'site_code': '02092000',
#    'name': 'SWIFT CREEK NEAR VANCEBORO, NC',
#    'lon': -77.1955108,
#    'lat': 35.34516225},
#   {'site_code': '03247040',
#    'name': 'East Fork Lake near Bantam OH',
#    'lon': -84.1521569,
#    'lat': 39.02228628},
#   {'site_code': '325736095164800',
#    'name': 'Rain Gage at Winnsboro, TX',
#    'lon': -95.28,
#    'lat': 32.96},
#   {'site_code': '05512500',
#    'name': 'BAY CREEK AT PITTSFIELD, IL',
#    'lon': -90.7940177,
#    'lat': 39.62532537},
#   {'site_code': '02299684',
#    'name': 'FORKED CREEK NEAR ENGLEWOOD FL',
#    'lon': -82.36815079,
#    'lat': 27.01005886},
#   {'site_code': '05389400',
#    'name': 'Bloody Run Creek near Marquette, IA',
#    'lon': -91.2065192,
#    'lat': 43.04081747},
#   {'site_code': '05428668',
#    'name': 'STARKWEATHER CREEK ABOVE ATWOOD AVE AT MADISON, WI',
#    'lon': -89.3331732,
#    'lat': 43.09194027},
#   {'site_code': '13335050',
#    'name': 'ASOTIN CREEK AT ASOTIN, WA',
#    'lon': -117.0559898,
#    'lat': 46.34071536},
#   {'site_code': '394348118040275',
#    'name': 'DVSV ET STA DEPTH 12 FT BLW LAND SURFACE',
#    'lon': -118.0672639,
#    'lat': 39.73010556},
#   {'site_code': '05514500',
#    'name': 'Cuivre River near Troy, MO',
#    'lon': -90.9775278,
#    'lat': 39.00880556},
#   {'site_code': '01613000',
#    'name': 'POTOMAC RIVER AT HANCOCK, MD',
#    'lon': -78.17788889,
#    'lat': 39.69755556},
#   {'site_code': '12302055',
#    'name': 'Fisher River near Libby MT',
#    'lon': -115.31465,
#    'lat': 48.35560278},
#   {'site_code': '09332600',
#    'name': 'Muddy Creek at Tomsich Butte nr Hanksville, UT',
#    'lon': -110.9995278,
#    'lat': 38.68694444},
#   {'site_code': '06923940',
#    'name': 'Niangua River ab Lake Niangua nr Macks Creek, MO',
#    'lon': -92.8980556,
#    'lat': 37.8633333},
#   {'site_code': '363143110355001',
#    'name': '02 040-05.38X15.27 [BMOB-4]',
#    'lon': -110.59903,
#    'lat': 36.52805329},
#   {'site_code': '360700114505105',
#    'name': 'LAS VEGAS BAY QW PLATFORM SITE3 9 METER DEPTH',
#    'lon': -114.848434,
#    'lat': 36.1165881},
#   {'site_code': '15266110',
#    'name': 'KENAI R BL SKILAK LK OUTLET NR STERLING AK',
#    'lon': -150.60109,
#    'lat': 60.466099},
#   {'site_code': '01446000',
#    'name': 'Beaver Brook near Belvidere NJ',
#    'lon': -75.04638889,
#    'lat': 40.8433333},
#   {'site_code': '07263300',
#    'name': 'Maumelle River at Maumelle Dam at Natural Steps,AR',
#    'lon': -92.4852778,
#    'lat': 34.86305556},
#   {'site_code': '01573482',
#    'name': 'Manada Creek at Manada Gap, PA',
#    'lon': -76.7091351,
#    'lat': 40.40675469},
#   {'site_code': '02146348',
#    'name': 'COFFEY CREEK NR CHARLOTTE, NC',
#    'lon': -80.9269444,
#    'lat': 35.1458333},
#   {'site_code': '402213104015501',
#    'name': 'SB00505930CBA NAWQA 13',
#    'lon': -104.0317972,
#    'lat': 40.37024444},
#   {'site_code': '13090999',
#    'name': 'BLUE LAKES SPRING BEL PUMP PLANT NR TWIN FALLS ID',
#    'lon': -114.4683333,
#    'lat': 42.6147222},
#   {'site_code': '434502088260902',
#    'name': 'HOLLY TREE LANE SITE #2 AT FOND DU LAC, WI',
#    'lon': -88.4358333,
#    'lat': 43.75055556},
#   {'site_code': '364259076262300',
#    'name': 'EAST DCH 2.1 MI BL WILLIAMSON DCH NR DEEP CR, VA',
#    'lon': -76.4397611,
#    'lat': 36.7164611},
#   {'site_code': '06821065',
#    'name': 'Little Platte River near Osborn, MO',
#    'lon': -94.3863383,
#    'lat': 39.68138877},
#   {'site_code': '01636242',
#    'name': 'CROOKED RUN BELOW HWY 340 AT RIVERTON, VA',
#    'lon': -78.1972225,
#    'lat': 38.9551101},
#   {'site_code': '09152500',
#    'name': 'GUNNISON RIVER NEAR GRAND JUNCTION, CO.',
#    'lon': -108.4506446,
#    'lat': 38.98331575},
#   {'site_code': '12078705',
#    'name': 'BLACK LAKE DITCH AT LAKE OUTLET NEAR TUMWATER, WA',
#    'lon': -122.965142,
#    'lat': 47.01009646},
#   {'site_code': '02429980',
#    'name': 'POLLARD MILL BRANCH AT PADEN, MS',
#    'lon': -88.24888889,
#    'lat': 34.65388889},
#   {'site_code': '335336082214600',
#    'name': 'MCK-  52',
#    'lon': -82.3626269,
#    'lat': 33.8934575},
#   {'site_code': '355906115492601',
#    'name': '162  S23 E55 05BAAB1    STUMP SPRING',
#    'lon': -115.8252778,
#    'lat': 35.98375},
#   {'site_code': '343114930420001',
#    'name': 'South Slope of Sugarloaf Mtn at Hot Springs, AR',
#    'lon': -93.0722222,
#    'lat': 34.52055556},
#   {'site_code': '415104121232901',
#    'name': '46.00N/05.00E-03P01M',
#    'lon': -121.3927008,
#    'lat': 41.85124685},
#   {'site_code': '071948150',
#    'name': 'Wetland BR at the WREC at Fayetteville, AR',
#    'lon': -94.1755556,
#    'lat': 36.0922222},
#   {'site_code': '01112500',
#    'name': 'BLACKSTONE RIVER AT WOONSOCKET, RI',
#    'lon': -71.5025613,
#    'lat': 42.0064871},
#   {'site_code': '13342250',
#    'name': 'SWEETWATER CREEK BEL SWEETWATER CANAL DIV NR WAHA',
#    'lon': -116.8522222,
#    'lat': 46.2719444},
#   {'site_code': '08319000',
#    'name': 'RIO GRANDE AT SAN FELIPE, NM',
#    'lon': -106.4398333,
#    'lat': 35.4445833},
#   {'site_code': '040244534',
#    'name': 'GOLF COURSE SITE AT SUPERIOR, WI',
#    'lon': -92.0726907,
#    'lat': 46.67799579},
#   {'site_code': '02108548',
#    'name': 'LITTLE ROCKFISH CREEK AT WALLACE, NC',
#    'lon': -77.9672064,
#    'lat': 34.73405715},
#   {'site_code': '03322000',
#    'name': 'OHIO RIVER AT EVANSVILLE, IN',
#    'lon': -87.5764045,
#    'lat': 37.9722644},
#   {'site_code': '05056678',
#    'name': 'TOLNA COULEE NEAR TOLNA, ND',
#    'lon': -98.4944444,
#    'lat': 47.8608333},
#   {'site_code': '414514081174400',
#    'name': 'Weather station near Headlands State Park OH',
#    'lon': -81.2955556,
#    'lat': 41.75388889},
#   {'site_code': '01350355',
#    'name': 'SCHOHARIE CREEK AT BREAKABEEN NY',
#    'lon': -74.4105556,
#    'lat': 42.53694444},
#   {'site_code': '09046400',
#    'name': 'INDIANA CREEK ABOVE MOUTH AT BLUE RIVER, CO',
#    'lon': -106.0236111,
#    'lat': 39.44944444},
#   {'site_code': '11455385',
#    'name': 'CACHE SLOUGH AB RYER ISLAND FERRY NR RIO VISTA CA',
#    'lon': -121.6580028,
#    'lat': 38.19395556},
#   {'site_code': '393554116252801',
#    'name': '139  N20 E49 23ACCB1    KVW ET',
#    'lon': -116.4243278,
#    'lat': 39.5982472},
#   {'site_code': '02336093',
#    'name': 'N FK PEACHTREE CR TRB AT DRESDEN DR, NR ATLANTA,GA',
#    'lon': -84.2947222,
#    'lat': 33.87},
#   {'site_code': '14165000',
#    'name': 'MOHAWK RIVER NEAR SPRINGFIELD, OR',
#    'lon': -122.9573052,
#    'lat': 44.09290317},
#   {'site_code': '02051000',
#    'name': 'NORTH MEHERRIN RIVER NEAR LUNENBURG, VA',
#    'lon': -78.3497182,
#    'lat': 36.9973738},
#   {'site_code': '04237575',
#    'name': 'SENECA RIVER (ERIE CANAL) AT COLD SPRINGS NY',
#    'lon': -76.25675,
#    'lat': 43.12780556},
#   {'site_code': '08148500',
#    'name': 'N Llano Rv nr Junction, TX',
#    'lon': -99.806179,
#    'lat': 30.5174101},
#   {'site_code': '01201487',
#    'name': 'STILL RIVER AT ROUTE 7 AT BROOKFIELD CENTER, CT',
#    'lon': -73.40320278,
#    'lat': 41.4658222},
#   {'site_code': '04273700',
#    'name': 'SALMON RIVER AT SOUTH PLATTSBURGH NY',
#    'lon': -73.4947222,
#    'lat': 44.64},
#   {'site_code': '06228450',
#    'name': 'SOUTH FORK LITTLE WIND RIV BEL WASHAKIE RES, WY',
#    'lon': -108.9998493,
#    'lat': 42.9844004},
#   {'site_code': '01571778',
#    'name': 'Lorberry Creek near Lorberry Junction, PA',
#    'lon': -76.4260683,
#    'lat': 40.5875889},
#   {'site_code': '04201506',
#    'name': 'Abram Creek at Middleburg Heights OH',
#    'lon': -81.81888889,
#    'lat': 41.36277778},
#   {'site_code': '04121900',
#    'name': 'LITTLE MUSKEGON RIVER NEAR MORLEY, MI',
#    'lon': -85.3425356,
#    'lat': 43.50252875},
#   {'site_code': '01115184',
#    'name': 'SPRUCE BROOK NR NORTH SCITUATE, RI',
#    'lon': -71.6200647,
#    'lat': 41.7887107},
#   {'site_code': '05388250',
#    'name': 'Upper Iowa River near Dorchester, IA',
#    'lon': -91.5087519,
#    'lat': 43.4210841},
#   {'site_code': '03364500',
#    'name': 'CLIFTY CREEK AT HARTSVILLE, IN',
#    'lon': -85.7016469,
#    'lat': 39.2747732},
#   {'site_code': '01630700',
#    'name': 'GOONEY RUN NEAR GLEN ECHO, VA',
#    'lon': -78.2319454,
#    'lat': 38.83511474},
#   {'site_code': '03341500',
#    'name': 'WABASH RIVER AT TERRE HAUTE, IN',
#    'lon': -87.4195,
#    'lat': 39.4657222},
#   {'site_code': '02346180',
#    'name': 'FLINT RIVER NEAR THOMASTON, GA',
#    'lon': -84.4240868,
#    'lat': 32.8390223},
#   {'site_code': '344750099480801',
#    'name': '04N-25W-26 BAB 1 SFR05',
#    'lon': -99.8022361,
#    'lat': 34.79732778},
#   {'site_code': '252019080544800',
#    'name': 'UPSTREAM NORTH RIVER, NEAR FLAMINGO, FL',
#    'lon': -80.9002778,
#    'lat': 25.35833333},
#   {'site_code': '07311200',
#    'name': 'Blue Beaver Creek near Cache, OK',
#    'lon': -98.5636712,
#    'lat': 34.62340607},
#   {'site_code': '16227500',
#    'name': 'Moanalua Stream nr Kaneohe, Oahu, HI',
#    'lon': -157.848611,
#    'lat': 21.38805556},
#   {'site_code': '02215100',
#    'name': 'TUCSAWHATCHEE CREEK NEAR HAWKINSVILLE, GA',
#    'lon': -83.5016667,
#    'lat': 32.23944444},
#   {'site_code': '06350000',
#    'name': 'CANNONBALL RIVER AT REGENT, ND',
#    'lon': -102.5518303,
#    'lat': 46.42667116},
#   {'site_code': '14313500',
#    'name': 'N UMPQUA RIVER BLW LEMOLO LK, NR TOKETEE FALLS, OR',
#    'lon': -122.1955907,
#    'lat': 43.32206866},
#   {'site_code': '103087891',
#    'name': 'ASPEN C ABV LEVIATHAN MINE NR MARKLEEVILLE CA',
#    'lon': -119.648611,
#    'lat': 38.7086111},
#   {'site_code': '424115073495301',
#    'name': 'Local number, A-654, SUNY Albany NY',
#    'lon': -73.83138889,
#    'lat': 42.6874722},
#   {'site_code': '06599950',
#    'name': 'Perry Creek near Hinton, IA',
#    'lon': -96.3725279,
#    'lat': 42.6197153},
#   {'site_code': '02105769',
#    'name': 'CAPE FEAR R AT LOCK #1 NR KELLY, NC',
#    'lon': -78.2936111,
#    'lat': 34.40444444},
#   {'site_code': '15746990',
#    'name': 'RED DOG C AB MOUTH NR KIVALINA AK',
#    'lon': -162.9424008,
#    'lat': 68.0887914},
#   {'site_code': '12157250',
#    'name': 'MISSION CREEK NEAR TULALIP, WA',
#    'lon': -122.2673635,
#    'lat': 48.05842935},
#   {'site_code': '09306800',
#    'name': 'BITTER CREEK NEAR BONANZA, UT',
#    'lon': -109.3548415,
#    'lat': 39.75330136},
#   {'site_code': '05379500',
#    'name': 'TREMPEALEAU RIVER AT DODGE, WI',
#    'lon': -91.5530278,
#    'lat': 44.13175},
#   {'site_code': '07050700',
#    'name': 'James River near Springfield, MO',
#    'lon': -93.2033889,
#    'lat': 37.1499722},
#   {'site_code': '07343000',
#    'name': 'N Sulphur Rv nr Cooper, TX',
#    'lon': -95.5877347,
#    'lat': 33.47483009},
#   {'site_code': '12202450',
#    'name': 'SILVER BEACH CR AT MAYNARD PL AT BELLINGHAM, WA',
#    'lon': -122.4065547,
#    'lat': 48.7692772},
#   {'site_code': '03026480',
#    'name': 'East Branch Clarion River near Clermont, PA',
#    'lon': -78.5314444,
#    'lat': 41.64405556},
#   {'site_code': '05293000',
#    'name': 'YELLOW BANK RIVER NEAR ODESSA, MN',
#    'lon': -96.353665,
#    'lat': 45.2269094},
#   {'site_code': '12500420',
#    'name': 'MOXEE DRAIN AT BIRCHFIELD ROAD NEAR UNION GAP, WA',
#    'lon': -120.4381179,
#    'lat': 46.5459606},
#   {'site_code': '350527106405102',
#    'name': 'T10N.R02E.13.414g (projected) cebm-t2',
#    'lon': -106.68065,
#    'lat': 35.09086667},
#   {'site_code': '360700114505101',
#    'name': 'LAS VEGAS BAY QW PLATFORM SITE3 1 METER DEPTH',
#    'lon': -114.848434,
#    'lat': 36.1165881},
#   {'site_code': '06746110',
#    'name': 'JOE WRIGHT CREEK BELOW JOE WRIGHT RESERVOIR, CO',
#    'lon': -105.8639,
#    'lat': 40.5619264},
#   {'site_code': '02469800',
#    'name': 'SATILPA CREEK NEAR COFFEEVILLE AL',
#    'lon': -88.0225066,
#    'lat': 31.7443247},
#   {'site_code': '06886900',
#    'name': 'TUTTLE C LK NR MANHATTAN, KS',
#    'lon': -96.6025038,
#    'lat': 39.25444066},
#   {'site_code': '06085800',
#    'name': 'Sun River at Simms MT',
#    'lon': -111.9319139,
#    'lat': 47.50162778},
#   {'site_code': '02479310',
#    'name': 'PASCAGOULA RIVER AT GRAHAM FERRY, MS',
#    'lon': -88.64138889,
#    'lat': 30.61055556},
#   {'site_code': '04121970',
#    'name': 'MUSKEGON RIVER NEAR CROTON, MI',
#    'lon': -85.6653239,
#    'lat': 43.43474558},
#   {'site_code': '01055000',
#    'name': 'Swift River near Roxbury, Maine',
#    'lon': -70.58888889,
#    'lat': 44.64277778},
#   {'site_code': '254158080212201',
#    'name': 'G  -3882',
#    'lon': -80.3561944,
#    'lat': 25.69956944},
#   {'site_code': '12143900',
#    'name': 'BOXLEY CREEK NEAR EDGEWICK, WA',
#    'lon': -121.7317744,
#    'lat': 47.44871459},
#   {'site_code': '01576787',
#    'name': 'Pequea Creek at Martic Forge, PA',
#    'lon': -76.32829298,
#    'lat': 39.90593409},
#   {'site_code': '424520070562401',
#    'name': 'MA-NIW   27 NEWBURY, MA',
#    'lon': -70.93948889,
#    'lat': 42.7553722},
#   {'site_code': '01302020',
#    'name': 'BRONX RIVER AT NY BOTANICAL GARDEN AT BRONX NY',
#    'lon': -73.87438889,
#    'lat': 40.86230556},
#   {'site_code': '08185500',
#    'name': 'Cibolo Ck at Sutherland Springs, TX',
#    'lon': -98.0533333,
#    'lat': 29.2797222},
#   {'site_code': '06334100',
#    'name': 'Wolf Creek near Hammond MT',
#    'lon': -104.7562111,
#    'lat': 45.1642972},
#   {'site_code': '343124082111400',
#    'name': 'USGS RAINGAGE AT HICKORY TAVERN,SC',
#    'lon': -82.1870542,
#    'lat': 34.5234522},
#   {'site_code': '02393419',
#    'name': 'ALLATOONA CREEK AT STILESBORO RD, NEAR ACWORTH, GA',
#    'lon': -84.6930556,
#    'lat': 33.99527778},
#   {'site_code': '01105880',
#    'name': 'HERRING RIVER AT NORTH HARWICH, MA',
#    'lon': -70.1069625,
#    'lat': 41.70011074},
#   {'site_code': '413520088043902',
#    'name': '36N10E22.6d2',
#    'lon': -88.0776944,
#    'lat': 41.58905556},
#   {'site_code': '08099100',
#    'name': 'Leon Rv nr De Leon, TX',
#    'lon': -98.5331058,
#    'lat': 32.1737502},
#   {'site_code': '09513780',
#    'name': 'NEW RIVER NEAR ROCK SPRINGS, AZ.',
#    'lon': -112.0990458,
#    'lat': 33.97420168},
#   {'site_code': '06115270',
#    'name': 'Armells Creek nr Landusky MT',
#    'lon': -108.6956389,
#    'lat': 47.6105583},
#   {'site_code': '411305083453109',
#    'name': 'OARDC NWARS test plot 5 subsurface drainage',
#    'lon': -83.7586111,
#    'lat': 41.21805556},
#   {'site_code': '04237020',
#    'name': 'SENECA R (BARGE CANAL) AT CROSS LAKE NR JORDAN NY',
#    'lon': -76.4981667,
#    'lat': 43.10013889},
#   {'site_code': '03430320',
#    'name': 'CUMBERLAND RIVER AT BRILEY PKWY NR INGLEWOOD, TN',
#    'lon': -86.7125,
#    'lat': 36.23527778},
#   {'site_code': '415044089284800',
#    'name': 'ROCK RIVER AT DIXON, IL (ILDNR)',
#    'lon': -89.4801036,
#    'lat': 41.84558786},
#   {'site_code': '01084000',
#    'name': 'NORTH BRANCH RIVER NEAR ANTRIM, NH',
#    'lon': -71.9784147,
#    'lat': 43.0817464},
#   {'site_code': '06816290',
#    'name': 'West Nodaway River at Massena, IA',
#    'lon': -94.757755,
#    'lat': 41.2455425},
#   {'site_code': '350148091313801',
#    'name': '05N05W27AB1 PR-51 WU',
#    'lon': -91.5273537,
#    'lat': 35.03008976},
#   {'site_code': '07176000',
#    'name': 'Verdigris River near Claremore, OK',
#    'lon': -95.6997222,
#    'lat': 36.3075},
#   {'site_code': '350144106400702',
#    'name': 'T09N.R03E.07.121B RBEDWM-T2',
#    'lon': -106.6689556,
#    'lat': 35.0291111},
#   {'site_code': '04206215',
#    'name': 'Bath Creek at Bath Center OH',
#    'lon': -81.6487351,
#    'lat': 41.16922157},
#   {'site_code': '471326097332902',
#    'name': '143-054-08BBB2',
#    'lon': -97.5572528,
#    'lat': 47.2243444},
#   {'site_code': '333001117005704',
#    'name': '008S001W06R004S',
#    'lon': -117.0160556,
#    'lat': 33.5004722},
#   {'site_code': '05056665',
#    'name': 'EASTERN STUMP LAKE NR LAKOTA, ND',
#    'lon': -98.3578795,
#    'lat': 47.8686089},
#   {'site_code': '16345000',
#    'name': 'Opaeula Str nr Wahiawa, Oahu, HI',
#    'lon': -158.00025,
#    'lat': 21.56233333},
#   {'site_code': '385428091265001',
#    'name': 'New Florence',
#    'lon': -91.4475,
#    'lat': 38.90777778},
#   {'site_code': '10172795',
#    'name': 'BOX ELDER WASH NEAR GRANTSVILLE, UT',
#    'lon': -112.5319006,
#    'lat': 40.4949426},
#   {'site_code': '461838097553402',
#    'name': '133-058-25BBA2',
#    'lon': -97.9265639,
#    'lat': 46.3112},
#   {'site_code': '05114000',
#    'name': 'SOURIS RIVER NR SHERWOOD, ND',
#    'lon': -101.9582209,
#    'lat': 48.9900156},
#   {'site_code': '351741080475045',
#    'name': 'CRN-54 RAINGAGE AT TURNING POINT ACADEMY',
#    'lon': -80.7961111,
#    'lat': 35.29527778},
#   {'site_code': '01571184',
#    'name': 'Mountain Creek near Pine Grove Furnace, PA',
#    'lon': -77.3085949,
#    'lat': 40.0309245},
#   {'site_code': '374425075400003',
#    'name': '65K 29 SOW 114C',
#    'lon': -75.66631809,
#    'lat': 37.74096248},
#   {'site_code': '351204106381602',
#    'name': 'T11N.R03E.09.113e (projected) aebm-t1',
#    'lon': -106.6376389,
#    'lat': 35.2012222},
#   {'site_code': '381929076043002',
#    'name': 'DO Fe  42',
#    'lon': -76.0749694,
#    'lat': 38.3246361},
#   {'site_code': '01351500',
#    'name': 'SCHOHARIE CREEK AT BURTONSVILLE NY',
#    'lon': -74.26277778,
#    'lat': 42.8},
#   {'site_code': '08077658',
#    'name': 'TX City Pump Sta at Texas City, TX',
#    'lon': -94.9249228,
#    'lat': 29.35745688},
#   {'site_code': '07349815',
#    'name': 'Cypress Bayou Lake near Benton, LA',
#    'lon': -93.6698995,
#    'lat': 32.6520916},
#   {'site_code': '375213076190205',
#    'name': '60L 31 SOW 216D',
#    'lon': -76.31722049,
#    'lat': 37.87029414},
#   {'site_code': '09271600',
#    'name': 'STEWART LAKE OUTFLOW NEAR JENSEN, UT',
#    'lon': -109.3631856,
#    'lat': 40.3460739},
#   {'site_code': '15129600',
#    'name': 'OPHIR C NR YAKUTAT AK',
#    'lon': -139.7452729,
#    'lat': 59.52358729},
#   {'site_code': '01557500',
#    'name': 'Bald Eagle Creek at Tyrone, PA',
#    'lon': -78.23362439,
#    'lat': 40.6836733},
#   {'site_code': '0213462300',
#    'name': 'LUMBER RIVER AT FAIR BLUFF, NC',
#    'lon': -79.0383656,
#    'lat': 34.31405519},
#   {'site_code': '452726122474500',
#    'name': 'FANNO CREEK PONDED SITE 1 AT GREENWAY PARK',
#    'lon': -122.7959306,
#    'lat': 45.4573333},
#   {'site_code': '01111500',
#    'name': 'BRANCH RIVER AT FORESTDALE, RI',
#    'lon': -71.56200758,
#    'lat': 41.99648716},
#   {'site_code': '02489000',
#    'name': 'PEARL RIVER NR COLUMBIA, MS',
#    'lon': -89.8469444,
#    'lat': 31.23777778},
#   {'site_code': '323511090511201',
#    'name': 'G0038  ISSAQUENA WU',
#    'lon': -90.8533333,
#    'lat': 32.58638889},
#   {'site_code': '07027720',
#    'name': 'SOUTH FORK FORKED DEER RIVER NEAR OWL CITY, TN',
#    'lon': -89.2122764,
#    'lat': 35.71876687},
#   {'site_code': '04063522',
#    'name': 'MENOMINEE RIVER AT US HWY-2 NEAR IRON MOUNTAIN, MI',
#    'lon': -88.074573,
#    'lat': 45.86606566},
#   {'site_code': '11446700',
#    'name': 'AMERICAN R A WILLIAM B POND PARK A CARMICHAEL CA',
#    'lon': -121.3327288,
#    'lat': 38.59129436},
#   {'site_code': '03249505',
#    'name': 'LICKING RIVER AT HWY 60 AT FARMERS, KY',
#    'lon': -83.5571327,
#    'lat': 38.14008125},
#   {'site_code': '351828116371203',
#    'name': '014N003E13M004S',
#    'lon': -116.6208806,
#    'lat': 35.3080222},
#   {'site_code': '02330150',
#    'name': 'OCHLOCKONEE RIVER NR SMITH CREEK, FLA.',
#    'lon': -84.6679637,
#    'lat': 30.17658934},
#   {'site_code': '11376550',
#    'name': 'BATTLE C BL COLEMAN FISH HATCHERY NR COTTONWOOD CA',
#    'lon': -122.1463869,
#    'lat': 40.39820996},
#   {'site_code': '06471000',
#    'name': 'JAMES R AT COLUMBIA,SD',
#    'lon': -98.3103756,
#    'lat': 45.6035795},
#   {'site_code': '10348200',
#    'name': 'TRUCKEE RV NR SPARKS, NV',
#    'lon': -119.7416444,
#    'lat': 39.51761667},
#   {'site_code': '350653106311602',
#    'name': '10N.04E.09.214A MATHESON MIDDLE SCHOOL',
#    'lon': -106.5218222,
#    'lat': 35.114775},
#   {'site_code': '12102212',
#    'name': 'SWAN CREEK AT PIONEER WAY TACOMA, WA',
#    'lon': -122.3917891,
#    'lat': 47.2284329},
#   {'site_code': '254218080214102',
#    'name': 'G  -3925',
#    'lon': -80.3613361,
#    'lat': 25.70488889},
#   {'site_code': '422433088140601',
#    'name': '45N9E-06.7e (NW-6-45-9)',
#    'lon': -88.2350167,
#    'lat': 42.4091333},
#   {'site_code': '253632080321101',
#    'name': 'G  -3627',
#    'lon': -80.50325,
#    'lat': 25.60869444},
#   {'site_code': '021720869',
#    'name': 'ASHLEY RIVER NEAR NORTH CHARLESTON, SC',
#    'lon': -80.0237014,
#    'lat': 32.8346201},
#   {'site_code': '345713106411002',
#    'name': 'T08N.R02E.01.142B I-25 WDEM-T2',
#    'lon': -106.68545,
#    'lat': 34.9516222},
#   {'site_code': '06610770',
#    'name': 'Big Papillion Creek at Q Street at Omaha, Nebr.',
#    'lon': -96.0166826,
#    'lat': 41.20541556},
#   {'site_code': '08151500',
#    'name': 'Llano Rv at Llano, TX',
#    'lon': -98.6697599,
#    'lat': 30.7512899},
#   {'site_code': '04087242',
#    'name': 'ROOT RIVER NEAR MOUTH AT RACINE, WI',
#    'lon': -87.7845191,
#    'lat': 42.7339086},
#   {'site_code': '261319080353201',
#    'name': 'EDEN 9 IN WATER CONSERVATION AREA 3-A',
#    'lon': -80.5922222,
#    'lat': 26.22194444},
#   {'site_code': '363021096432403',
#    'name': '23N-05E 01 BBB 3 RALSTON GW ADA',
#    'lon': -96.7235361,
#    'lat': 36.5059583},
#   {'site_code': '103366097',
#    'name': 'ANGORA CK NR MOUTH AT LAKE TAHOE GOLF COURSE',
#    'lon': -120.01,
#    'lat': 38.87375},
#   {'site_code': '01363382',
#    'name': 'BUSH KILL BLW MALTBY HOLLOW BK AT WEST SHOKAN NY',
#    'lon': -74.2930556,
#    'lat': 41.96555556},
#   {'site_code': '350846106402804',
#    'name': 'T11N.R02E.25.444E MERS-T2',
#    'lon': -106.6749139,
#    'lat': 35.1461},
#   {'site_code': '423000088164401',
#    'name': 'ELIZABETH LAKE AT TWIN LAKES, WI-IL',
#    'lon': -88.2788056,
#    'lat': 42.4999722},
#   {'site_code': '09424447',
#    'name': 'BURRO CREEK AT OLD US 93 BRIDGE, NEAR BAGDAD, AZ',
#    'lon': -113.4452053,
#    'lat': 34.5416838},
#   {'site_code': '06900800',
#    'name': 'Grand River near Fountain Grove, MO',
#    'lon': -93.3252778,
#    'lat': 39.6922222},
#   {'site_code': '365637089070601',
#    'name': 'New Madrid Floodway Stage Sensor No. 911329',
#    'lon': -89.1183333,
#    'lat': 36.9436111},
#   {'site_code': '06805570',
#    'name': 'Platte River at La Platte, Nebr.',
#    'lon': -95.928,
#    'lat': 41.0578611},
#   {'site_code': '02300210',
#    'name': 'SOUTH FORK LITTLE MANATEE RIVER NEAR PARRISH FL',
#    'lon': -82.2112009,
#    'lat': 27.60197978},
#   {'site_code': '06426130',
# ...
#    'lon': -84.0647222,
#    'lat': 34.37944444},
#   {'site_code': '13353010',
#    'name': 'SNAKE RIVER BL GOOSE ISLAND BL ICE HARBOR DAM, WA',
#    'lon': -118.9401224,
#    'lat': 46.2421853},
#   {'site_code': '06893562',
#    'name': 'Brush Creek at Rockhill Road in Kansas City, MO',
#    'lon': -94.5787222,
#    'lat': 39.03925},
#   {'site_code': '06854000',
#    'name': 'WHITE ROCK C AT LOVEWELL, KS',
#    'lon': -98.0225448,
#    'lat': 39.88417866},
#   {'site_code': '01111212',
#    'name': 'BLACKSTONE RIVER, RT 122 BRIDGE NEAR UXBRIDGE, MA',
#    'lon': -71.6164542,
#    'lat': 42.05481959},
#   {'site_code': '350402106392602',
#    'name': '10N.03E.30.244D BEBM',
#    'lon': -106.6575083,
#    'lat': 35.06730278},
#   {'site_code': '08195000',
#    'name': 'Frio Rv at Concan, TX',
#    'lon': -99.7047756,
#    'lat': 29.48856496},
#   {'site_code': '06804000',
#    'name': 'Wahoo Creek at Ithaca, Nebr.',
#    'lon': -96.5377778,
#    'lat': 41.1475},
#   {'site_code': '265633080203001',
#    'name': 'PB - 689',
#    'lon': -80.3453333,
#    'lat': 26.9431111},
#   {'site_code': '07344480',
#    'name': 'Cross Lake at Shreveport, LA',
#    'lon': -93.7983333,
#    'lat': 32.5125},
#   {'site_code': '04044724',
#    'name': 'AU TRAIN RIVER AT FOREST LAKE, MI',
#    'lon': -86.8501514,
#    'lat': 46.34077908},
#   {'site_code': '02290709',
#    'name': '10B BLACK CR CANAL AT OLD CUTLER RD NR GOU',
#    'lon': -80.3595556,
#    'lat': 25.5598611},
#   {'site_code': '370539093494001',
#    'name': 'Mt. Vernon Ozark Aquifer',
#    'lon': -93.8278333,
#    'lat': 37.0942222},
#   {'site_code': '05056215',
#    'name': 'EDMORE COULEE TRIB NR WEBSTER, ND',
#    'lon': -98.6809499,
#    'lat': 48.2663928},
#   {'site_code': '04176500',
#    'name': 'RIVER RAISIN NEAR MONROE, MI',
#    'lon': -83.53104619,
#    'lat': 41.9606008},
#   {'site_code': '09312800',
#    'name': 'WILLOW CREEK NEAR CASTLE GATE, UTAH',
#    'lon': -110.7923812,
#    'lat': 39.7769068},
#   {'site_code': '364518120222401',
#    'name': '013S015E31J017M',
#    'lon': -120.3732889,
#    'lat': 36.75503889},
#   {'site_code': '08329938',
#    'name': ' LADERA ARROYO AT ALBUQUERQUE, NM',
#    'lon': -106.7466667,
#    'lat': 35.11555556},
#   {'site_code': '255123081321300',
#    'name': 'FAKA UNION BOUNDARY AT CHANNEL MARKER 6 FL',
#    'lon': -81.5370556,
#    'lat': 25.8565},
#   {'site_code': '11447905',
#    'name': 'SACRAMENTO R BL GEORGIANA SLOUGH CA',
#    'lon': -121.5227309,
#    'lat': 38.23880385},
#   {'site_code': '320754081364301',
#    'name': '33R045',
#    'lon': -81.6117788,
#    'lat': 32.13186697},
#   {'site_code': '395313105110500',
#    'name': 'S. INTERCEPTOR DITCH ABV. POND C-2 AT RFP',
#    'lon': -105.1849872,
#    'lat': 39.88665285},
#   {'site_code': '04240158',
#    'name': 'WILLOW BROOK NEAR BORODINO NY',
#    'lon': -76.3252222,
#    'lat': 42.87441667},
#   {'site_code': '01417500',
#    'name': 'EAST BRANCH DELAWARE RIVER AT HARVARD NY',
#    'lon': -75.11927778,
#    'lat': 42.0245833},
#   {'site_code': '03216540',
#    'name': 'EAST FORK LITTLE SANDY RIVER NEAR FALLSBURG, KY',
#    'lon': -82.7087717,
#    'lat': 38.233695},
#   {'site_code': '351058106385902',
#    'name': 'T11N.R3E.17.142B PDN.EBM-T2',
#    'lon': -106.6497389,
#    'lat': 35.18286667},
#   {'site_code': '03282060',
#    'name': 'KENTUCKY RIVER AT LOCK 13 NEAR WILLOW SHOALS, KY',
#    'lon': -83.8329755,
#    'lat': 37.60202947},
#   {'site_code': '06889610',
#    'name': 'SB SHUNGANUNGA C AT SW 37TH ST, TOPEKA, KS',
#    'lon': -95.711927,
#    'lat': 39.0002788},
#   {'site_code': '484154116161402',
#    'name': '62N 01E 25ADB2',
#    'lon': -116.2705,
#    'lat': 48.69827778},
#   {'site_code': '350519106405703',
#    'name': 'T10N.R02E.13.433d (projected) cwbd-t2',
#    'lon': -106.6827167,
#    'lat': 35.0884361},
#   {'site_code': '021973008',
#    'name': 'MCQUEEN BRANCH @ RD F AT SRS, SC',
#    'lon': -81.63122139,
#    'lat': 33.29597916},
#   {'site_code': '12102025',
#    'name': 'DIRU CREEK BL HATCHERY, PIONEER WY NR PUYALLUP, WA',
#    'lon': -122.3378985,
#    'lat': 47.1928779},
#   {'site_code': '01200500',
#    'name': 'HOUSATONIC RIVER AT GAYLORDSVILLE, CT',
#    'lon': -73.4898462,
#    'lat': 41.6531496},
#   {'site_code': '07146500',
#    'name': 'ARKANSAS R AT ARKANSAS CITY, KS',
#    'lon': -97.0392194,
#    'lat': 37.0375083},
#   {'site_code': '360310114172316',
#    'name': 'LAKE MEAD TEMPLE BASIN QW PLATFORM 16 METER DEPTH',
#    'lon': -114.2897222,
#    'lat': 36.05277778},
#   {'site_code': '375635075271501',
#    'name': '67M 10 SOW 115A',
#    'lon': -75.4538118,
#    'lat': 37.9431789},
#   {'site_code': '02092576',
#    'name': 'TRENT RIVER AT US HIGHWAY 70 AT NEW BERN, NC',
#    'lon': -77.0366667,
#    'lat': 35.10264444},
#   {'site_code': '05267000',
#    'name': 'MISSISSIPPI RIVER NEAR ROYALTON, MN',
#    'lon': -94.3552782,
#    'lat': 45.8260765},
#   {'site_code': '03084000',
#    'name': 'Abers Creek near Murrysville, PA',
#    'lon': -79.7136566,
#    'lat': 40.45034589},
#   {'site_code': '215509159340401',
#    'name': '2-5534-06 Upper Eleele Reservoir, Kauai, HI',
#    'lon': -159.5656667,
#    'lat': 21.91847222},
#   {'site_code': '12200750',
#    'name': 'UNNAMED TRIBUTARY TROUT LAKE SAN JUAN ISLAND, WA',
#    'lon': -123.1318506,
#    'lat': 48.53537609},
#   {'site_code': '08013000',
#    'name': 'Calcasieu River nr Glenmora, LA',
#    'lon': -92.6736111,
#    'lat': 30.99666667},
#   {'site_code': '01389005',
#    'name': 'Passaic River below Pompton Riv at Two Bridges NJ',
#    'lon': -74.2691667,
#    'lat': 40.89638889},
#   {'site_code': '351019116373501',
#    'name': '013N003E35J001S',
#    'lon': -116.6263889,
#    'lat': 35.17194444},
#   {'site_code': '194013156013801',
#    'name': 'Kaloko Anchialine Pool 83C, HI',
#    'lon': -156.0270833,
#    'lat': 19.67038889},
#   {'site_code': '07076530',
#    'name': 'Big Creek near Letona, AR',
#    'lon': -91.8010278,
#    'lat': 35.3619722},
#   {'site_code': '384957077481701',
#    'name': '48U 26 SOW 215',
#    'lon': -77.8048111,
#    'lat': 38.8326333},
#   {'site_code': '03013000',
#    'name': 'CONEWANGO CREEK AT WATERBORO NY',
#    'lon': -79.0691667,
#    'lat': 42.1708333},
#   {'site_code': '12121720',
#    'name': 'LAUGHING JACOBS CREEK NEAR ISSAQUAH, WA',
#    'lon': -122.0523423,
#    'lat': 47.56565618},
#   {'site_code': '262331082383202',
#    'name': 'L  -5673',
#    'lon': -81.7271944,
#    'lat': 26.39205556},
#   {'site_code': '205902156380901',
#    'name': '6-5938-04 Kapalua 3, Maui, HI',
#    'lon': -156.6358056,
#    'lat': 20.98388889},
#   {'site_code': '365949091421401',
#    'name': 'Mountain View',
#    'lon': -91.7034167,
#    'lat': 36.99688889},
#   {'site_code': '340248117020902',
#    'name': '001S002W36A003S',
#    'lon': -117.0358778,
#    'lat': 34.046825},
#   {'site_code': '01434017',
#    'name': 'EAST BRANCH NEVERSINK RIVER NEAR CLARYVILLE NY',
#    'lon': -74.54027778,
#    'lat': 41.92527778},
#   {'site_code': '04152500',
#    'name': 'TOBACCO RIVER AT GLIDDEN ROAD AT BEAVERTON, MI',
#    'lon': -84.4738977,
#    'lat': 43.8794687},
#   {'site_code': '05436500',
#    'name': 'SUGAR RIVER NEAR BRODHEAD, WI',
#    'lon': -89.3979722,
#    'lat': 42.61230556},
#   {'site_code': '03120500',
#    'name': 'McGuire Creek near Leesville OH',
#    'lon': -81.196493,
#    'lat': 40.47034258},
#   {'site_code': '07382000',
#    'name': 'Bayou Cocodrie near Clearwater, LA',
#    'lon': -92.3802778,
#    'lat': 31.00027778},
#   {'site_code': '344544079263701',
#    'name': 'SC-142 AT LAURINBURG, NC (BLACK CREEK)',
#    'lon': -79.4436111,
#    'lat': 34.7622222},
#   {'site_code': '415318085243401',
#    'name': 'ST. JOSEPH 07-09 PIEZOMETER',
#    'lon': -85.4093361,
#    'lat': 41.88845556},
#   {'site_code': '14034480',
#    'name': 'BALM FORK NEAR HEPPNER, OR',
#    'lon': -119.5411325,
#    'lat': 45.33207265},
#   {'site_code': '02107544',
#    'name': 'BLACK RIVER NEAR CURRIE, NC',
#    'lon': -78.1436111,
#    'lat': 34.43166667},
#   {'site_code': '392934104414901',
#    'name': 'SC00606532BB UDAW 4',
#    'lon': -104.6961056,
#    'lat': 39.4913},
#   {'site_code': '01056480',
#    'name': 'Townsend Brook near Auburn, Maine',
#    'lon': -70.2371694,
#    'lat': 44.16648889},
#   {'site_code': '350142106402701',
#    'name': '09N.03E.07.113B RBWDES',
#    'lon': -106.6743917,
#    'lat': 35.028},
#   {'site_code': '282531081082202',
#    'name': 'USGS OBSERVATION WELL COCOA G NEAR BITHLO, FL',
#    'lon': -81.1392315,
#    'lat': 28.42556083},
#   {'site_code': '08072680',
#    'name': 'S Mayde Ck at Heathergold Dr nr Addicks, TX',
#    'lon': -95.7096111,
#    'lat': 29.8051111},
#   {'site_code': '04175120',
#    'name': 'HURON RIVER AT FORT ROAD AT ROCKWOOD, MI',
#    'lon': -83.25388889,
#    'lat': 42.06416667},
#   {'site_code': '02301740',
#    'name': 'NORTH ARCHIE CREEK AT PROGRESS BLVD. NEAR TAMPA FL',
#    'lon': -82.3498147,
#    'lat': 27.8966908},
#   {'site_code': '02294760',
#    'name': 'BARBER BRANCH NEAR HOMELAND FL',
#    'lon': -81.8122222,
#    'lat': 27.83833333},
#   {'site_code': '07064440',
#    'name': 'Current River at Montauk State Park, MO',
#    'lon': -91.6712593,
#    'lat': 37.44837816},
#   {'site_code': '0208194820',
#    'name': 'TAR RIVER AT SR1001 AT STRICKLAND CROSSROADS, NC',
#    'lon': -78.0096083,
#    'lat': 35.86545556},
#   {'site_code': '04071765',
#    'name': 'OCONTO RIVER NEAR OCONTO, WI',
#    'lon': -87.98388889,
#    'lat': 44.86055556},
#   {'site_code': '06803430',
#    'name': 'North Oak Creek at Valparaiso, Nebr.',
#    'lon': -96.8383889,
#    'lat': 41.07491667},
#   {'site_code': '09443900',
#    'name': 'FISH POND DITCH ABOVE HATCHERY AT GLENWOOD, NM',
#    'lon': -108.8772222,
#    'lat': 33.3225},
#   {'site_code': '304942082213801',
#    'name': '27E004',
#    'lon': -82.3604055,
#    'lat': 30.82883445},
#   {'site_code': '365559092030001',
#    'name': 'Noblett Lake',
#    'lon': -92.05,
#    'lat': 36.9330833},
#   {'site_code': '07066510',
#    'name': 'Current River above Powder Mill, MO',
#    'lon': -91.1776639,
#    'lat': 37.18561389},
#   {'site_code': '311022081304601',
#    'name': '33H324',
#    'lon': -81.5127778,
#    'lat': 31.17277778},
#   {'site_code': '10348036',
#    'name': 'TRUCKEE RV AT GLENDALE AVE NR SPARKS, NV',
#    'lon': -119.7766389,
#    'lat': 39.5258333},
#   {'site_code': '12500450',
#    'name': 'YAKIMA RIVER ABOVE AHTANUM CREEK AT UNION GAP, WA',
#    'lon': -120.4672855,
#    'lat': 46.53429376},
#   {'site_code': '01434021',
#    'name': 'W BR NEVERSINK R AT WINNISOOK L NR FROST VALLEY NY',
#    'lon': -74.4144444,
#    'lat': 42.0111111},
#   {'site_code': '02476600',
#    'name': 'OKATIBBEE CREEK AT ARUNDEL, MS',
#    'lon': -88.7536111,
#    'lat': 32.29833333},
#   {'site_code': '07358284',
#    'name': 'Hot Springs Cr DS of Grand Ave at Hot Springs, AR',
#    'lon': -93.0505556,
#    'lat': 34.50277778},
#   {'site_code': '15515080',
#    'name': 'EMMA C NR HEALY AK',
#    'lon': -148.727612,
#    'lat': 64.01121149},
#   {'site_code': '09270500',
#    'name': 'DRY FORK AT MOUTH NEAR DRY FORK, UTAH',
#    'lon': -109.6056958,
#    'lat': 40.5263475},
#   {'site_code': '404706101282201',
#    'name': ' 10N 36W31CCCC1 MADRID',
#    'lon': -101.4732208,
#    'lat': 40.7849978},
#   {'site_code': '351054106385401',
#    'name': 'T11N.R3E.17.233A PDN.EDWS',
#    'lon': -106.6483333,
#    'lat': 35.18166667},
#   {'site_code': '272714081545901',
#    'name': 'ROMP 31 AVON PARK WELL NEAR ONA FL',
#    'lon': -81.91625,
#    'lat': 27.45413889},
#   {'site_code': '414149086183101',
#    'name': 'CITY OF SOUTH BEND MONITORING WELL NEAR AIRPORT',
#    'lon': -86.3086147,
#    'lat': 41.69715848},
#   {'site_code': '04220223',
#    'name': 'SANDY CREEK AT NORTH HAMLIN NY',
#    'lon': -77.9152222,
#    'lat': 43.3390833},
#   {'site_code': '01048000',
#    'name': 'Sandy River near Mercer, Maine',
#    'lon': -69.9375,
#    'lat': 44.70805556},
#   {'site_code': '13210050',
#    'name': 'BOISE RIVER NR MIDDLETON ID',
#    'lon': -116.5737442,
#    'lat': 43.6848841},
#   {'site_code': '312900110071001',
#    'name': 'D-22-22 28CAA2 [HUN-LO]',
#    'lon': -110.1199667,
#    'lat': 31.48331944},
#   {'site_code': '09244490',
#    'name': 'YAMPA RIVER ABOVE ELKHEAD CREEK NEAR HAYDEN, CO',
#    'lon': -107.3989444,
#    'lat': 40.51793056},
#   {'site_code': '341512117102201',
#    'name': 'CEDAR GLEN PRECIP GAGE A LAKE ARROWHEAD CA',
#    'lon': -117.1727778,
#    'lat': 34.2533333},
#   {'site_code': '06929315',
#    'name': 'Paddy Creek above Slabtown Spring, MO',
#    'lon': -92.0492806,
#    'lat': 37.5574361},
#   {'site_code': '07144780',
#    'name': 'NF NINNESCAH R AB CHENEY RE, KS',
#    'lon': -98.0139449,
#    'lat': 37.8625129},
#   {'site_code': '01480887',
#    'name': 'Valley Creek at Ravine Road near Downingtown, PA',
#    'lon': -75.66410518,
#    'lat': 39.9987186},
#   {'site_code': '13039500',
#    'name': 'HENRYS FORK NR LAKE ID',
#    'lon': -111.3497222,
#    'lat': 44.5944444},
#   {'site_code': '02115360',
#    'name': 'YADKIN RIVER AT ENON, NC',
#    'lon': -80.44388889,
#    'lat': 36.13166667},
#   {'site_code': '15302200',
#    'name': 'KOKTULI R NR ILIAMNA AK',
#    'lon': -155.5246895,
#    'lat': 59.7926376},
#   {'site_code': '14169000',
#    'name': 'LONG TOM RIVER NEAR ALVADORE, OR',
#    'lon': -123.2998173,
#    'lat': 44.12345657},
#   {'site_code': '04024000',
#    'name': 'ST. LOUIS RIVER AT SCANLON, MN',
#    'lon': -92.4188018,
#    'lat': 46.7032765},
#   {'site_code': '03401450',
#    'name': 'STONY FORK NEAR MOUTH AT MIDDLESBORO, KY',
#    'lon': -83.7532502,
#    'lat': 36.61424859},
#   {'site_code': '06437000',
#    'name': 'BELLE FOURCHE R NEAR STURGIS,SD',
#    'lon': -103.1368464,
#    'lat': 44.5130418},
#   {'site_code': '06282000',
#    'name': 'SHOSHONE RIVER BELOW BUFFALO BILL RESERVOIR, WY',
#    'lon': -109.0979218,
#    'lat': 44.5166196},
#   {'site_code': '07057370',
#    'name': 'White River near Norfork, AR',
#    'lon': -92.3,
#    'lat': 36.2236111},
#   {'site_code': '11089200',
#    'name': 'COYOTE C NR BUENA PARK CA',
#    'lon': -118.0275,
#    'lat': 33.8711111},
#   {'site_code': '021623961',
#    'name': 'NORTH SALUDA RESERVOIR NEAR TIGERVILLE,SC',
#    'lon': -82.4086111,
#    'lat': 35.14166667},
#   {'site_code': '01049550',
#    'name': 'Togus Stream at Togus, Maine',
#    'lon': -69.6979361,
#    'lat': 44.26613056},
#   {'site_code': '11164500',
#    'name': 'SAN FRANCISQUITO C A STANFORD UNIVERSITY CA',
#    'lon': -122.1894095,
#    'lat': 37.42327257},
#   {'site_code': '03437500',
#    'name': 'SOUTH FORK LITTLE RIVER AT HOPKINSVILLE, KY',
#    'lon': -87.481397,
#    'lat': 36.8394899},
#   {'site_code': '431316095135201',
#    'name': '097N37W17ADDB 71668 1985IGS & USGS LSR-1U IADRN-1',
#    'lon': -95.2303333,
#    'lat': 43.22130556},
#   {'site_code': '430649089181211',
#    'name': 'PERMEABLE PAVEMENT CELL 1 DRAIN TILE AT MADISON,WI',
#    'lon': -89.3033333,
#    'lat': 43.1136111},
#   {'site_code': '373316103592401',
#    'name': 'BIG ARROYO HILLS MET STATION NR HOUGHTON, CO',
#    'lon': -103.9899444,
#    'lat': 37.55438889},
#   {'site_code': '03249498',
#    'name': 'CAVE RUN LAKE NEAR FARMERS, KY',
#    'lon': -83.5335206,
#    'lat': 38.1200817},
#   {'site_code': '07010082',
#    'name': 'Black Creek near Brentwood, MO',
#    'lon': -90.337338,
#    'lat': 38.61671885},
#   {'site_code': '06893590',
#    'name': 'Blue River at 12th Street in Kansas City, MO',
#    'lon': -94.4910278,
#    'lat': 39.09691667},
#   {'site_code': '04163400',
#    'name': 'PLUM BROOK AT UTICA, MI',
#    'lon': -83.0713165,
#    'lat': 42.60142277},
#   {'site_code': '10172875',
#    'name': 'GRANITE CREEK NEAR CALLAO, UT',
#    'lon': -113.8616608,
#    'lat': 39.77771867},
#   {'site_code': '10251375',
#    'name': 'AMARGOSA RV AT DUMONT DUNES NR DEATH VALLEY, CA',
#    'lon': -116.2514107,
#    'lat': 35.6958028},
#   {'site_code': '06918493',
#    'name': 'South Fork Dry Sac River near Springfield, MO',
#    'lon': -93.2494722,
#    'lat': 37.26638889},
#   {'site_code': '02322616',
#    'name': 'CANNON CREEK NEAR LAKE CITY, FL',
#    'lon': -82.667068,
#    'lat': 30.15856477},
#   {'site_code': '03361650',
#    'name': 'SUGAR CREEK AT NEW PALESTINE, IN',
#    'lon': -85.8855359,
#    'lat': 39.71421068},
#   {'site_code': '09370600',
#    'name': 'MANCOS RIVER AT ANITAS FLAT BELOW MANCOS, CO',
#    'lon': -108.3578618,
#    'lat': 37.2524964},
#   {'site_code': '14312600',
#    'name': 'LAKE CREEK AT HIGHWAY 138 NEAR DIAMOND LAKE, OR',
#    'lon': -122.1705889,
#    'lat': 43.25762536},
#   {'site_code': '07377243',
#    'name': 'Sandy Ck at Alph. Forbes nr Greenwell Springs, LA',
#    'lon': -90.9821167,
#    'lat': 30.62110833},
#   ...],
#  'water': [],
#  'no_water': []}

# %%
len(sites_dict.get('unchecked'))
# Out:
# 20495

# %%
with open(filepath, 'w+') as fp:
    json.dump(sites_dict, fp)
