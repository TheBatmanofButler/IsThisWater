# %%
from urllib import request

import json
import os
import random

# %%
MAPBOX_ACCESS_TOKEN = os.environ['MAPBOX_ACCESS_TOKEN']

STATE_CODES = ['AL', 'AK', 'AZ', 'AR', 'CA', 'CO', 'CT', 'DC', 'DE', 'FL', 'GA', 
               'HI', 'ID', 'IL', 'IN', 'IA', 'KS', 'KY', 'LA', 'ME', 'MD', 
               'MA', 'MI', 'MN', 'MS', 'MO', 'MT', 'NE', 'NV', 'NH', 'NJ', 
               'NM', 'NY', 'NC', 'ND', 'OH', 'OK', 'OR', 'PA', 'RI', 'SC', 
               'SD', 'TN', 'TX', 'UT', 'VT', 'VA', 'WA', 'WV', 'WI', 'WY']

filepath = 'sites.json'

# %%
sites_dict = {
    'unchecked': [],
    'water_found': [],
    'water_not_found': []   
}

# %%
def get_sites_for_state(state_code):
    url = 'http://waterservices.usgs.gov/nwis/iv/?format=json&stateCd={}'.format(state_code)
    response = request.urlopen(url)
    sites = json.loads(response.read())['value']['timeSeries']

    return sites


def parse_site_data(site):
    site_info = site['sourceInfo']
    site_code = site_info['siteCode'][0]['value']
    site_geo_info = site_info['geoLocation']['geogLocation']

    name = site_info['siteName']
    lon = site_geo_info['longitude']
    lat = site_geo_info['latitude']

    return site_code, name, lon, lat

# %%
total_sites = 0
unique_sites = set()

for state_code in STATE_CODES:
    sites = get_sites_for_state(state_code)
    num_sites_for_state = 0

    for site in sites:
        site_code, name, lon, lat = parse_site_data(site)
        
        if site_code in unique_sites:
            continue

        unique_sites.add(site_code)
        num_sites_for_state += 1

        sites_dict['unchecked'].append({
            'site_code': site_code,
            'name': name,
            'lon': lon,
            'lat': lat
        })

    total_sites += num_sites_for_state
    print('Data recorded for {} {} sites.'.format(num_sites_for_state, state_code))

print('{} total sites.'.format(total_sites))
# Out:
# Data recorded for 224 AL sites.
# Data recorded for 269 AK sites.
# Data recorded for 425 AZ sites.
# Data recorded for 329 AR sites.
# Data recorded for 1147 CA sites.
# Data recorded for 754 CO sites.
# Data recorded for 105 CT sites.
# Data recorded for 7 DC sites.
# Data recorded for 64 DE sites.
# Data recorded for 1298 FL sites.
# Data recorded for 578 GA sites.
# Data recorded for 280 HI sites.
# Data recorded for 452 ID sites.
# Data recorded for 513 IL sites.
# Data recorded for 483 IN sites.
# Data recorded for 307 IA sites.
# Data recorded for 303 KS sites.
# Data recorded for 269 KY sites.
# Data recorded for 321 LA sites.
# Data recorded for 153 ME sites.
# Data recorded for 263 MD sites.
# Data recorded for 224 MA sites.
# Data recorded for 350 MI sites.
# Data recorded for 312 MN sites.
# Data recorded for 244 MS sites.
# Data recorded for 533 MO sites.
# Data recorded for 362 MT sites.
# Data recorded for 307 NE sites.
# Data recorded for 472 NV sites.
# Data recorded for 79 NH sites.
# Data recorded for 473 NJ sites.
# Data recorded for 734 NM sites.
# Data recorded for 658 NY sites.
# Data recorded for 623 NC sites.
# Data recorded for 186 ND sites.
# Data recorded for 549 OH sites.
# Data recorded for 312 OK sites.
# Data recorded for 578 OR sites.
# Data recorded for 539 PA sites.
# Data recorded for 58 RI sites.
# Data recorded for 374 SC sites.
# Data recorded for 255 SD sites.
# Data recorded for 282 TN sites.
# Data recorded for 950 TX sites.
# Data recorded for 319 UT sites.
# Data recorded for 77 VT sites.
# Data recorded for 559 VA sites.
# Data recorded for 539 WA sites.
# Data recorded for 194 WV sites.
# Data recorded for 516 WI sites.
# Data recorded for 265 WY sites.
# 20467 total sites.

# %%
sites_dict['unchecked'] = random.sample(sites_dict['unchecked'], len(sites_dict['unchecked']))

# %%
sites_dict
# Out:
# {'unchecked': [{'site_code': '1025125356',
#    'name': 'WREN WASH AT YUCCA MTN, NTS, NV',
#    'lon': -116.455,
#    'lat': 36.8597222},
#   {'site_code': '400832074082101',
#    'name': '250429-- Allaire State Park C Obs',
#    'lon': -74.14236318,
#    'lat': 40.142892},
#   {'site_code': '07378500',
#    'name': 'Amite River near Denham Springs, LA',
#    'lon': -90.99038,
#    'lat': 30.464079},
#   {'site_code': '02226180',
#    'name': 'BRUNSWICK RIVER AT ST. SIMONS ISLAND, GA',
#    'lon': -81.3964856,
#    'lat': 31.13356523},
#   {'site_code': '15294100',
#    'name': 'DESHKA R NR WILLOW AK',
#    'lon': -150.3391832,
#    'lat': 61.7675212},
#   {'site_code': '09423000',
#    'name': 'COLORADO RIVER BELOW DAVIS DAM, AZ-NV',
#    'lon': -114.5721876,
#    'lat': 35.19166556},
#   {'site_code': '09486510',
#    'name': 'SANTA CRUZ RIVER NR. RILLITO, AZ.',
#    'lon': -111.1528808,
#    'lat': 32.40507247},
#   {'site_code': '12175000',
#    'name': 'ROSS RESERVOIR NEAR NEWHALEM, WA',
#    'lon': -121.0684535,
#    'lat': 48.73262959},
#   {'site_code': '261008081023700',
#    'name': 'I-75 BRIDGE STR-Z AT MILE 61.1 NEAR NAPLES, FL',
#    'lon': -81.0436111,
#    'lat': 26.16888889},
#   {'site_code': '03431000',
#    'name': 'MILL CREEK NEAR ANTIOCH, TN',
#    'lon': -86.6807333,
#    'lat': 36.08159827},
#   {'site_code': '07358570',
#    'name': 'Gulpha Cr at Ridgeway St at Hot Springs, AR',
#    'lon': -93.0065,
#    'lat': 34.494},
#   {'site_code': '452111093523402',
#    'name': 'ALUS-35   033N28W18ACB   02             0000620723',
#    'lon': -93.8812111,
#    'lat': 45.3574361},
#   {'site_code': '01649500',
#    'name': 'NORTHEAST BRANCH ANACOSTIA RIVER AT RIVERDALE, MD',
#    'lon': -76.9259722,
#    'lat': 38.96025},
#   {'site_code': '03364340',
#    'name': 'HAW CREEK AT EAST COLUMBUS, IN',
#    'lon': -85.9094444,
#    'lat': 39.20027778},
#   {'site_code': '03353910',
#    'name': 'EAST FORK WHITE LICK CREEK AT MOORESVILLE, IN',
#    'lon': -86.357215,
#    'lat': 39.6283796},
#   {'site_code': '412746081380100',
#    'name': 'CU-42',
#    'lon': -81.6336917,
#    'lat': 41.4627333},
#   {'site_code': '06394000',
#    'name': 'BEAVER CREEK NEAR NEWCASTLE, WYO.',
#    'lon': -104.117713,
#    'lat': 43.53525197},
#   {'site_code': '0167357970',
#    'name': 'MONCUIN CREEK BELOW US HWY 360 NEAR MANQUIN, VA',
#    'lon': -77.1463611,
#    'lat': 37.71225},
#   {'site_code': '251946080254800',
#    'name': 'EVERGLADES 1 IN C-111 BASIN NR HOMESTEAD, FL',
#    'lon': -80.4351667,
#    'lat': 25.33033333},
#   {'site_code': '345833106400501',
#    'name': '09N.02E.30.322 SE USGS Well at Valle de Oro',
#    'lon': -106.6680833,
#    'lat': 34.97601667},
#   {'site_code': '263845081260703',
#    'name': 'HE - 851',
#    'lon': -81.4350763,
#    'lat': 26.64618116},
#   {'site_code': '07010030',
#    'name': 'River Des Peres Tributary at Pagedale, MO',
#    'lon': -90.3148333,
#    'lat': 38.67688889},
#   {'site_code': '13342250',
#    'name': 'SWEETWATER CREEK BEL SWEETWATER CANAL DIV NR WAHA',
#    'lon': -116.8522222,
#    'lat': 46.2719444},
#   {'site_code': '07250974',
#    'name': 'Jack Creek near Winfrey, AR',
#    'lon': -94.0916667,
#    'lat': 35.70444444},
#   {'site_code': '12170310',
#    'name': 'UNNAMED TRIBUTARY SKAGIT BAY CAMANO ISLAND, WA',
#    'lon': -122.4623815,
#    'lat': 48.2545441},
#   {'site_code': '02233484',
#    'name': 'ECONLOCKHATCHEE RIVER NEAR OVIEDO, FL',
#    'lon': -81.169786,
#    'lat': 28.65555285},
#   {'site_code': '02273230',
#    'name': 'C-41 CANAL NEAR BRIGHTON, FL',
#    'lon': -81.201458,
#    'lat': 27.21393588},
#   {'site_code': '04227000',
#    'name': 'CANASERAGA CREEK AT SHAKERS CROSSING NY',
#    'lon': -77.8405556,
#    'lat': 42.73694444},
#   {'site_code': '01569775',
#    'name': 'Alexander Spring Creek near Plainfield, PA',
#    'lon': -77.2622055,
#    'lat': 40.16897719},
#   {'site_code': '270959082203002',
#    'name': 'ROMP 19 WUAM WELL NEAR SARASOTA FL',
#    'lon': -82.3414825,
#    'lat': 27.16671917},
#   {'site_code': '351058106385902',
#    'name': 'T11N.R3E.17.142B PDN.EBM-T2',
#    'lon': -106.6497389,
#    'lat': 35.18286667},
#   {'site_code': '06024510',
#    'name': 'West Fork Ruby Creek near Wisdom MT',
#    'lon': -113.7638222,
#    'lat': 45.54681667},
#   {'site_code': '10242300',
#    'name': 'PINTO CREEK NEAR NEWCASTLE, UTAH',
#    'lon': -113.515793,
#    'lat': 37.62553137},
#   {'site_code': '09024000',
#    'name': 'FRASER RIVER AT WINTER PARK, CO.',
#    'lon': -105.7766741,
#    'lat': 39.89998695},
#   {'site_code': '372223080234801',
#    'name': '27G  1 SOW 232',
#    'lon': -80.39666389,
#    'lat': 37.37315},
#   {'site_code': '380626121384702',
#    'name': 'TWITCHELL ISL DEMO PROJ E POND SITE 6 NR RIO VISTA',
#    'lon': -121.6464917,
#    'lat': 38.10717778},
#   {'site_code': '351609079343701',
#    'name': 'MO-247 SEVEN LAKES 1 NR WEST END,NC (BLACK CREEK)',
#    'lon': -79.5769444,
#    'lat': 35.26916667},
#   {'site_code': '011277905',
#    'name': 'LATIMER BROOK NR I-95N EXIT 75 NR FLANDERS, CT',
#    'lon': -72.2022222,
#    'lat': 41.3686111},
#   {'site_code': '433531092265301',
#    'name': 'NTR3-1    North Drained Site Transect 3',
#    'lon': -92.4479694,
#    'lat': 43.59199444},
#   {'site_code': '02312500',
#    'name': 'WITHLACOOCHEE RIVER AT CROOM, FL',
#    'lon': -82.222032,
#    'lat': 28.5927714},
#   {'site_code': '303227097404504',
#    'name': 'UBCWCID Dam 11 nr Round Rock, TX',
#    'lon': -97.6787944,
#    'lat': 30.54131389},
#   {'site_code': '021973405',
#    'name': 'C-001 AT SAVANNAH RIVER SITE, SC',
#    'lon': -81.6812228,
#    'lat': 33.2537577},
#   {'site_code': '07064440',
#    'name': 'Current River at Montauk State Park, MO',
#    'lon': -91.6712593,
#    'lat': 37.44837816},
#   {'site_code': '04280450',
#    'name': 'METTAWEE RIVER NEAR MIDDLE GRANVILLE NY',
#    'lon': -73.2841667,
#    'lat': 43.46388889},
#   {'site_code': '09371520',
#    'name': 'MCELMO CREEK ABOVE TRAIL CANYON NEAR CORTEZ, CO',
#    'lon': -108.7006527,
#    'lat': 37.3266601},
#   {'site_code': '03216350',
#    'name': 'LITTLE SANDY RIVER BELOW GRAYSON DAM NEAR LEON, KY',
#    'lon': -82.9910027,
#    'lat': 38.25397068},
#   {'site_code': '02312700',
#    'name': 'OUTLET RIVER AT PANACOOCHEE RETREATS, FL',
#    'lon': -82.1528658,
#    'lat': 28.8002651},
#   {'site_code': '07362590',
#    'name': 'Lake Winona at Reform, AR',
#    'lon': -92.8513889,
#    'lat': 34.79777778},
#   {'site_code': '11304810',
#    'name': 'SAN JOAQUIN R BL GARWOOD BRIDGE A STOCKTON CA',
#    'lon': -121.3302245,
#    'lat': 37.93547987},
#   {'site_code': '02420000',
#    'name': 'ALABAMA RIVER NEAR MONTGOMERY, AL.',
#    'lon': -86.40830579,
#    'lat': 32.41152597},
#   {'site_code': '07258500',
#    'name': 'Petit Jean River near Booneville, AR',
#    'lon': -93.9236111,
#    'lat': 35.10694444},
#   {'site_code': '08389055',
#    'name': 'RIO BONITO NEAR LINCOLN, NM',
#    'lon': -105.4644444,
#    'lat': 33.5236111},
#   {'site_code': '340503117104104',
#    'name': '001S003W15K004S',
#    'lon': -117.1772083,
#    'lat': 34.0843222},
#   {'site_code': '06883940',
#    'name': ' BIG SANDY CR AT ALEXANDRIA, NE',
#    'lon': -97.3880556,
#    'lat': 40.23527778},
#   {'site_code': '07242350',
#    'name': 'Deep Fork near Arcadia, OK',
#    'lon': -97.3600365,
#    'lat': 35.64727889},
#   {'site_code': '422622122004000',
#    'name': 'MID-NORTH - LOWER  - MDNL',
#    'lon': -122.0122388,
#    'lat': 42.43916489},
#   {'site_code': '09439000',
#    'name': 'GILA RIVER AT DUNCAN, AZ',
#    'lon': -109.0991667,
#    'lat': 32.72444444},
#   {'site_code': '340508117163306',
#    'name': '001S004W14E013S',
#    'lon': -117.2758694,
#    'lat': 34.08556944},
#   {'site_code': '09337000',
#    'name': 'PINE CREEK NEAR ESCALANTE, UT',
#    'lon': -111.6360113,
#    'lat': 37.86248747},
#   {'site_code': '385601085365701',
#    'name': 'JENNINGS 3 (JN 3)',
#    'lon': -85.6158002,
#    'lat': 38.93366619},
#   {'site_code': '351345116382701',
#    'name': 'Temperature Rod GS-1',
#    'lon': -116.6409722,
#    'lat': 35.22952778},
#   {'site_code': '350400106393702',
#    'name': '10N.03E.30.232J BWRM',
#    'lon': -106.6600889,
#    'lat': 35.06669444},
#   {'site_code': '332535117341001',
#    'name': 'CRISTIANITOS C PRECIP GAGE AB SAN MATEO C',
#    'lon': -117.5703242,
#    'lat': 33.42641717},
#   {'site_code': '02061500',
#    'name': 'BIG OTTER RIVER NEAR EVINGTON, VA',
#    'lon': -79.3036357,
#    'lat': 37.20847738},
#   {'site_code': '390438084310701',
#    'name': 'A21D0075',
#    'lon': -84.5185539,
#    'lat': 39.0772824},
#   {'site_code': '07292500',
#    'name': 'HOMOCHITTO RIVER AT ROSETTA, MS',
#    'lon': -91.1094444,
#    'lat': 31.3247222},
#   {'site_code': '372319104073301',
#    'name': 'BROWN SHEEP CAMP MET STATION NEAR TYRONE, CO,',
#    'lon': -104.1263582,
#    'lat': 37.38862664},
#   {'site_code': '371151116294102',
#    'name': '228  S08 E49 34    2    ER-EC-11 deep',
#    'lon': -116.4956507,
#    'lat': 37.19749199},
#   {'site_code': '14096850',
#    'name': 'BEAVER CREEK BELOW QUARTZ CREEK, NR SIMNASHO, OR',
#    'lon': -121.3942286,
#    'lat': 44.9587272},
#   {'site_code': '02234384',
#    'name': 'SOLDIER CREEK NEAR LONGWOOD, FL',
#    'lon': -81.308678,
#    'lat': 28.71888466},
#   {'site_code': '07260990',
#    'name': 'North Fork Cadron Creek near Quitman, AR',
#    'lon': -92.2969444,
#    'lat': 35.39416667},
#   {'site_code': '350900089482300',
#    'name': 'Sh:Q-001',
#    'lon': -89.8061111,
#    'lat': 35.1500833},
#   {'site_code': '11173200',
#    'name': 'ARROYO HONDO NR SAN JOSE CA',
#    'lon': -121.769397,
#    'lat': 37.46160337},
#   {'site_code': '373745118554002',
#    'name': '004S028E06L002M',
#    'lon': -118.9287433,
#    'lat': 37.6291015},
#   {'site_code': '10172791',
#    'name': 'SETTLEMENT CREEK ABOVE RESERVOIR NEAR TOOELE, UT',
#    'lon': -112.2905017,
#    'lat': 40.50549997},
#   {'site_code': '06919900',
#    'name': 'Sac River near Caplinger Mills, MO',
#    'lon': -93.8031667,
#    'lat': 37.8698333},
#   {'site_code': '03157000',
#    'name': 'Clear Creek near Rockbridge OH',
#    'lon': -82.5784946,
#    'lat': 39.5883982},
#   {'site_code': '360246114443012',
#    'name': 'BOULDER BASIN MONITORING STATION (56 METER DEPTH)',
#    'lon': -114.7416667,
#    'lat': 36.0461111},
#   {'site_code': '11148500',
#    'name': 'ESTRELLA R NR ESTRELLA CA',
#    'lon': -120.6401683,
#    'lat': 35.71719096},
#   {'site_code': '07227420',
#    'name': 'Cramer Ck at US Hwy 54 nr Dalhart, TX',
#    'lon': -102.8931667,
#    'lat': 35.75125},
#   {'site_code': '05526000',
#    'name': 'IROQUOIS RIVER NEAR CHEBANSE, IL',
#    'lon': -87.8233719,
#    'lat': 41.0089215},
#   {'site_code': '412541081194500',
#    'name': 'GE-363',
#    'lon': -81.33188889,
#    'lat': 41.4281111},
#   {'site_code': '01589197',
#    'name': 'GWYNNS FALLS NEAR DELIGHT, MD',
#    'lon': -76.7834167,
#    'lat': 39.44294444},
#   {'site_code': '04214500',
#    'name': 'BUFFALO CREEK AT GARDENVILLE NY',
#    'lon': -78.755,
#    'lat': 42.8547222},
#   {'site_code': '11526400',
#    'name': 'TRINITY R AB NF TRINITY R NR HELENA CA',
#    'lon': -123.1144757,
#    'lat': 40.76653148},
#   {'site_code': '06637750',
#    'name': 'ROCK CREEK ABOVE ROCK CREEK RESERVOIR, WY',
#    'lon': -108.7752778,
#    'lat': 42.5497222},
#   {'site_code': '04201400',
#    'name': 'West Branch Rocky River at West View OH',
#    'lon': -81.9031933,
#    'lat': 41.3508833},
#   {'site_code': '254707080370201',
#    'name': 'EDEN 10 IN WATER CONSERVATION AREA 3-B',
#    'lon': -80.6172222,
#    'lat': 25.78527778},
#   {'site_code': '01379699',
#    'name': 'Rockaway River at NJ Rt 15 at Berkshire Valley NJ',
#    'lon': -74.59138889,
#    'lat': 40.93416667},
#   {'site_code': '05536123',
#    'name': 'CHICAGO RIVER AT COLUMBUS DRIVE AT CHICAGO, IL',
#    'lon': -87.6211634,
#    'lat': 41.88836628},
#   {'site_code': '01594800',
#    'name': 'ST LEONARD CREEK NEAR ST LEONARD, MD',
#    'lon': -76.49513889,
#    'lat': 38.44891667},
#   {'site_code': '07119700',
#    'name': 'ARKANSAS RIVER AT CATLIN DAM, NEAR FOWLER, CO.',
#    'lon': -103.9119006,
#    'lat': 38.12583934},
#   {'site_code': '371459079560300',
#    'name': 'MET STATION AT MILL MOUNTAIN PARK AT ROANOKE, VA',
#    'lon': -79.9340278,
#    'lat': 37.24980556},
#   {'site_code': '12469500',
#    'name': 'LENORE LK NEAR SOAP LK, WA',
#    'lon': -119.5028148,
#    'lat': 47.5143084},
#   {'site_code': '11299997',
#    'name': 'STANISLAUS R BL TULLOCH PP NR KNIGHTS FERRY CA',
#    'lon': -120.6052025,
#    'lat': 37.87603788},
#   {'site_code': '340334110050300',
#    'name': 'FAUGHT RIDGE PRECIP NEAR PINETOP-LAKESIDE, AZ',
#    'lon': -110.08415,
#    'lat': 34.05941667},
#   {'site_code': '01570030',
#    'name': 'Unnamed Trib to Trindle Sp Run, Site 2, nr Mechbrg',
#    'lon': -76.9966426,
#    'lat': 40.23814486},
#   {'site_code': '07343200',
#    'name': 'Sulphur Rv nr Talco, TX',
#    'lon': -95.1324428,
#    'lat': 33.3862233},
#   {'site_code': '01451650',
#    'name': 'Little Lehigh Creek at Tenth St. Br. at Allentown',
#    'lon': -75.4740717,
#    'lat': 40.59648637},
#   {'site_code': '10310000',
#    'name': 'W FK CARSON RV AT WOODFORDS, CA',
#    'lon': -119.833789,
#    'lat': 38.76962765},
#   {'site_code': '01372051',
#    'name': 'FALL KILL AT POUGHKEEPSIE NY',
#    'lon': -73.9261111,
#    'lat': 41.71},
#   {'site_code': '05357205',
#    'name': 'ALLEQUASH CREEK NEAR SAYNER, WI',
#    'lon': -89.5993944,
#    'lat': 46.0308444},
#   {'site_code': '03111500',
#    'name': 'Short Creek near Dillonvale OH',
#    'lon': -80.7342482,
#    'lat': 40.19340427},
#   {'site_code': '06719560',
#    'name': 'LENA GULCH AT LAKEWOOD, CO',
#    'lon': -105.1488333,
#    'lat': 39.74040278},
#   {'site_code': '03159246',
#    'name': 'Sunday Creek below Millfield OH',
#    'lon': -82.1009782,
#    'lat': 39.42979358},
#   {'site_code': '01616400',
#    'name': 'MILL CREEK AT BUNKER HILL, WV',
#    'lon': -78.0534361,
#    'lat': 39.334625},
#   {'site_code': '351536080410645',
#    'name': 'CRN-65 RAINGAGE AT REEDY CREEK ELEMENTARY SCHOOL',
#    'lon': -80.685,
#    'lat': 35.26},
#   {'site_code': '431312089475301',
#    'name': 'DN-09/06E/29-0083',
#    'lon': -89.7999167,
#    'lat': 43.22294444},
#   {'site_code': '12102075',
#    'name': 'CLARKS CREEK AT TACOMA ROAD NEAR PUYALLUP, WA',
#    'lon': -122.337343,
#    'lat': 47.19760016},
#   {'site_code': '340447118442301',
#    'name': 'CORRAL CANYON PRECIP GAGE NR MALIBU CA',
#    'lon': -118.7397222,
#    'lat': 34.0797222},
#   {'site_code': '06332000',
#    'name': 'WHITE EARTH RIVER AT WHITE EARTH, ND',
#    'lon': -102.7672222,
#    'lat': 48.37555556},
#   {'site_code': '05573540',
#    'name': 'SANGAMON RIVER AT ROUTE 48 AT DECATUR, IL',
#    'lon': -88.9764673,
#    'lat': 39.83114814},
#   {'site_code': '02310075',
#    'name': 'ANCLOTE RIVER NEAR HOLIDAY FL',
#    'lon': -82.7193056,
#    'lat': 28.1744722},
#   {'site_code': '07342500',
#    'name': 'S Sulphur Rv nr Cooper, TX',
#    'lon': -95.5949562,
#    'lat': 33.356499},
#   {'site_code': '022313219',
#    'name': 'S-253 WEIR UPSTREAM NEAR FORT DRUM, FL',
#    'lon': -80.6790194,
#    'lat': 27.5909972},
#   {'site_code': '254151080214304',
#    'name': 'G  -3906',
#    'lon': -80.3620222,
#    'lat': 25.69770833},
#   {'site_code': '294327095445201',
#    'name': 'JY-65-29-106 (Fort Bend Extensometer)',
#    'lon': -95.7477778,
#    'lat': 29.72416667},
#   {'site_code': '16400000',
#    'name': 'Halawa Stream near Halawa, Molokai, HI',
#    'lon': -156.7619722,
#    'lat': 21.1555},
#   {'site_code': '06800000',
#    'name': 'Maple Creek near Nickerson, Nebr.',
#    'lon': -96.5408333,
#    'lat': 41.56116667},
#   {'site_code': '12353650',
#    'name': 'Clark Fork at Superior, MT',
#    'lon': -114.890409,
#    'lat': 47.19631608},
#   {'site_code': '01409400',
#    'name': 'Mullica River near Batsto NJ',
#    'lon': -74.665,
#    'lat': 39.67444444},
#   {'site_code': '405256091012601',
#    'name': 'MISSISSIPPI RIVER AT LOCK & DAM 18 (CORPS)',
#    'lon': -91.0240323,
#    'lat': 40.8822604},
#   {'site_code': '08388450',
#    'name': 'BONITO LAKE NEAR ALTO, NM',
#    'lon': -105.7349722,
#    'lat': 33.4565833},
#   {'site_code': '441748088133701',
#    'name': 'TRT WETLAND ONE SURFACE INLET NR KAUKAUNA, WI',
#    'lon': -88.2269444,
#    'lat': 44.29666667},
#   {'site_code': '09295000',
#    'name': 'DUCHESNE RIVER AT MYTON, UT',
#    'lon': -110.0637613,
#    'lat': 40.20023757},
#   {'site_code': '01389765',
#    'name': 'Molly Ann Brook at North Haledon NJ',
#    'lon': -74.1847222,
#    'lat': 40.95305556},
#   {'site_code': '06610785',
#    'name': 'West Papillion Creek at Millard, Nebr.',
#    'lon': -96.1276111,
#    'lat': 41.2073611},
#   {'site_code': '094985005',
#    'name': 'PINTO CREEK ABOVE HAUNTED CANYON NR MIAMI, AZ',
#    'lon': -110.9986111,
#    'lat': 33.4058333},
#   {'site_code': '13161070',
#    'name': 'SIMPLOT NO.4 FARM CANAL NR GRAND VIEW ID',
#    'lon': -115.9834264,
#    'lat': 42.9698932},
#   {'site_code': '06889630',
#    'name': 'SHUNGANUNGA C AT TOPEKA, KS',
#    'lon': -95.685815,
#    'lat': 39.02972276},
#   {'site_code': '382006121401601',
#    'name': 'LIBERTY ISLAND A LIBERTY CUT NR COURTLAND CA',
#    'lon': -121.6711083,
#    'lat': 38.33500556},
#   {'site_code': '02301718',
#    'name': 'ALAFIA RIVER AT RIVERVIEW FL',
#    'lon': -82.3198141,
#    'lat': 27.86780308},
#   {'site_code': '343108092585201',
#    'name': '02S18W30BBD1 CKM',
#    'lon': -92.9811667,
#    'lat': 34.51875},
#   {'site_code': '09182400',
#    'name': 'CASTLE CREEK BELOW CASTLE VALLEY NEAR MOAB, UT',
#    'lon': -109.4501174,
#    'lat': 38.6738712},
#   {'site_code': '422202083023301',
#    'name': 'RECOVERY PARK SOUTH 06 SHALLOW (RP-S-06 S)',
#    'lon': -83.0424778,
#    'lat': 42.36713056},
#   {'site_code': '03440000',
#    'name': 'CATHEYS CREEK NEAR BREVARD, NC',
#    'lon': -82.7831834,
#    'lat': 35.21122316},
#   {'site_code': '0414826545',
#    'name': 'TRIB (TILE) TO LUM DRAIN NEAR SWARTZ CREEK, MI',
#    'lon': -83.7902778,
#    'lat': 42.91194444},
#   {'site_code': '384428119191301',
#    'name': 'SARONI CANAL 2.1 SW/GW - CANAL SW',
#    'lon': -119.3202778,
#    'lat': 38.7411111},
#   {'site_code': '262331082383202',
#    'name': 'L  -5673',
#    'lon': -81.7271944,
#    'lat': 26.39205556},
#   {'site_code': '10290500',
#    'name': 'ROBINSON CK AT TWIN LKS OUTLET NR BRIDGEPORT, CA',
#    'lon': -119.3246032,
#    'lat': 38.17214225},
#   {'site_code': '07109500',
#    'name': 'ARKANSAS RIVER NEAR AVONDALE, CO.',
#    'lon': -104.3991356,
#    'lat': 38.24805799},
#   {'site_code': '261004081082000',
#    'name': 'I-75 CULVERT AT MILE 67 NEAR NAPLES, FL',
#    'lon': -81.13888889,
#    'lat': 26.16777778},
#   {'site_code': '324003114235701',
#    'name': 'C-09-21 10ABC1 [FORTUNA WASH WELL]',
#    'lon': -114.3998647,
#    'lat': 32.6675595},
#   {'site_code': '09074000',
#    'name': 'HUNTER CREEK NEAR ASPEN, CO',
#    'lon': -106.797538,
#    'lat': 39.20582037},
#   {'site_code': '07178035',
#    'name': 'Mingo Creek at 36th Street North at Tulsa, OK',
#    'lon': -95.8591567,
#    'lat': 36.20620625},
#   {'site_code': '01209700',
#    'name': 'NORWALK RIVER AT SOUTH WILTON, CT',
#    'lon': -73.4195444,
#    'lat': 41.16376667},
#   {'site_code': '03528000',
#    'name': 'CLINCH RIVER ABOVE TAZEWELL, TN',
#    'lon': -83.3982345,
#    'lat': 36.425087},
#   {'site_code': '350635080513245',
#    'name': 'CRN-56 RAINGAGE AT SOUTH MECK HIGH SCHOOL',
#    'lon': -80.8591667,
#    'lat': 35.10944444},
#   {'site_code': '04103010',
#    'name': 'KALAMAZOO RIVER NEAR MARENGO, MI',
#    'lon': -84.8558115,
#    'lat': 42.26170826},
#   {'site_code': '295826095082200',
#    'name': 'Lk Houston S Union Pacific RR Bridge nr Houston,TX',
#    'lon': -95.1393833,
#    'lat': 29.97393333},
#   {'site_code': '06764880',
#    'name': 'South Platte River at Roscoe, Nebr.',
#    'lon': -101.5766667,
#    'lat': 41.1261111},
#   {'site_code': '06903400',
#    'name': 'Chariton River near Chariton, IA',
#    'lon': -93.2598477,
#    'lat': 40.95189005},
#   {'site_code': '365325120391504',
#    'name': '012S012E16H005M',
#    'lon': -120.6554167,
#    'lat': 36.8903333},
#   {'site_code': '01388910',
#    'name': 'Pompton River at Mountain View NJ',
#    'lon': -74.2705556,
#    'lat': 40.91444444},
#   {'site_code': '381619081392901',
#    'name': ' Kan-0192',
#    'lon': -81.6591667,
#    'lat': 38.27166667},
#   {'site_code': '01473800',
#    'name': 'Schuylkill River at Manayunk, Philadelphia, PA',
#    'lon': -75.2282354,
#    'lat': 40.02816755},
#   {'site_code': '07231000',
#    'name': 'Little River near Sasakwa, OK',
#    'lon': -96.5125113,
#    'lat': 34.9653615},
#   {'site_code': '06632400',
#    'name': 'ROCK CREEK AB KING CANYON CANAL, NR ARLINGTON, WY',
#    'lon': -106.2227908,
#    'lat': 41.58524549},
#   {'site_code': '04293200',
#    'name': 'MUD CREEK AT BEAR MOUNTAIN RD, NEAR NORTH TROY, VT',
#    'lon': -72.3591667,
#    'lat': 44.9983333},
#   {'site_code': '14202980',
#    'name': 'SCOGGINS CK BLW HENRY HAGG LAKE, NR GASTON, OR',
#    'lon': -123.200109,
#    'lat': 45.46927968},
#   {'site_code': '01472000',
#    'name': 'Schuylkill River at Pottstown, PA',
#    'lon': -75.6515752,
#    'lat': 40.2417631},
#   {'site_code': '03353890',
#    'name': 'EAST FORK WHITE LICK CREEK NEAR CAMBY, IN',
#    'lon': -86.3333254,
#    'lat': 39.68948987},
#   {'site_code': '06221400',
#    'name': 'DINWOODY CREEK ABOVE LAKES, NEAR BURRIS, WY',
#    'lon': -109.4087778,
#    'lat': 43.34616667},
#   {'site_code': '03106280',
#    'name': 'Lake Arthur at Moraine State Park, PA',
#    'lon': -80.1211704,
#    'lat': 40.9625628},
#   {'site_code': '06317020',
#    'name': 'WILD HORSE CREEK NEAR ARVADA, WY',
#    'lon': -106.0319671,
#    'lat': 44.6324821},
#   {'site_code': '06659580',
#    'name': 'SAND CREEK AT COLORADO-WYOMING STATE LINE',
#    'lon': -105.7597028,
#    'lat': 40.99365},
#   {'site_code': '01439800',
#    'name': 'Big Flat Brook near Hainesville NJ',
#    'lon': -74.8036111,
#    'lat': 41.20694444},
#   {'site_code': '12439500',
#    'name': 'OKANOGAN RIVER AT OROVILLE, WA',
#    'lon': -119.4203419,
#    'lat': 48.9307184},
#   {'site_code': '394215074561702',
#    'name': '070477-- New Brooklyn Park 2 Obs',
#    'lon': -74.93766569,
#    'lat': 39.7042823},
#   {'site_code': '06309200',
#    'name': 'MIDDLE FORK POWDER RIVER NEAR BARNUM, WY',
#    'lon': -107.1383995,
#    'lat': 43.57773999},
#   {'site_code': '07364133',
#    'name': 'Bayou Bartholomew at Garrett Bridge, AR',
#    'lon': -91.6561111,
#    'lat': 33.86638889},
#   {'site_code': '411403112200801',
#    'name': 'BEAR RIVER BAY OUTFLOW AT GSL MINERALS CORP BRIDGE',
#    'lon': -112.356111,
#    'lat': 41.27138889},
#   {'site_code': '06803502',
#    'name': 'Deadmans Run at 38th Street at Lincoln, Nebr.',
#    'lon': -96.6655583,
#    'lat': 40.83536389},
#   {'site_code': '02310000',
#    'name': 'ANCLOTE RIVER NEAR ELFERS FL',
#    'lon': -82.6664882,
#    'lat': 28.21417784},
#   {'site_code': '05545750',
#    'name': 'FOX RIVER NEAR NEW MUNSTER, WI',
#    'lon': -88.225923,
#    'lat': 42.61085116},
#   {'site_code': '0209782609',
#    'name': 'WHITE OAK CR AT MOUTH NEAR GREEN LEVEL, NC',
#    'lon': -78.9202778,
#    'lat': 35.76027778},
#   {'site_code': '0535739503',
#    'name': 'LITTLE TURTLE RIVER AT GARNET STREET AT MERCER, WI',
#    'lon': -90.0593311,
#    'lat': 46.16355979},
#   {'site_code': '350359106335206',
#    'name': '10N.04E.30.134F CESAR CHAVEZ SHALLOW OBS-1F',
#    'lon': -106.5645694,
#    'lat': 35.06649167},
#   {'site_code': '403746105231301',
#    'name': 'HIGH PARK PRECIP AT SKY CORRAL NR STOVE PRAIRIE CO',
#    'lon': -105.3868333,
#    'lat': 40.6293611},
#   {'site_code': '10167450',
#    'name': 'LTL COTTONWOOD CR @TANNER FLT CPGD NR ALTA, UT',
#    'lon': -111.7007608,
#    'lat': 40.56994975},
#   {'site_code': '451726122461800',
#    'name': 'UNNAMED CR NR MOUTH AT RM 38.7 NR WILSONVILLE, OR',
#    'lon': -122.7716667,
#    'lat': 45.29063889},
#   {'site_code': '15087700',
#    'name': 'INDIAN R AT SITKA AK',
#    'lon': -135.3162085,
#    'lat': 57.05297119},
#   {'site_code': '402504074414201',
#    'name': 'Skillman USGS unheated rain gage NJ',
#    'lon': -74.6946042,
#    'lat': 40.4178833},
#   {'site_code': '440823070291501',
#    'name': 'ME-OW1214 Oxford, Maine',
#    'lon': -70.4870029,
#    'lat': 44.1397931},
#   {'site_code': '08034500',
#    'name': 'Mud Ck nr Jacksonville, TX',
#    'lon': -95.1607787,
#    'lat': 31.97655578},
#   {'site_code': '402736088523902',
#    'name': '23N3E-9.6a3',
#    'lon': -88.8773861,
#    'lat': 40.4600222},
#   {'site_code': '08158000',
#    'name': 'Colorado Rv at Austin, TX',
#    'lon': -97.6800556,
#    'lat': 30.24613889},
#   {'site_code': '07331000',
#    'name': 'Washita River near Dickson, OK',
#    'lon': -96.9758447,
#    'lat': 34.23342725},
#   {'site_code': '02329184',
#    'name': 'MEGGINNIS ARM TRIB AB I-10 AT TALLAHASSEE, FLA.',
#    'lon': -84.3001787,
#    'lat': 30.48381079},
#   {'site_code': '07346310',
#    'name': '(COE) Caddo Lake at Dam near Mooringsport, LA',
#    'lon': -93.9146254,
#    'lat': 32.71014469},
#   {'site_code': '05120500',
#    'name': 'WINTERING RIVER NR KARLSRUHE, ND',
#    'lon': -100.5398623,
#    'lat': 48.13833739},
#   {'site_code': '350638106413702',
#    'name': '10N.02E.11.244A WEST BLUFF NO. 1',
#    'lon': -106.6946222,
#    'lat': 35.11000556},
#   {'site_code': '422308088231001',
#    'name': '45N7E-11.5a1 (8-GRN-I)',
#    'lon': -88.3861111,
#    'lat': 42.38555556},
#   {'site_code': '01342730',
#    'name': 'STEELE CREEK AT ILION NY',
#    'lon': -75.0416667,
#    'lat': 43.0065833},
#   {'site_code': '06752260',
#    'name': 'CACHE LA POUDRE RIVER AT FORT COLLINS, CO',
#    'lon': -105.0692222,
#    'lat': 40.5880833},
#   {'site_code': '413611087200903',
#    'name': 'CITY HALL RAIN GARDEN OVERFLOW AT GARY, IN',
#    'lon': -87.3358333,
#    'lat': 41.60305556},
#   {'site_code': '385952119103901',
#    'name': 'CAMPBELL DITCH 1 SW/GW - CANAL SW',
#    'lon': -119.1775,
#    'lat': 38.99777778},
#   {'site_code': '16200000',
#    'name': 'NF Kaukonahua Str abv RB, nr Wahiawa, Oahu, HI',
#    'lon': -157.9453056,
#    'lat': 21.51627778},
#   {'site_code': '365530077104006',
#    'name': '53D 10 SOW 179E',
#    'lon': -77.17746768,
#    'lat': 36.9251502},
#   {'site_code': '331944082025501',
#    'name': '29AA42',
#    'lon': -82.0492778,
#    'lat': 33.32955556},
#   {'site_code': '08279000',
#    'name': 'EMBUDO CREEK AT DIXON, NM',
#    'lon': -105.9136306,
#    'lat': 36.21085556},
#   {'site_code': '09527590',
#    'name': 'COACHELLA CANAL ABOVE ALL-AMERICAN CANAL DIVERSION',
#    'lon': -114.9438889,
#    'lat': 32.71416667},
#   {'site_code': '06889160',
#    'name': 'SOLDIER C NR CIRCLEVILLE, KS',
#    'lon': -95.9505944,
#    'lat': 39.4631449},
#   {'site_code': '08177500',
#    'name': 'Coleto Ck nr Victoria, TX',
#    'lon': -97.1386004,
#    'lat': 28.73110317},
#   {'site_code': '340456116362101',
#    'name': 'BIG MORONGO CYN PRECIP GAGE NR MORONGO VALLEY CA',
#    'lon': -116.6058333,
#    'lat': 34.0822222},
#   {'site_code': '05406524',
#    'name': 'HALFWAY PRAIRIE CREEK @ HUDSON RD AT MAZOMANIE, WI',
#    'lon': -89.7802778,
#    'lat': 43.17666667},
#   {'site_code': '351028080385545',
#    'name': 'CRN-32 RAINGAGE AT BAIN ELEMENTARY SCHOOL',
#    'lon': -80.6483333,
#    'lat': 35.1747222},
#   {'site_code': '03031624',
#    'name': 'Sandy Lick Creek at Dubois, PA',
#    'lon': -78.7638861,
#    'lat': 41.1254972},
#   {'site_code': '395246105111800',
#    'name': 'SMART DITCH ABOVE POND D-1 AT ROCKY FLATS PLANT',
#    'lon': -105.1877651,
#    'lat': 39.8791529},
#   {'site_code': '02228070',
#    'name': 'SATILLA RIVER AT US 17, AT WOODBINE, GA',
#    'lon': -81.725662,
#    'lat': 30.97467607},
#   {'site_code': '310427084591101',
#    'name': '06G006',
#    'lon': -84.9863169,
#    'lat': 31.07435},
#   {'site_code': '07176950',
#    'name': 'Hominy Creek near Hominy, OK',
#    'lon': -96.3789064,
#    'lat': 36.4736793},
#   {'site_code': '07234100',
#    'name': 'Clear Creek near Elmwood, OK',
#    'lon': -100.5023688,
#    'lat': 36.64502788},
#   {'site_code': '05451770',
#    'name': 'Iowa River at County Highway E49 near Tama, IA',
#    'lon': -92.63655,
#    'lat': 41.96425556},
#   {'site_code': '384537104494701',
#    'name': 'OAK MEADOW PARK MET STATION AT CO. SPRNGS, CO',
#    'lon': -104.8297778,
#    'lat': 38.76016667},
#   {'site_code': '08166250',
#    'name': 'Guadalupe Rv nr Center Point, TX',
#    'lon': -99.11,
#    'lat': 29.98777778},
#   {'site_code': '345902106410701',
#    'name': '09N.02E.25.122P PEDSW',
#    'lon': -106.6849611,
#    'lat': 34.9838111},
#   {'site_code': '02236700',
#    'name': 'LITTLE CREEK NEAR CLERMONT, FL',
#    'lon': -81.7570206,
#    'lat': 28.46111497},
#   {'site_code': '253952080321501',
#    'name': 'G  -3272',
#    'lon': -80.5389333,
#    'lat': 25.66493333},
#   {'site_code': '12464770',
#    'name': 'CRAB CREEK AT ROCKY FORD ROAD NEAR RITZVILLE, WA',
#    'lon': -118.3691441,
#    'lat': 47.30265108},
#   {'site_code': '09490500',
#    'name': 'BLACK RIVER NEAR FORT APACHE, AZ.',
#    'lon': -110.2117674,
#    'lat': 33.71282949},
#   {'site_code': '411219096010601',
#    'name': 'Bioretention Cell nr 69th & Q St. Omaha, NE',
#    'lon': -96.0183472,
#    'lat': 41.2053861},
#   {'site_code': '10366000',
#    'name': 'TWENTYMILE CREEK NEAR ADEL,OREG.',
#    'lon': -119.9627248,
#    'lat': 42.07211128},
#   {'site_code': '12166150',
#    'name': 'NF STILLAGUAMISH NR SWEDE HEAVEN, WA',
#    'lon': -121.8101667,
#    'lat': 48.27766667},
#   {'site_code': '02169000',
#    'name': 'SALUDA RIVER NEAR COLUMBIA, SC',
#    'lon': -81.0878717,
#    'lat': 34.0140416},
#   {'site_code': '06741510',
#    'name': 'BIG THOMPSON RIVER AT LOVELAND, CO.',
#    'lon': -105.0610909,
#    'lat': 40.3785946},
#   {'site_code': '09151500',
#    'name': 'ESCALANTE CREEK NEAR DELTA, CO.',
#    'lon': -108.2600775,
#    'lat': 38.756651},
#   {'site_code': '363537089300001',
#    'name': 'New Madrid Floodway Stage Sensor No. 911330',
#    'lon': -89.5,
#    'lat': 36.5936111},
#   {'site_code': '03351350',
#    'name': 'WHITE RIVER AT 16TH STREET AT INDIANAPOLIS, IN',
#    'lon': -86.1981111,
#    'lat': 39.78866667},
#   {'site_code': '01546500',
#    'name': 'Spring Creek near Axemann, PA',
#    'lon': -77.794168,
#    'lat': 40.88978334},
#   {'site_code': '03149500',
#    'name': 'Salt Creek near Chandlersville OH',
#    'lon': -81.8604105,
#    'lat': 39.9086814},
#   {'site_code': '14187200',
#    'name': 'SOUTH SANTIAM RIVER NEAR FOSTER, OR',
#    'lon': -122.6886956,
#    'lat': 44.4123468},
#   {'site_code': '05382257',
#    'name': 'STILLWELL CREEK AT YARD ROAD NEAR TOMAH, WI',
#    'lon': -90.6811111,
#    'lat': 44.00055556},
#   {'site_code': '04063700',
#    'name': 'POPPLE RIVER NEAR FENCE, WI',
#    'lon': -88.4636111,
#    'lat': 45.7636111},
#   {'site_code': '273109080270301',
#    'name': 'STL- 264',
#    'lon': -80.4507778,
#    'lat': 27.51925},
#   {'site_code': '13076100',
#    'name': 'RATTLESNAKE CREEK NR POCATELLO ID',
#    'lon': -112.5585929,
#    'lat': 42.7010246},
#   {'site_code': '09219200',
#    'name': 'Blacks Fork above Smiths Fork, near Lyman, WY',
#    'lon': -110.2059583,
#    'lat': 41.39415},
#   {'site_code': '0208281175',
#    'name': 'SWIFT CREEK AT NC 97 NEAR LEGGETT, NC',
#    'lon': -77.5944444,
#    'lat': 35.98027778},
#   {'site_code': '02308865',
#    'name': 'ROOSEVELT CANAL AT STR 23-8 NR PINELLAS PARK FL',
#    'lon': -82.6759327,
#    'lat': 27.90780025},
#   {'site_code': '01379530',
#    'name': 'Canoe Brook near Summit NJ',
#    'lon': -74.3536111,
#    'lat': 40.74444444},
#   {'site_code': '375617090465401',
#    'name': 'Potosi',
#    'lon': -90.7821944,
#    'lat': 37.93816667},
#   {'site_code': '11460151',
#    'name': 'REDWOOD C A HWY 1 BRIDGE A MUIR BEACH CA',
#    'lon': -122.578611,
#    'lat': 37.8661111},
#   {'site_code': '01342743',
#    'name': 'FULMER CREEK NEAR MOHAWK NY',
#    'lon': -74.9904444,
#    'lat': 42.9852222},
#   {'site_code': '14309000',
#    'name': 'COW CREEK NEAR AZALEA, OR',
#    'lon': -123.1789492,
#    'lat': 42.82484286},
#   {'site_code': '06178000',
#    'name': 'Poplar River at international boundary',
#    'lon': -105.6969083,
#    'lat': 48.9902861},
#   {'site_code': '08062800',
#    'name': 'Cedar Ck nr Kemp, TX',
#    'lon': -96.1127508,
#    'lat': 32.50347129},
#   {'site_code': '12036400',
#    'name': 'SCHAFER CREEK NEAR GRISDALE, WA',
#    'lon': -123.6151652,
#    'lat': 47.20425777},
#   {'site_code': '06078270',
#    'name': 'Sand Coulee at Sand Coulee MT',
#    'lon': -111.1637083,
#    'lat': 47.4050111},
#   {'site_code': '10344400',
#    'name': 'LITTLE TRUCKEE R AB BOCA RES NR TRUCKEE CA',
#    'lon': -120.084366,
#    'lat': 39.43574106},
#   {'site_code': '320622081063701',
#    'name': '37Q185',
#    'lon': -81.110112,
#    'lat': 32.1063171},
#   {'site_code': '15457790',
#    'name': 'GOLDSTREAM C BL ALABAM C NR LIVENGOOD AK',
#    'lon': -148.3911245,
#    'lat': 65.57540267},
#   {'site_code': '073745235',
#    'name': 'Bayou Dupre Sector Gate near Violet, LA',
#    'lon': -89.8365833,
#    'lat': 29.93519444},
#   {'site_code': '404505073131501',
#    'name': 'S123414. 1',
#    'lon': -73.2203936,
#    'lat': 40.7514871},
#   {'site_code': '13022925',
#    'name': "Grey's River blw slide nr Bedford, WY",
#    'lon': -110.813,
#    'lat': 43.03216667},
#   {'site_code': '06815000',
#    'name': 'Big Nemaha River at Falls City, Nebr.',
#    'lon': -95.5960957,
#    'lat': 40.0355577},
#   {'site_code': '01511500',
#    'name': 'TIOUGHNIOGA RIVER AT ITASKA NY',
#    'lon': -75.90888889,
#    'lat': 42.29805556},
#   {'site_code': '06796550',
#    'name': 'Platte River near Venice, Nebr.',
#    'lon': -96.3397446,
#    'lat': 41.19805528},
#   {'site_code': '361739099323301',
#    'name': '21N-22W-15 CAD Woodward 15',
#    'lon': -99.5425556,
#    'lat': 36.29427778},
#   {'site_code': '433531092265306',
#    'name': 'NTR3-5    North Drained Site Transect 3',
#    'lon': -92.4479583,
#    'lat': 43.59219444},
#   {'site_code': '360848080251845',
#    'name': 'RAINGAGE AT RIVER RIDGE ROAD NEAR ENON, NC',
#    'lon': -80.4216167,
#    'lat': 36.1466083},
#   {'site_code': '07052100',
#    'name': 'Wilson Creek near Springfield, MO',
#    'lon': -93.3702778,
#    'lat': 37.16852778},
#   {'site_code': '422032088222001',
#    'name': '45N7E-25.7a (MHEN-08-01)',
#    'lon': -88.3723528,
#    'lat': 42.3423361},
#   {'site_code': '13212890',
#    'name': 'DIXIE DRAIN NR WILDER ID',
#    'lon': -116.8893167,
#    'lat': 43.73071667},
#   {'site_code': '04174490',
#    'name': 'ALLEN CREEK AT MOUTH AT ANN ARBOR, MI',
#    'lon': -83.7461111,
#    'lat': 42.2897222},
#   {'site_code': '08164504',
#    'name': 'E Mustang Ck nr Louise, TX',
#    'lon': -96.4171913,
#    'lat': 29.07081227},
#   {'site_code': '310602081423601',
#    'name': '32G047',
#    'lon': -81.7100278,
#    'lat': 31.10080556},
#   {'site_code': '310925081312203',
#    'name': '33H208',
#    'lon': -81.5226016,
#    'lat': 31.15717459},
#   {'site_code': '05540275',
#    'name': 'SPRING BROOK AT 87TH STREET NEAR NAPERVILLE, IL',
#    'lon': -88.1636111,
#    'lat': 41.7258333},
#   {'site_code': '422108071052501',
#    'name': 'BRIDGE-RT2AE-BOSTON, MA',
#    'lon': 0.0,
#    'lat': 0.0},
#   {'site_code': '385428091265001',
#    'name': 'New Florence',
#    'lon': -91.4475,
#    'lat': 38.90777778},
#   {'site_code': '391504106225200',
#    'name': 'DINERO MINE DRAINAGE TUNNEL BLW TURQUOISE LK NR LE',
#    'lon': -106.3811111,
#    'lat': 39.2511111},
#   {'site_code': '11447360',
#    'name': 'ARCADE C NR DEL PASO HEIGHTS CA',
#    'lon': -121.3827302,
#    'lat': 38.64184848},
#   {'site_code': '13011500',
#    'name': 'PACIFIC CREEK AT MORAN WY',
#    'lon': -110.5177778,
#    'lat': 43.85027778},
#   {'site_code': '06829500',
#    'name': 'REPUBLICAN RIVER AT TRENTON, NEBR.',
#    'lon': -101.0477778,
#    'lat': 40.16666667},
#   {'site_code': '360310114172301',
#    'name': 'LAKE MEAD TEMPLE BASIN QW PLATFORM 1 METER DEPTH',
#    'lon': -114.2897222,
#    'lat': 36.05277778},
#   {'site_code': '14019220',
#    'name': 'COLUMBIA RIVER AT MCNARY DAM LOCK NR UMATILLA, OR',
#    'lon': -119.2930719,
#    'lat': 45.9412437},
#   {'site_code': '03050460',
#    'name': 'TYGART VALLEY R BELOW OUTLET WORKS, ELKINS, WV',
#    'lon': -79.8695,
#    'lat': 38.92106944},
#   {'site_code': '05578250',
#    'name': 'NORTH FORK SALT CREEK NEAR DE WITT, IL',
#    'lon': -88.8097222,
#    'lat': 40.23527778},
#   {'site_code': '393040105003201',
#    'name': 'SC00606821CD DENV 6',
#    'lon': -105.0091056,
#    'lat': 39.50914167},
#   {'site_code': '453845121564001',
#    'name': 'COLUMBIA RIVER AT CASCADE ISLAND, WA',
#    'lon': -121.945637,
#    'lat': 45.6456726},
#   {'site_code': '06436180',
#    'name': 'WHITEWOOD CR ABOVE WHITEWOOD,SD',
#    'lon': -103.6293606,
#    'lat': 44.4422065},
#   {'site_code': '01673550',
#    'name': 'TOTOPOTOMOY CREEK NEAR STUDLEY, VA',
#    'lon': -77.2577548,
#    'lat': 37.6626434},
#   {'site_code': '05541710',
#    'name': 'AUX SABLE CREEK NEAR MORRIS, IL',
#    'lon': -88.347566,
#    'lat': 41.4172533},
#   {'site_code': '02266600',
#    'name': 'CYPRESS LAKE NEAR ST. CLOUD, FL',
#    'lon': -81.3017364,
#    'lat': 28.07501783},
#   {'site_code': '340321117153801',
#    'name': '001S004W25E005S',
#    'lon': -117.260511,
#    'lat': 34.05585},
#   {'site_code': '04206021',
#    'name': 'Powers Brook at Stow OH',
#    'lon': -81.454279,
#    'lat': 41.20116719},
#   {'site_code': '0204288786',
#    'name': 'STORM DRAIN AT PROFESSIONAL PL NEAR CHESAPEAKE, VA',
#    'lon': -76.22907778,
#    'lat': 36.7638111},
#   {'site_code': '300034090055300',
#    'name': 'City Park West Lagoon at New Orleans, LA',
#    'lon': -90.0980556,
#    'lat': 30.00944444},
#   {'site_code': '10311400',
#    'name': 'CARSON RV AT DEER RUN RD NR CARSON CITY, NV',
#    'lon': -119.6948694,
#    'lat': 39.18137778},
#   {'site_code': '09525500',
#    'name': 'YUMA MAIN CANAL BLW COLORADO R. SIPHON AT YUMA, AZ',
#    'lon': -114.6199524,
#    'lat': 32.73032465},
#   {'site_code': '04240200',
#    'name': 'NINEMILE CREEK AT CAMILLUS NY',
#    'lon': -76.3080556,
#    'lat': 43.03916667},
#   {'site_code': '0157608335',
#    'name': 'Little Conestoga Creek, Site 3A, near Morgantown',
#    'lon': -75.9266052,
#    'lat': 40.14648597},
#   {'site_code': '07337900',
#    'name': 'Glover River near Glover, OK',
#    'lon': -94.9021667,
#    'lat': 34.09760677},
#   {'site_code': '09383570',
#    'name': 'NUTRIOSO CREEK AT SPRINGERVILLE, AZ',
#    'lon': -109.2711969,
#    'lat': 34.1389354},
#   {'site_code': '254950080171202',
#    'name': 'G  -1368A',
#    'lon': -80.2863333,
#    'lat': 25.8315},
#   {'site_code': '03056000',
#    'name': 'TYGART VALLEY R AT TYGART DAM NR GRAFTON, WV',
#    'lon': -80.0250779,
#    'lat': 39.31981459},
#   {'site_code': '04201404',
#    'name': 'Baker Creek at Olmsted Falls OH',
#    'lon': -81.9001376,
#    'lat': 41.35088339},
#   {'site_code': '15238600',
#    'name': 'SPRUCE C NR SEWARD AK',
#    'lon': -149.4543636,
#    'lat': 60.0688812},
#   {'site_code': '02307780',
#    'name': 'LONG BRANCH NEAR PINELLAS PARK FL',
#    'lon': -82.7248228,
#    'lat': 27.91585545},
#   {'site_code': '04279000',
#    'name': 'LA CHUTE AT TICONDEROGA NY',
#    'lon': -73.43188889,
#    'lat': 43.84402778},
#   {'site_code': '05270500',
#    'name': 'SAUK RIVER NEAR ST. CLOUD, MN',
#    'lon': -94.2336033,
#    'lat': 45.55968715},
#   {'site_code': '11042900',
#    'name': 'SANTA GERTRUDIS C NR TEMECULA CA',
#    'lon': -117.1647544,
#    'lat': 33.52447127},
#   {'site_code': '07358280',
#    'name': 'Hot Springs at Hot Springs, AR',
#    'lon': -93.0535128,
#    'lat': 34.51175606},
#   {'site_code': '343537099234301',
#    'name': '01N-21W-03 ABB 1 SFR01',
#    'lon': -99.3952167,
#    'lat': 34.5937472},
#   {'site_code': '12452990',
#    'name': 'ENTIAT RIVER NEAR ENTIAT, WA',
#    'lon': -120.250634,
#    'lat': 47.663185},
#   {'site_code': '07037500',
#    'name': 'St. Francis River near Patterson, MO',
#    'lon': -90.5033056,
#    'lat': 37.19452778},
#   {'site_code': '073745257',
#    'name': 'Crooked B. NW of L. Cuatro Caballo near Delacroix',
#    'lon': -89.7195065,
#    'lat': 29.7082661},
#   {'site_code': '03125500',
#    'name': 'Piedmont Lake at Piedmont OH',
#    'lon': -81.2156623,
#    'lat': 40.19201236},
#   {'site_code': '01014000',
#    'name': 'St. John River below Fish R, nr Fort Kent, Maine',
#    'lon': -68.58527778,
#    'lat': 47.2833333},
#   {'site_code': '02131510',
#    'name': 'LYNCHES RIVER AT I-95, ABOVE OLANTA,SC',
#    'lon': -79.98613889,
#    'lat': 34.03819444},
#   {'site_code': '262822081213201',
#    'name': 'C  -1075',
#    'lon': -81.3656311,
#    'lat': 26.4756319},
#   {'site_code': '263180080205001',
#    'name': 'SITE 7 IN CONS AREA NO. 1 NR SHAWANO, FL',
#    'lon': -80.3361028,
#    'lat': 26.5225472},
#   {'site_code': '07024500',
#    'name': 'SOUTH FORK OBION RIVER NEAR GREENFIELD, TN',
#    'lon': -88.8108946,
#    'lat': 36.1181209},
#   {'site_code': '05362000',
#    'name': 'JUMP RIVER AT SHELDON, WI',
#    'lon': -90.956525,
#    'lat': 45.30802638},
#   {'site_code': '07141175',
#    'name': 'BUCKNER C NR BURDETT, KS',
#    'lon': -99.6428988,
#    'lat': 38.1625166},
#   {'site_code': '03182888',
#    'name': 'DRY CREEK AT TUCKAHOE, WV',
#    'lon': -80.2781241,
#    'lat': 37.7412334},
#   {'site_code': '06869950',
#    'name': 'MULBERRY C NR SALINA, KS',
#    'lon': -97.6683699,
#    'lat': 38.8444476},
#   {'site_code': '06848500',
#    'name': 'PRAIRIE DOG C NR WOODRUFF, KS',
#    'lon': -99.4786584,
#    'lat': 39.9787043},
#   {'site_code': '11507000',
#    'name': 'UPPER KLAMATH LAKE NEAR KLAMATH FALLS, OR',
#    'lon': -121.8163945,
#    'lat': 42.24986606},
#   {'site_code': '03077500',
#    'name': 'Youghiogheny River at Youghiogheny River Dam, PA',
#    'lon': -79.3642019,
#    'lat': 39.80535485},
#   {'site_code': '06714600',
#    'name': 'SOUTH CLEAR CRK ABV LEAVENWORTH CRK NR GEORGETWN.',
#    'lon': -105.6994488,
#    'lat': 39.68693178},
#   {'site_code': '03612000',
#    'name': 'CACHE RIVER AT FORMAN, IL',
#    'lon': -88.923955,
#    'lat': 37.33644107},
#   {'site_code': '09085000',
#    'name': 'ROARING FORK RIVER AT GLENWOOD SPRINGS, CO.',
#    'lon': -107.3294984,
#    'lat': 39.54359307},
#   {'site_code': '0143402265',
#    'name': 'W BR NEVERSINK R AT BRANCH NR FROST VALLEY NY',
#    'lon': -74.4808333,
#    'lat': 41.99027778},
#   {'site_code': '363514089134101',
#    'name': 'New Madrid Floodway Stage Sensor No. 911310',
#    'lon': -89.2280556,
#    'lat': 36.5872222},
#   {'site_code': '01484695',
#    'name': 'BEAVERDAM DITCH NEAR MILLVILLE, DE',
#    'lon': -75.13338889,
#    'lat': 38.52144444},
#   {'site_code': '02327031',
#    'name': 'SPRING CREEK NEAR SPRING CREEK, FL',
#    'lon': -84.3273972,
#    'lat': 30.07270485},
#   {'site_code': '08329870',
#    'name': 'BEAR ARROYO AT JEFFERSON ST AT ALBQ, NM',
#    'lon': -106.5977778,
#    'lat': 35.1508333},
#   {'site_code': '06917560',
#    'name': 'Marmaton River near Richards, MO',
#    'lon': -94.5822222,
#    'lat': 37.8647222},
#   {'site_code': '04176605',
#    'name': 'OTTER CREEK AT LA SALLE, MI',
#    'lon': -83.4535445,
#    'lat': 41.86699035},
#   {'site_code': '424848088083100',
#    'name': 'WIND LAKE AT OUTLET AT WIND LAKE, WI',
#    'lon': -88.1420325,
#    'lat': 42.81334964},
#   {'site_code': '12137290',
#    'name': 'SOUTH FORK SULTAN RIVER NEAR SULTAN, WA',
#    'lon': -121.6267826,
#    'lat': 47.94732637},
#   {'site_code': '01434080',
#    'name': 'DRY CREEK ABOVE SEEP ZONE NEAR FROST VALLEY NY',
#    'lon': -74.5116667,
#    'lat': 41.96777778},
#   {'site_code': '323112114482701',
#    'name': 'C-10-25 34AAC1',
#    'lon': -114.8075,
#    'lat': 32.52013889},
#   {'site_code': '14208700',
#    'name': 'OAK GROVE FORK NEAR GOVERNMENT CAMP, OR',
#    'lon': -121.8150775,
#    'lat': 45.11373009},
#   {'site_code': '06926290',
#    'name': 'Tavern Creek below St. Elizabeth, MO',
#    'lon': -92.2333333,
#    'lat': 38.27777778},
#   {'site_code': '381929076043002',
#    'name': 'DO Fe  42',
#    'lon': -76.0749694,
#    'lat': 38.3246361},
#   {'site_code': '01589305',
#    'name': 'POWDER MILL RUN NEAR LOCHEARN, MD',
#    'lon': -76.7108333,
#    'lat': 39.3351111},
#   {'site_code': '08099000',
#    'name': 'Leon Res nr Ranger, TX',
#    'lon': -98.6756129,
#    'lat': 32.36374406},
#   {'site_code': '323303117050202',
#    'name': '019S002W03E002S',
#    'lon': -117.0838806,
#    'lat': 32.55031389},
#   {'site_code': '09442683',
#    'name': 'PARSONS DITCH NR RESERVE, NM',
#    'lon': -108.7655556,
#    'lat': 33.69055556},
#   {'site_code': '340841090134701',
#    'name': 'M0072 QUITMAN (Allen)',
#    'lon': -90.2296944,
#    'lat': 34.1447222},
#   {'site_code': '03524740',
#    'name': 'CLINCH RIVER AT ROUTE 65 AT DUNGANNON, VA',
#    'lon': -82.4619444,
#    'lat': 36.83138889},
#   {'site_code': '0158175320',
#    'name': 'WHEEL CREEK NEAR ABINGDON, MD',
#    'lon': -76.3400833,
#    'lat': 39.48163889},
#   {'site_code': '11336600',
#    'name': 'DELTA CROSS CHANNEL NR WALNUT GROVE',
#    'lon': -121.5052778,
#    'lat': 38.2447222},
#   {'site_code': '365751076433503',
#    'name': '57D 23 SOW 143C',
#    'lon': -76.72606929,
#    'lat': 36.96431588},
#   {'site_code': '321727110230201',
#    'name': 'D-13-19 22ADD3',
#    'lon': -110.384125,
#    'lat': 32.29089167},
#   {'site_code': '02251800',
#    'name': 'INDIAN RIVER AT WABASSO, FL',
#    'lon': -80.4275516,
#    'lat': 27.75447297},
#   {'site_code': '03152000',
#    'name': 'LITTLE KANAWHA RIVER AT GLENVILLE, WV',
#    'lon': -80.8382222,
#    'lat': 38.9329722},
#   {'site_code': '253417080224302',
#    'name': 'BLACK CR CANAL RAINGAGE WEST OF US1 NR GOULDS, FL',
#    'lon': -80.37875,
#    'lat': 25.57091667},
#   {'site_code': '16330000',
#    'name': 'Kamananui Str at Maunawai, Oahu, HI',
#    'lon': -158.0545833,
#    'lat': 21.63547222},
#   {'site_code': '05406465',
#    'name': 'BREWERY CREEK AT CT HIGHWAY K NEAR CROSS PLAINS,WI',
#    'lon': -89.5967881,
#    'lat': 43.1491601},
#   {'site_code': '02240000',
#    'name': 'OCKLAWAHA RIVER NEAR CONNER, FL',
#    'lon': -81.9859203,
#    'lat': 29.21469888},
#   {'site_code': '01434021',
#    'name': 'W BR NEVERSINK R AT WINNISOOK L NR FROST VALLEY NY',
#    'lon': -74.4144444,
#    'lat': 42.0111111},
#   {'site_code': '01323500',
#    'name': 'GREAT SACANDAGA LAKE AT CONKLINGVILLE NY',
#    'lon': -73.92706958,
#    'lat': 43.3159042},
#   {'site_code': '392058104364401',
#    'name': 'SC00806513DC LDAW 12',
#    'lon': -104.6123583,
#    'lat': 39.34967778},
#   {'site_code': '07179750',
#    'name': 'NEOSHO R AT BURLINGAME RD NR EMPORIA, KS',
#    'lon': -96.1583287,
#    'lat': 38.42862475},
#   {'site_code': '04206210',
#    'name': 'North Fork at Bath OH',
#    'lon': -81.6531797,
#    'lat': 41.18894375},
#   {'site_code': '03085152',
#    'name': 'Monongahela R at Point State Park at Pittsburgh',
#    'lon': -80.0108333,
#    'lat': 40.43944444},
#   {'site_code': '281918082264603',
#    'name': 'STATE HWY 52 NRSD WELL NEAR GOWERS CORNER FL',
#    'lon': -82.4460833,
#    'lat': 28.32191667},
#   {'site_code': '06890898',
#    'name': 'PERRY LK NR PERRY, KS',
#    'lon': -95.4263636,
#    'lat': 39.11416639},
#   {'site_code': '335401078512800',
#    'name': 'WACCAMAW RIVER BELOW LONGS, SC',
#    'lon': -78.8577778,
#    'lat': 33.90027778},
#   {'site_code': '10293050',
#    'name': 'E WALKER RV BLW SWEETWATER CK NR BRIDGEPORT, CA',
#    'lon': -119.1059819,
#    'lat': 38.44074975},
#   {'site_code': '02130910',
#    'name': 'BLACK CREEK NEAR HARTSVILLE, SC',
#    'lon': -80.149791,
#    'lat': 34.39737618},
#   {'site_code': '07069000',
#    'name': 'Black River at Pocahontas, AR',
#    'lon': -90.9702778,
#    'lat': 36.25416667},
#   {'site_code': '0208111310',
#    'name': 'CASHIE RIVER AT SR1257 NEAR WINDSOR, NC',
#    'lon': -76.9841667,
#    'lat': 36.04777778},
#   {'site_code': '280842082392000',
#    'name': 'BROOKER CK PRESERVE RAINFALL NR TARPON SPRINGS FL',
#    'lon': -82.6555833,
#    'lat': 28.14483333},
#   {'site_code': '05543500',
#    'name': 'ILLINOIS RIVER AT MARSEILLES, IL',
#    'lon': -88.7175739,
#    'lat': 41.32697786},
#   {'site_code': '03540500',
#    'name': 'EMORY RIVER AT OAKDALE, TN',
#    'lon': -84.557992,
#    'lat': 35.9831307},
#   {'site_code': '09357255',
#    'name': 'GALLEGOS CANYON AT NIIP NEAR FARMINGTON, NM',
#    'lon': -108.1095154,
#    'lat': 36.69083779},
#   {'site_code': '07179300',
#    'name': 'NEOSHO R NR PARKERVILLE, KS',
#    'lon': -96.6496611,
#    'lat': 38.75129167},
#   {'site_code': '01049505',
#    'name': 'Kennebec River at Gardiner, Maine',
#    'lon': -69.7694444,
#    'lat': 44.23027778},
#   {'site_code': '01115276',
#    'name': 'WESTCONNAUG STREAM AT PLAINFIELD PIKE, RI',
#    'lon': -71.6672885,
#    'lat': 41.7853772},
#   {'site_code': '430154100411801',
#    'name': ' 35N29W 2DDDD(RST GW WELL M-10 NR OLSONVILLE, SD)',
#    'lon': -100.68875,
#    'lat': 43.03222878},
#   {'site_code': '06228000',
#    'name': 'WIND RIVER AT RIVERTON, WY',
#    'lon': -108.3767701,
#    'lat': 43.01051478},
#   {'site_code': '08331510',
#    'name': 'RIO GRANDE AT STATE HWY 346 NEAR BOSQUE, NM',
#    'lon': -106.7630556,
#    'lat': 34.545},
#   {'site_code': '03234500',
#    'name': 'Scioto River at Higby OH',
#    'lon': -82.8637854,
#    'lat': 39.21228934},
#   {'site_code': '01643500',
#    'name': 'BENNETT CREEK AT PARK MILLS, MD',
#    'lon': -77.4070833,
#    'lat': 39.29413889},
#   {'site_code': '333241095432300',
#    'name': 'Rain Gage at Roxton, TX',
#    'lon': -95.7230556,
#    'lat': 33.5447222},
#   {'site_code': '10249190',
#    'name': 'WILLOW CK NR WARM SPGS, NV',
#    'lon': -116.6022898,
#    'lat': 38.5763226},
#   {'site_code': '03318005',
#    'name': 'ROUGH RIVER LAKE NEAR FALLS OF ROUGH, KY',
#    'lon': -86.499425,
#    'lat': 37.62005547},
#   {'site_code': '08178585',
#    'name': 'Salado Ck at Wilderness Rd, San Antonio, TX',
#    'lon': -98.5655755,
#    'lat': 29.63078135},
#   {'site_code': '303026091113001',
#    'name': 'EB-297',
#    'lon': -91.1917745,
#    'lat': 30.50741157},
#   {'site_code': '06885500',
# ...
#   {'site_code': '02341665',
#    'name': 'UPATOI CREEK BELOW BAKER CREEK, NEAR UPATOI, GA',
#    'lon': -84.6977778,
#    'lat': 32.51888889},
#   {'site_code': '12019310',
#    'name': 'CHEHALIS RIVER ABOVE MAHAFFEY CREEK NR PE ELL, WA',
#    'lon': -123.2987167,
#    'lat': 46.54531667},
#   {'site_code': '11451715',
#    'name': 'BEAR C AB HOLSTEN CHIMNEY CYN NR RUMSEY CA',
#    'lon': -122.3427535,
#    'lat': 38.95767446},
#   {'site_code': '05422560',
#    'name': 'Duck Creek at 110th Avenue at Davenport, IA',
#    'lon': -90.6876409,
#    'lat': 41.55669745},
#   {'site_code': '01490000',
#    'name': 'CHICAMACOMICO RIVER NEAR SALEM, MD',
#    'lon': -75.8799167,
#    'lat': 38.51166667},
#   {'site_code': '03353630',
#    'name': 'LITTLE BUCK CREEK NEAR SOUTHPORT, IN',
#    'lon': -86.0824849,
#    'lat': 39.6700453},
#   {'site_code': '394348118040248',
#    'name': 'DVSV ET STA DEPTH 2 FT BLW LAND SURFACE (A)',
#    'lon': -118.0672639,
#    'lat': 39.73010556},
#   {'site_code': '383550092094201',
#    'name': 'Jefferson City',
#    'lon': -92.1618611,
#    'lat': 38.59713889},
#   {'site_code': '03015000',
#    'name': 'Conewango Creek at Russell, PA',
#    'lon': -79.133101,
#    'lat': 41.9381145},
#   {'site_code': '02131000',
#    'name': 'PEE DEE RIVER AT PEEDEE, SC',
#    'lon': -79.5483896,
#    'lat': 34.20432518},
#   {'site_code': '0208730025',
#    'name': 'BIG BRANCH TRIB AT WINGATE DR AT RALEIGH, NC',
#    'lon': -78.6166695,
#    'lat': 35.8440396},
#   {'site_code': '07307800',
#    'name': 'Pease Rv nr Childress, TX',
#    'lon': -100.0737179,
#    'lat': 34.2275718},
#   {'site_code': '12329500',
#    'name': 'Flint Creek at Maxville MT',
#    'lon': -113.2402778,
#    'lat': 46.4637583},
#   {'site_code': '03592718',
#    'name': 'LITTLE YELLOW CREEK EAST NR BURNSVILLE, MS',
#    'lon': -88.2880556,
#    'lat': 34.83555556},
#   {'site_code': '03049680',
#    'name': 'Allegheny R at Lock & Dam 2 at Aspinwall, PA',
#    'lon': -79.915,
#    'lat': 40.4875},
#   {'site_code': '03524000',
#    'name': 'CLINCH RIVER AT CLEVELAND, VA',
#    'lon': -82.1548569,
#    'lat': 36.9448295},
#   {'site_code': '360246114443013',
#    'name': 'BOULDER BASIN MONITORING STATION (61 METER DEPTH)',
#    'lon': -114.7416667,
#    'lat': 36.0461111},
#   {'site_code': '08140700',
#    'name': 'Pecan Bayou nr Cross Cut, TX',
#    'lon': -99.1303376,
#    'lat': 31.9726444},
#   {'site_code': '02094770',
#    'name': 'SOUTH BUFFALO CREEK AT US 220 AT GREENSBORO, NC',
#    'lon': -79.7997222,
#    'lat': 36.03805556},
#   {'site_code': '383315107525201',
#    'name': 'NC05000933DB LGRB Poly 20',
#    'lon': -107.8811111,
#    'lat': 38.55416667},
#   {'site_code': '08278500',
#    'name': 'RIO SANTA BARBARA NR PENASCO, NM',
#    'lon': -105.632515,
#    'lat': 36.1111377},
#   {'site_code': '02134480',
#    'name': 'BIG SWAMP NR TAR HEEL, NC',
#    'lon': -78.83638889,
#    'lat': 34.71027778},
#   {'site_code': '02358789',
#    'name': 'CHIPOLA RIVER AT MARIANNA FL',
#    'lon': -85.2163178,
#    'lat': 30.77297064},
#   {'site_code': '01381940',
#    'name': 'Passaic R at Horse Neck Bridge near Pine Bk NJ',
#    'lon': -74.34,
#    'lat': 40.8822222},
#   {'site_code': '382407076260301',
#    'name': 'CA Fd  54',
#    'lon': -76.4346111,
#    'lat': 38.40225},
#   {'site_code': '023362095',
#    'name': 'BURNT FORK CR AT MILLWOOD WAY NEAR CLARKSTON, GA',
#    'lon': -84.2747222,
#    'lat': 33.82138889},
#   {'site_code': '480608115242901',
#    'name': 'Libby Wetland Site bl Schrieber Lake nr Libby, MT',
#    'lon': -115.4089188,
#    'lat': 48.1022259},
#   {'site_code': '03023100',
#    'name': 'French Creek at Meadville, PA',
#    'lon': -80.1595043,
#    'lat': 41.63255476},
#   {'site_code': '13331500',
#    'name': 'MINAM RIVER AT MINAM, OR',
#    'lon': -117.7265892,
#    'lat': 45.6198669},
#   {'site_code': '06784800',
#    'name': 'TURKEY CREEK NEAR DANNEBROG, NE',
#    'lon': -98.5572222,
#    'lat': 41.15694444},
#   {'site_code': '0209725960',
#    'name': 'THIRD FORK CREEK AT M.L. KING PARKWAY AT DURHAM,NC',
#    'lon': -78.9269417,
#    'lat': 35.95118056},
#   {'site_code': '01310500',
#    'name': 'EAST MEADOW BROOK AT FREEPORT NY',
#    'lon': -73.5697222,
#    'lat': 40.66555556},
#   {'site_code': '02069700',
#    'name': 'SOUTH MAYO RIVER NEAR NETTLERIDGE, VA',
#    'lon': -80.1294928,
#    'lat': 36.570971},
#   {'site_code': '05341402',
#    'name': 'BALSAM BRANCH AT BALSAM LAKE, WI',
#    'lon': -92.4504759,
#    'lat': 45.44690309},
#   {'site_code': '290855080582700',
#    'name': 'HALIFAX RIVER AT PORT ORANGE FL',
#    'lon': -80.9741667,
#    'lat': 29.1486111},
#   {'site_code': '12166000',
#    'name': 'BOULDER RIVER NEAR OSO, WA',
#    'lon': -121.780411,
#    'lat': 48.27760727},
#   {'site_code': '02215100',
#    'name': 'TUCSAWHATCHEE CREEK NEAR HAWKINSVILLE, GA',
#    'lon': -83.5016667,
#    'lat': 32.23944444},
#   {'site_code': '350842106403202',
#    'name': '11N.03E.31.111B MERM',
#    'lon': -106.6758806,
#    'lat': 35.14505},
#   {'site_code': '07055790',
#    'name': 'Big Creek near Mt. Judea, AR',
#    'lon': -93.0726667,
#    'lat': 35.9386111},
#   {'site_code': '02105769',
#    'name': 'CAPE FEAR R AT LOCK #1 NR KELLY, NC',
#    'lon': -78.2936111,
#    'lat': 34.40444444},
#   {'site_code': '403516101560601',
#    'name': '  7N 41W11DAA 1  LAMAR',
#    'lon': -101.9354582,
#    'lat': 40.58777385},
#   {'site_code': '404708076070701',
#    'name': 'SC   296  Schuylkill County Observation Well',
#    'lon': -76.1184722,
#    'lat': 40.78575},
#   {'site_code': '394508118025553',
#    'name': 'PL1 ET STA DEPTH 3 FT BLW LAND SURFACE (B)',
#    'lon': -118.0485083,
#    'lat': 39.75216667},
#   {'site_code': '06349700',
#    'name': 'MISSOURI RIVER NR SCHMIDT, ND',
#    'lon': -100.7391667,
#    'lat': 46.65638889},
#   {'site_code': '04057800',
#    'name': 'MIDDLE BRANCH ESCANABA RIVER AT HUMBOLDT, MI',
#    'lon': -87.8865238,
#    'lat': 46.49910267},
#   {'site_code': '420425122361700',
#    'name': 'HIGHWAY RUNOFF SITE NR I5 AND OLD HWY 99',
#    'lon': -122.6046667,
#    'lat': 42.0735833},
#   {'site_code': '09383400',
#    'name': 'LITTLE COLORADO RIVER AT GREER, AZ',
#    'lon': -109.4573125,
#    'lat': 34.0167143},
#   {'site_code': '484204116150201',
#    'name': '62N 02E 30ABD1-DESTROYED',
#    'lon': -116.2506944,
#    'lat': 48.7009722},
#   {'site_code': '02335078',
#    'name': 'JOHNS CREEK AT BUICE ROAD, NEAR WARSAW, GA',
#    'lon': -84.2110306,
#    'lat': 34.016211},
#   {'site_code': '05397500',
#    'name': 'EAU CLAIRE RIVER AT KELLY, WI',
#    'lon': -89.5519444,
#    'lat': 44.91888889},
#   {'site_code': '01620500',
#    'name': 'NORTH RIVER NEAR STOKESVILLE, VA',
#    'lon': -79.2391667,
#    'lat': 38.335},
#   {'site_code': '11042631',
#    'name': 'PECHANGA C NR TEMECULA CA',
#    'lon': -117.1238889,
#    'lat': 33.46416667},
#   {'site_code': '14361500',
#    'name': 'ROGUE RIVER AT GRANTS PASS, OR',
#    'lon': -123.3178365,
#    'lat': 42.43039607},
#   {'site_code': '06929315',
#    'name': 'Paddy Creek above Slabtown Spring, MO',
#    'lon': -92.0492806,
#    'lat': 37.5574361},
#   {'site_code': '05443000',
#    'name': 'ROCK RIVER ABOVE SINNISSIPPI DAM AT ROCK FALLS, IL',
#    'lon': -89.6763889,
#    'lat': 41.7875},
#   {'site_code': '021556524',
#    'name': 'LAKE BLALOCK NEAR COWPENS, SC',
#    'lon': -81.8678816,
#    'lat': 35.05817815},
#   {'site_code': '05537500',
#    'name': 'LONG RUN NEAR LEMONT, IL',
#    'lon': -87.9992252,
#    'lat': 41.642531},
#   {'site_code': '08315500',
#    'name': 'MCCLURE RESERVOIR NEAR SANTA FE N MEX',
#    'lon': -105.8358333,
#    'lat': 35.6872222},
#   {'site_code': '08056000',
#    'name': 'Elm Fk Trinity Rv at Frasier Dam, Dallas, TX',
#    'lon': -96.8900038,
#    'lat': 32.842072},
#   {'site_code': '11129800',
#    'name': 'ZACA C NR BUELLTON CA',
#    'lon': -120.1843172,
#    'lat': 34.64859614},
#   {'site_code': '12044900',
#    'name': 'ELWHA RIVER ABOVE LAKE MILLS NR PORT ANGELES, WA',
#    'lon': -123.5907453,
#    'lat': 47.970089},
#   {'site_code': '350403106392302',
#    'name': '10N.03E.30.244G BEDWM',
#    'lon': -106.6566056,
#    'lat': 35.06739167},
#   {'site_code': '02427250',
#    'name': 'PINE BARREN CREEK NEAR SNOW HILL, AL.',
#    'lon': -87.0683187,
#    'lat': 31.99625809},
#   {'site_code': '215607159344301',
#    'name': '2-5634-01 Hanapepe Ridge, Kauai, HI',
#    'lon': -159.5758333,
#    'lat': 21.93194444},
#   {'site_code': '254446080295501',
#    'name': 'G  -3574',
#    'lon': -80.49788889,
#    'lat': 25.7463611},
#   {'site_code': '14315500',
#    'name': 'NORTH UMPQUA RIVER AT TOKETEE FALLS, OR',
#    'lon': -122.4217087,
#    'lat': 43.26373317},
#   {'site_code': '01350101',
#    'name': 'SCHOHARIE CREEK AT GILBOA NY',
#    'lon': -74.4505556,
#    'lat': 42.3972222},
#   {'site_code': '350356106393901',
#    'name': '10N.03E.30.421C BWBS-T2',
#    'lon': -106.6608306,
#    'lat': 35.0655611},
#   {'site_code': '07024175',
#    'name': 'Mississippi River at New Madrid, MO',
#    'lon': -89.5472222,
#    'lat': 36.5808333},
#   {'site_code': '13117020',
#    'name': 'BIRCH CREEK AT BLUE DOME INN NR RENO ID',
#    'lon': -112.9091667,
#    'lat': 44.1533333},
#   {'site_code': '13238322',
#    'name': 'NORTH FORK PAYETTE RIVER BL FISHER CR NR McCALL ID',
#    'lon': -116.0592903,
#    'lat': 45.0346186},
#   {'site_code': '06892495',
#    'name': 'CEDAR C NR DESOTO, KS',
#    'lon': -94.9227778,
#    'lat': 38.97805556},
#   {'site_code': '10136600',
#    'name': 'WEBER RIVER AT I-84 AT UINTAH, UT',
#    'lon': -111.9195556,
#    'lat': 41.1370833},
#   {'site_code': '05200510',
#    'name': 'MISSISSIPPI RIVER NEAR BEMIDJI, MN',
#    'lon': -94.7280436,
#    'lat': 47.48328559},
#   {'site_code': '400416074270101',
#    'name': '290138-- Colliers Mills 1 Obs',
#    'lon': -74.450151,
#    'lat': 40.07066978},
#   {'site_code': '08076180',
#    'name': 'Garners Bayou nr Humble, TX',
#    'lon': -95.2339608,
#    'lat': 29.93386089},
#   {'site_code': '430159093403201',
#    'name': '095N24W21ADAD       1996NAWQA IADRN-2',
#    'lon': -93.6755278,
#    'lat': 43.0331111},
#   {'site_code': '433644114231300',
#    'name': 'TIMBER GULCH PRECIP GAGE NR HAILEY, ID',
#    'lon': -114.388861,
#    'lat': 43.61528889},
#   {'site_code': '06479512',
#    'name': 'BIG SIOUX R AT BROADWAY AT WATERTOWN, SD',
#    'lon': -97.118962,
#    'lat': 44.88940887},
#   {'site_code': '02208150',
#    'name': 'ALCOVY RIVER AT NEW HOPE ROAD, NEAR GRAYSON, GA',
#    'lon': -83.8879582,
#    'lat': 33.9176073},
#   {'site_code': '02334620',
#    'name': 'DICK CREEK AT OLD ATLANTA RD, NEAR SUWANEE, GA',
#    'lon': -84.1301922,
#    'lat': 34.07148875},
#   {'site_code': '03126000',
#    'name': 'Stillwater Creek at Piedmont OH',
#    'lon': -81.2153844,
#    'lat': 40.1947901},
#   {'site_code': '304806084404101',
#    'name': '08E039',
#    'lon': -84.6781111,
#    'lat': 30.8018611},
#   {'site_code': '04200000',
#    'name': 'East Branch Black River at Elyria OH',
#    'lon': -82.0943144,
#    'lat': 41.34754779},
#   {'site_code': '02085500',
#    'name': 'FLAT RIVER AT BAHAMA, NC',
#    'lon': -78.87888889,
#    'lat': 36.18277778},
#   {'site_code': '0205373035',
#    'name': 'BOTTOM CREEK ABOVE TRIBUTARY NR BENT MOUNTAIN, VA',
#    'lon': -80.1519167,
#    'lat': 37.1870833},
#   {'site_code': '09163570',
#    'name': 'HAY PRESS C AB FRUITA RES #3, NR GLADE PARK, CO.',
#    'lon': -108.7828793,
#    'lat': 38.8508166},
#   {'site_code': '04170000',
#    'name': 'HURON RIVER AT MILFORD, MI',
#    'lon': -83.62660809,
#    'lat': 42.57892089},
#   {'site_code': '02389150',
#    'name': 'ETOWAH RIVER AT GA 9, NEAR DAWSONVILLE, GA',
#    'lon': -84.1133333,
#    'lat': 34.35805556},
#   {'site_code': '11284400',
#    'name': 'BIG C AB WHITES GULCH NR GROVELAND CA',
#    'lon': -120.1849103,
#    'lat': 37.8418714},
#   {'site_code': '02344724',
#    'name': 'WHITEWATER CREEK AT EASTIN RD, NR FAYETTEVILLE, GA',
#    'lon': -84.5083333,
#    'lat': 33.4872222},
#   {'site_code': '410121081330300',
#    'name': 'Long Lake Feeder O&E Canal OH',
#    'lon': -81.55067419,
#    'lat': 41.02255558},
#   {'site_code': '06730400',
#    'name': 'COAL CREEK NEAR LOUISVILLE, CO',
#    'lon': -105.1172068,
#    'lat': 39.9760962},
#   {'site_code': '01125490',
#    'name': 'LITTLE RIVER AT HARRISVILLE, CT',
#    'lon': -71.9300083,
#    'lat': 41.92784444},
#   {'site_code': '09378200',
#    'name': 'MONTEZUMA CREEK AT GOLF COURSE AT MONTICELLO, UT',
#    'lon': -109.3423393,
#    'lat': 37.86054967},
#   {'site_code': '01339060',
#    'name': 'SAUQUOIT CREEK AT WHITESBORO NY',
#    'lon': -75.294,
#    'lat': 43.11144444},
#   {'site_code': '02480285',
#    'name': 'WEST PASCAGOULA RIVER AT HWY 90 AT GAUTIER, MS',
#    'lon': -88.6084444,
#    'lat': 30.38269444},
#   {'site_code': '354029106274430',
#    'name': 'Peralta Canyon Nr. White Rock, NM',
#    'lon': -106.4621389,
#    'lat': 35.67477778},
#   {'site_code': '07343840',
#    'name': 'White Oak Ck at IH 30 nr Omaha, TX',
#    'lon': -94.8025,
#    'lat': 33.2747222},
#   {'site_code': '380730075110402',
#    'name': 'WO Ef 31',
#    'lon': -75.18452778,
#    'lat': 38.12513889},
#   {'site_code': '02308870',
#    'name': 'PINEBROOK CN AT BRYAN DAIRY RD AT PINELLAS PARK FL',
#    'lon': -82.7370453,
#    'lat': 27.8722458},
#   {'site_code': '12091290',
#    'name': 'LEACH CR AT MEADOW PARK GC AT UNIVERSITY PLACE, WA',
#    'lon': -122.5209584,
#    'lat': 47.1984316},
#   {'site_code': '04175340',
#    'name': 'STONY CREEK AT TUTTLE HILL RD AT OAKVILLE, MI',
#    'lon': -83.5785477,
#    'lat': 42.08476489},
#   {'site_code': '12122500',
#    'name': 'BEAR CREEK NEAR REDMOND, WA',
#    'lon': -122.0773455,
#    'lat': 47.7175992},
#   {'site_code': '12211200',
#    'name': 'NOOKSACK RIVER AT EVERSON, WA',
#    'lon': -122.3479369,
#    'lat': 48.91789467},
#   {'site_code': '300722089150100',
#    'name': 'Mississippi Sound near Grand Pass',
#    'lon': -89.2502778,
#    'lat': 30.12277778},
#   {'site_code': '08167500',
#    'name': 'Guadalupe Rv nr Spring Branch, TX',
#    'lon': -98.3836275,
#    'lat': 29.8604957},
#   {'site_code': '12371550',
#    'name': 'Flathead Lake at Polson MT',
#    'lon': -114.1612972,
#    'lat': 47.6969083},
#   {'site_code': '15477730',
#    'name': 'LIESE C NR BIG DELTA AK',
#    'lon': -144.8854024,
#    'lat': 64.4476748},
#   {'site_code': '01315170',
#    'name': 'DURGIN BROOK AT BOREAS RIVER NY',
#    'lon': -73.9536111,
#    'lat': 43.9398333},
#   {'site_code': '10245970',
#    'name': 'ROBERTS CK NR EUREKA, NV',
#    'lon': -116.3009444,
#    'lat': 39.78977778},
#   {'site_code': '14197900',
#    'name': 'WILLAMETTE RIVER AT NEWBERG, OR',
#    'lon': -122.9614893,
#    'lat': 45.2845625},
#   {'site_code': '413542080245002',
#    'name': 'CW   413 Crawford County Observation Well',
#    'lon': -80.41375,
#    'lat': 41.5953333},
#   {'site_code': '01419500',
#    'name': 'WILLOWEMOC CREEK NR LIVINGSTON MANOR NY',
#    'lon': -74.81277778,
#    'lat': 41.9033333},
#   {'site_code': '04189131',
#    'name': 'Blanchard River at Gilboa OH',
#    'lon': -83.91888889,
#    'lat': 41.01527778},
#   {'site_code': '05517500',
#    'name': 'KANKAKEE RIVER AT DUNNS BRIDGE, IN',
#    'lon': -86.968356,
#    'lat': 41.2200392},
#   {'site_code': '08268700',
#    'name': 'RIO GRANDE NEAR ARROYO HONDO, NM',
#    'lon': -105.710012,
#    'lat': 36.53446658},
#   {'site_code': '03015795',
#    'name': 'East Hickory Creek near Queen, PA',
#    'lon': -79.3381018,
#    'lat': 41.64200548},
#   {'site_code': '332857117043305',
#    'name': '008S002W15F005S',
#    'lon': -117.0758889,
#    'lat': 33.4827222},
#   {'site_code': '01370520',
#    'name': 'WALLKILL RIVER AT PHILLIPSBURG NY',
#    'lon': -74.3657097,
#    'lat': 41.4389827},
#   {'site_code': '05426031',
#    'name': 'ROCK RIVER AT JEFFERSON, WI',
#    'lon': -88.8073274,
#    'lat': 42.99611515},
#   {'site_code': '05467000',
#    'name': 'POPE CREEK NEAR KEITHSBURG, IL',
#    'lon': -90.9193094,
#    'lat': 41.12892328},
#   {'site_code': '384713091474301',
#    'name': 'Reform',
#    'lon': -91.7952778,
#    'lat': 38.78666667},
#   {'site_code': '05484800',
#    'name': 'Walnut Creek at Des Moines, IA',
#    'lon': -93.7032762,
#    'lat': 41.5872114},
#   {'site_code': '261342081352903',
#    'name': 'C - 953R',
#    'lon': -81.5914694,
#    'lat': 26.2282111},
#   {'site_code': '02080500',
#    'name': 'ROANOKE RIVER AT ROANOKE RAPIDS, NC',
#    'lon': -77.6336111,
#    'lat': 36.46},
#   {'site_code': '405445100074001',
#    'name': ' 11N 25W24BCB 1  GOTHENBURG',
#    'lon': -100.1283889,
#    'lat': 40.9122222},
#   {'site_code': '415044089284800',
#    'name': 'ROCK RIVER AT DIXON, IL (ILDNR)',
#    'lon': -89.4801036,
#    'lat': 41.84558786},
#   ...],
#  'water_found': [],
#  'water_not_found': []}

# %%
len(sites_dict.get('unchecked'))
# Out:
# 20467

# %%
with open(filepath, 'w+') as fp:
    json.dump(sites_dict, fp)
